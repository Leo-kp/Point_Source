# %%
import os
import shutil
from pathlib import Path

import pyvista as pv
import ogstools as ot
import ogstools.variables as ov

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from meshing import create_cube_mesh_p
from functions_s import pd_ps,step_rate_s

# %% [markdown]
# # STIMTEC Example

# %% [markdown]
# ## Path adjoint

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out_ps"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Point-source step-rate

# %% [markdown]
# ### Preprocesing and preparing data

# %%
cwd=Path.cwd()
newpath=cwd/"STIMTEC_example"
TESTSR= 'BH10_20180716_51.6.csv'
dataex_f=pd.read_csv(newpath/"BH10_20180716_51.6_SR.csv",sep=",",header=0)
protocol=pd.read_csv(newpath/"protocol_SR.csv", sep=",",header=0)

# %%
fig3, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"{TESTSR},SR steps")

ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d")
for i in range (len(protocol)):
     ax.axvline(x=dataex_f.loc[protocol.iloc[i,0],'Zeit [s]'],ls="--",color="tab:red")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_downhole [lpm]_s'],label="Q downhole_smoothed")

plt.legend()
plt.show()

# %% [markdown]
# ### Point-source analytical running

# %%
#data 
ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":4e-8 ,
       "r_w":0.038 
      }

delta_t=dataex_f['Zeit [s]'].values
tp=protocol['T_s [s]'].values
q_array=protocol['qs [m**/s]'].values

k_val=4.5e-14 #reference k

rgeo=np.geomspace(0.038,5,5)
r_val=rgeo
pwsr2= step_rate_s(pd_ps, delta_t, tp, q_array, ddict, k_val, r_val)

rinv=np.sqrt(k_val*(max(dataex_f['Zeit [s]'])-min(dataex_f['Zeit [s]']))/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Investigation radius (m):  7.62
#  "unperturbed" threshold (m):  30.50

# %%
line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

fig5, ax=plt.subplots()

for i, r in enumerate(rgeo):
    plt.plot(delta_t, pwsr2[:, i]/1e6, label=f'r = {r:.2f} m')
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: BH10_20180716_51.6, r-values, k={k_val} m^2")

plt.legend() 
plt.pause(1)

# %% [markdown]
# ## Point-source Numerical

# %% [markdown]
# ### Meshing 3D point-source

# %%
cube_file = MESH_DIR / "cube_3d_ps.msh"

create_cube_mesh_p(
    cube_file,
    width= 50,
    height= 50,
    thickness=50,
    mesh_size= 2, #optimal one-size-to-mesh ratio= 20-40, ie, side(50)/mesh_size(2)=25, ref 1
    target_rw= 0.05, # Added target_rw for explicit control
    center_z= -50,
    debug_gui= False,
    local_ref= True,
    ) 

cube_meshes = ot.meshes_from_gmsh(cube_file, log=False)
for name, mesh in cube_meshes.items():
    vtu = MESH_DIR / f"cube_{name}.vtu"
    pv.save_meshio(vtu, mesh)
    print(f"Saved {vtu}")
# Out:
# Saved _out_ps\mesh\cube_domain.vtu
# Saved _out_ps\mesh\cube_physical_group_points.vtu
# Saved _out_ps\mesh\cube_physical_group_center.vtu
# Saved _out_ps\mesh\cube_physical_group_edges.vtu
# Saved _out_ps\mesh\cube_physical_group_bottom.vtu
# Saved _out_ps\mesh\cube_physical_group_top.vtu
# Saved _out_ps\mesh\cube_physical_group_back.vtu
# Saved _out_ps\mesh\cube_physical_group_front.vtu
# Saved _out_ps\mesh\cube_physical_group_left.vtu
# Saved _out_ps\mesh\cube_physical_group_right.vtu
# Saved _out_ps\mesh\cube_physical_group_volume.vtu

# %% [markdown]
# ### Running OGS

# %%
# !ogs ./BH10_20180716_51.6_PS3D.prj -m ./_out_ps/mesh -o ./_out_ps/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-04-09 17:26:13+0200.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file BH10_20180716_51.6_PS3D.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: pi_inf
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Initialize processes.
# info: Time step #0 started. Time: 2600.023. Step size: 0.
# info: [time] Output of timestep 0 took 0.515735 s.
# info: Time step #0 took 0.580323 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-04-09 17:26:16+0200.
# info: Solve processes.
# info: Time step #1 started. Time: 2600.123. Step size: 0.10000000000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.413323 s.
# info: [time] Applying Dirichlet BCs took 0.011305 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 74/10000
# info: 	 residual: 6.616393e-21
#
# info: [time] Linear solver took 0.0503929 s.
# info: Convergence criterion: |dx|=8.7321e+04, |x|=8.7321e+04, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.47526 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.415131 s.
# info: [time] Applying Dirichlet BCs took 0.0111689 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 20/10000
# info: 	 residual: 5.421533e-21
#
# info: [time] Linear solver took 0.0149564 s.
# info: Convergence criterion: |dx|=1.5143e-11, |x|=8.7321e+04, |dx|/|x|=1.7342e-16
# info: [time] Iteration #2 took 0.441446 s.
# info: [time] Solving process #0 took 0.917027 s in time step #1
# info: [time] Time step #1 took 0.987895 s.
# info: [time] Output of timestep 1 took 0.494042 s.
# info: Time step #2 started. Time: 2600.2730000000001. Step size: 0.15000000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.42698 s.
# info: [time] Applying Dirichlet BCs took 0.0121739 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 78/10000
# info: 	 residual: 6.797882e-21
#
# info: [time] Linear solver took 0.0557578 s.
# info: Convergence criterion: |dx|=3.8215e+04, |x|=1.1721e+05, |dx|/|x|=3.2605e-01
# info: [time] Iteration #1 took 0.495108 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.400248 s.
# info: [time] Applying Dirichlet BCs took 0.0125308 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 3.230279e-21
#
# info: [time] Linear solver took 0.0184709 s.
# info: Convergence criterion: |dx|=4.9083e-11, |x|=1.1721e+05, |dx|/|x|=4.1877e-16
# info: [time] Iteration #2 took 0.43143 s.
# info: [time] Solving process #0 took 0.927211 s in time step #2
# info: [time] Time step #2 took 0.99291 s.
# info: [time] Output of timestep 2 took 0.486362 s.
# info: Time step #3 started. Time: 2600.498. Step size: 0.22500000000000003.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.345999 s.
# info: [time] Applying Dirichlet BCs took 0.0104178 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 83/10000
# info: 	 residual: 7.504860e-21
#
# info: [time] Linear solver took 0.0559036 s.
# info: Convergence criterion: |dx|=2.9632e+04, |x|=1.3846e+05, |dx|/|x|=2.1401e-01
# info: [time] Iteration #1 took 0.412526 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.385251 s.
# info: [time] Applying Dirichlet BCs took 0.0105831 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 26/10000
# info: 	 residual: 9.210964e-21
#
# info: [time] Linear solver took 0.0183237 s.
# info: Convergence criterion: |dx|=6.8232e-11, |x|=1.3846e+05, |dx|/|x|=4.9277e-16
# info: [time] Iteration #2 took 0.414388 s.
# info: [time] Solving process #0 took 0.827345 s in time step #3
# info: [time] Time step #3 took 0.893953 s.
# info: [time] Output of timestep 3 took 0.479546 s.
# info: Time step #4 started. Time: 2600.8355000000001. Step size: 0.33750000000000002.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.36194 s.
# info: [time] Applying Dirichlet BCs took 0.0109708 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 87/10000
# info: 	 residual: 6.052878e-21
#
# info: [time] Linear solver took 0.0604413 s.
# info: Convergence criterion: |dx|=2.5103e+04, |x|=1.5630e+05, |dx|/|x|=1.6061e-01
# info: [time] Iteration #1 took 0.433576 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.372774 s.
# info: [time] Applying Dirichlet BCs took 0.0107978 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 28/10000
# info: 	 residual: 9.611833e-21
#
# info: [time] Linear solver took 0.0189516 s.
# info: Convergence criterion: |dx|=1.0339e-10, |x|=1.5630e+05, |dx|/|x|=6.6149e-16
# info: [time] Iteration #2 took 0.402756 s.
# info: [time] Solving process #0 took 0.836791 s in time step #4
# info: [time] Time step #4 took 0.902941 s.
# info: [time] Output of timestep 4 took 0.490924 s.
# info: Time step #5 started. Time: 2601.34175. Step size: 0.50625000000000009.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.338535 s.
# info: [time] Applying Dirichlet BCs took 0.0110204 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 97/10000
# info: 	 residual: 6.627166e-21
#
# info: [time] Linear solver took 0.0572951 s.
# info: Convergence criterion: |dx|=2.1709e+04, |x|=1.7179e+05, |dx|/|x|=1.2636e-01
# info: [time] Iteration #1 took 0.407039 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.374985 s.
# info: [time] Applying Dirichlet BCs took 0.0103402 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 33/10000
# info: 	 residual: 5.916244e-21
#
# info: [time] Linear solver took 0.0175032 s.
# info: Convergence criterion: |dx|=7.7805e-11, |x|=1.7179e+05, |dx|/|x|=4.5289e-16
# info: [time] Iteration #2 took 0.402974 s.
# info: [time] Solving process #0 took 0.810418 s in time step #5
# info: [time] Time step #5 took 0.86221 s.
# info: [time] Output of timestep 5 took 0.364973 s.
# info: Time step #6 started. Time: 2602.1011250000001. Step size: 0.75937500000000013.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.310314 s.
# info: [time] Applying Dirichlet BCs took 0.0118623 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 98/10000
# info: 	 residual: 8.140162e-21
#
# info: [time] Linear solver took 0.0494631 s.
# info: Convergence criterion: |dx|=1.8876e+04, |x|=1.8535e+05, |dx|/|x|=1.0184e-01
# info: [time] Iteration #1 took 0.371816 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.319729 s.
# info: [time] Applying Dirichlet BCs took 0.0088357 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 33/10000
# info: 	 residual: 8.198771e-21
#
# info: [time] Linear solver took 0.0187406 s.
# info: Convergence criterion: |dx|=8.6733e-11, |x|=1.8535e+05, |dx|/|x|=4.6795e-16
# info: [time] Iteration #2 took 0.347481 s.
# info: [time] Solving process #0 took 0.719715 s in time step #6
# info: [time] Time step #6 took 0.773412 s.
# info: [time] Output of timestep 6 took 0.36846 s.
# info: Time step #7 started. Time: 2603.2401875. Step size: 1.1390625000000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289578 s.
# info: [time] Applying Dirichlet BCs took 0.0087074 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 9.175610e-21
#
# info: [time] Linear solver took 0.0548138 s.
# info: Convergence criterion: |dx|=1.6420e+04, |x|=1.9717e+05, |dx|/|x|=8.3279e-02
# info: [time] Iteration #1 took 0.353271 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.32383 s.
# info: [time] Applying Dirichlet BCs took 0.0088765 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 37/10000
# info: 	 residual: 8.978187e-21
#
# info: [time] Linear solver took 0.019216 s.
# info: Convergence criterion: |dx|=1.1201e-10, |x|=1.9717e+05, |dx|/|x|=5.6810e-16
# info: [time] Iteration #2 took 0.352085 s.
# info: [time] Solving process #0 took 0.705726 s in time step #7
# info: [time] Time step #7 took 0.759176 s.
# info: [time] Output of timestep 7 took 0.361775 s.
# info: Time step #8 started. Time: 2604.9487812500001. Step size: 1.7085937500000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.309146 s.
# info: [time] Applying Dirichlet BCs took 0.0085204 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 108/10000
# info: 	 residual: 8.054607e-21
#
# info: [time] Linear solver took 0.0561314 s.
# info: Convergence criterion: |dx|=1.4260e+04, |x|=2.0744e+05, |dx|/|x|=6.8746e-02
# info: [time] Iteration #1 took 0.373967 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.306474 s.
# info: [time] Applying Dirichlet BCs took 0.0091055 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 38/10000
# info: 	 residual: 7.033730e-21
#
# info: [time] Linear solver took 0.0181901 s.
# info: Convergence criterion: |dx|=1.7095e-10, |x|=2.0744e+05, |dx|/|x|=8.2412e-16
# info: [time] Iteration #2 took 0.333926 s.
# info: [time] Solving process #0 took 0.708263 s in time step #8
# info: [time] Time step #8 took 0.758186 s.
# info: [time] Output of timestep 8 took 0.363946 s.
# info: Time step #9 started. Time: 2607.511671875. Step size: 2.5628906250000001.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289996 s.
# info: [time] Applying Dirichlet BCs took 0.0087974 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 108/10000
# info: 	 residual: 8.103721e-21
#
# info: [time] Linear solver took 0.0541007 s.
# info: Convergence criterion: |dx|=1.2353e+04, |x|=2.1629e+05, |dx|/|x|=5.7114e-02
# info: [time] Iteration #1 took 0.353067 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.311099 s.
# info: [time] Applying Dirichlet BCs took 0.0085665 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.034102e-21
#
# info: [time] Linear solver took 0.0185749 s.
# info: Convergence criterion: |dx|=1.1085e-10, |x|=2.1629e+05, |dx|/|x|=5.1250e-16
# info: [time] Iteration #2 took 0.338453 s.
# info: [time] Solving process #0 took 0.691936 s in time step #9
# info: [time] Time step #9 took 0.745006 s.
# info: [time] Output of timestep 9 took 0.363358 s.
# info: Time step #10 started. Time: 2611.3560078125001. Step size: 3.8443359375000004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.300602 s.
# info: [time] Applying Dirichlet BCs took 0.0091339 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 111/10000
# info: 	 residual: 8.808956e-21
#
# info: [time] Linear solver took 0.0574271 s.
# info: Convergence criterion: |dx|=1.0670e+04, |x|=2.2389e+05, |dx|/|x|=4.7655e-02
# info: [time] Iteration #1 took 0.367369 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305434 s.
# info: [time] Applying Dirichlet BCs took 0.0091818 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 37/10000
# info: 	 residual: 8.157639e-21
#
# info: [time] Linear solver took 0.0205087 s.
# info: Convergence criterion: |dx|=1.6730e-10, |x|=2.2389e+05, |dx|/|x|=7.4723e-16
# info: [time] Iteration #2 took 0.335313 s.
# info: [time] Solving process #0 took 0.703206 s in time step #10
# info: [time] Time step #10 took 0.752697 s.
# info: [time] Output of timestep 10 took 0.365179 s.
# info: Time step #11 started. Time: 2617.12251171875. Step size: 5.7665039062500005.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.303968 s.
# info: [time] Applying Dirichlet BCs took 0.0092611 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 114/10000
# info: 	 residual: 7.078751e-21
#
# info: [time] Linear solver took 0.0564944 s.
# info: Convergence criterion: |dx|=9.1843e+03, |x|=2.3037e+05, |dx|/|x|=3.9867e-02
# info: [time] Iteration #1 took 0.369891 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.31341 s.
# info: [time] Applying Dirichlet BCs took 0.008837 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 38/10000
# info: 	 residual: 8.048507e-21
#
# info: [time] Linear solver took 0.0193523 s.
# info: Convergence criterion: |dx|=1.0657e-10, |x|=2.3037e+05, |dx|/|x|=4.6261e-16
# info: [time] Iteration #2 took 0.341769 s.
# info: [time] Solving process #0 took 0.712057 s in time step #11
# info: [time] Time step #11 took 0.764212 s.
# info: [time] Output of timestep 11 took 0.361244 s.
# info: Time step #12 started. Time: 2625.7722675781251. Step size: 8.6497558593750004.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.281957 s.
# info: [time] Applying Dirichlet BCs took 0.0083288 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 6.386825e-21
#
# info: [time] Linear solver took 0.059654 s.
# info: Convergence criterion: |dx|=7.8766e+03, |x|=2.3587e+05, |dx|/|x|=3.3393e-02
# info: [time] Iteration #1 took 0.350129 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.326949 s.
# info: [time] Applying Dirichlet BCs took 0.0091585 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 40/10000
# info: 	 residual: 9.047987e-21
#
# info: [time] Linear solver took 0.0206931 s.
# info: Convergence criterion: |dx|=1.2043e-10, |x|=2.3587e+05, |dx|/|x|=5.1055e-16
# info: [time] Iteration #2 took 0.356963 s.
# info: [time] Solving process #0 took 0.707495 s in time step #12
# info: [time] Time step #12 took 0.761233 s.
# info: [time] Output of timestep 12 took 0.366292 s.
# info: Time step #13 started. Time: 2635.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.286921 s.
# info: [time] Applying Dirichlet BCs took 0.0084629 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 121/10000
# info: 	 residual: 8.483127e-21
#
# info: [time] Linear solver took 0.0609105 s.
# info: Convergence criterion: |dx|=5.6578e+03, |x|=2.3978e+05, |dx|/|x|=2.3595e-02
# info: [time] Iteration #1 took 0.356466 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314383 s.
# info: [time] Applying Dirichlet BCs took 0.0089139 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 9.353072e-21
#
# info: [time] Linear solver took 0.021179 s.
# info: Convergence criterion: |dx|=1.7595e-10, |x|=2.3978e+05, |dx|/|x|=7.3380e-16
# info: [time] Iteration #2 took 0.344637 s.
# info: [time] Solving process #0 took 0.701475 s in time step #13
# info: [time] Time step #13 took 0.752709 s.
# info: [time] Output of timestep 13 took 0.365353 s.
# info: Time step #14 started. Time: 2645.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.283853 s.
# info: [time] Applying Dirichlet BCs took 0.0085479 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 121/10000
# info: 	 residual: 8.387383e-21
#
# info: [time] Linear solver took 0.0600259 s.
# info: Convergence criterion: |dx|=3.8843e+03, |x|=2.4244e+05, |dx|/|x|=1.6021e-02
# info: [time] Iteration #1 took 0.352623 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.327725 s.
# info: [time] Applying Dirichlet BCs took 0.0128598 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 7.859258e-21
#
# info: [time] Linear solver took 0.0235558 s.
# info: Convergence criterion: |dx|=1.2559e-10, |x|=2.4244e+05, |dx|/|x|=5.1803e-16
# info: [time] Iteration #2 took 0.364298 s.
# info: [time] Solving process #0 took 0.717297 s in time step #14
# info: [time] Time step #14 took 0.771816 s.
# info: [time] Output of timestep 14 took 0.367984 s.
# info: Time step #15 started. Time: 2655.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.316953 s.
# info: [time] Applying Dirichlet BCs took 0.0107068 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 121/10000
# info: 	 residual: 8.041544e-21
#
# info: [time] Linear solver took 0.0618736 s.
# info: Convergence criterion: |dx|=2.8575e+03, |x|=2.4438e+05, |dx|/|x|=1.1693e-02
# info: [time] Iteration #1 took 0.389703 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305676 s.
# info: [time] Applying Dirichlet BCs took 0.0097472 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 8.976701e-21
#
# info: [time] Linear solver took 0.0212714 s.
# info: Convergence criterion: |dx|=1.5933e-10, |x|=2.4438e+05, |dx|/|x|=6.5194e-16
# info: [time] Iteration #2 took 0.336856 s.
# info: [time] Solving process #0 took 0.726936 s in time step #15
# info: [time] Time step #15 took 0.778172 s.
# info: [time] Output of timestep 15 took 0.363054 s.
# info: Time step #16 started. Time: 2665.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.281036 s.
# info: [time] Applying Dirichlet BCs took 0.0094264 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 128/10000
# info: 	 residual: 9.182165e-21
#
# info: [time] Linear solver took 0.0643353 s.
# info: Convergence criterion: |dx|=6.9069e+05, |x|=9.3338e+05, |dx|/|x|=7.3999e-01
# info: [time] Iteration #1 took 0.354969 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.312968 s.
# info: [time] Applying Dirichlet BCs took 0.0097836 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 40/10000
# info: 	 residual: 8.937121e-21
#
# info: [time] Linear solver took 0.0206927 s.
# info: Convergence criterion: |dx|=4.9914e-10, |x|=9.3338e+05, |dx|/|x|=5.3477e-16
# info: [time] Iteration #2 took 0.343597 s.
# info: [time] Solving process #0 took 0.698916 s in time step #16
# info: [time] Time step #16 took 0.752537 s.
# info: [time] Output of timestep 16 took 0.376496 s.
# info: Time step #17 started. Time: 2675.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.295243 s.
# info: [time] Applying Dirichlet BCs took 0.0108762 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 6.364852e-21
#
# info: [time] Linear solver took 0.0626419 s.
# info: Convergence criterion: |dx|=9.1866e+04, |x|=1.0072e+06, |dx|/|x|=9.1210e-02
# info: [time] Iteration #1 took 0.36893 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314882 s.
# info: [time] Applying Dirichlet BCs took 0.0097861 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 7.808144e-21
#
# info: [time] Linear solver took 0.0233609 s.
# info: Convergence criterion: |dx|=5.5125e-10, |x|=1.0072e+06, |dx|/|x|=5.4732e-16
# info: [time] Iteration #2 took 0.348194 s.
# info: [time] Solving process #0 took 0.717499 s in time step #17
# info: [time] Time step #17 took 0.773303 s.
# info: [time] Output of timestep 17 took 0.358376 s.
# info: Time step #18 started. Time: 2685.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.360332 s.
# info: [time] Applying Dirichlet BCs took 0.0130178 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 121/10000
# info: 	 residual: 7.048440e-21
#
# info: [time] Linear solver took 0.0672759 s.
# info: Convergence criterion: |dx|=3.6027e+04, |x|=1.0338e+06, |dx|/|x|=3.4850e-02
# info: [time] Iteration #1 took 0.440803 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.336949 s.
# info: [time] Applying Dirichlet BCs took 0.0101781 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 8.425616e-21
#
# info: [time] Linear solver took 0.0213305 s.
# info: Convergence criterion: |dx|=5.7666e-10, |x|=1.0338e+06, |dx|/|x|=5.5783e-16
# info: [time] Iteration #2 took 0.368624 s.
# info: [time] Solving process #0 took 0.809746 s in time step #18
# info: [time] Time step #18 took 0.865594 s.
# info: [time] Output of timestep 18 took 0.384527 s.
# info: Time step #19 started. Time: 2695.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.355765 s.
# info: [time] Applying Dirichlet BCs took 0.0149913 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 131/10000
# info: 	 residual: 9.040337e-21
#
# info: [time] Linear solver took 0.0734835 s.
# info: Convergence criterion: |dx|=6.6897e+05, |x|=3.8316e+05, |dx|/|x|=1.7459e+00
# info: [time] Iteration #1 took 0.444402 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.339084 s.
# info: [time] Applying Dirichlet BCs took 0.010882 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 9.599005e-21
#
# info: [time] Linear solver took 0.0247244 s.
# info: Convergence criterion: |dx|=3.7481e-10, |x|=3.8316e+05, |dx|/|x|=9.7823e-16
# info: [time] Iteration #2 took 0.374861 s.
# info: [time] Solving process #0 took 0.819631 s in time step #19
# info: [time] Time step #19 took 0.875765 s.
# info: [time] Output of timestep 19 took 0.374855 s.
# info: Time step #20 started. Time: 2705.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.357806 s.
# info: [time] Applying Dirichlet BCs took 0.0117904 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 8.226767e-21
#
# info: [time] Linear solver took 0.0658377 s.
# info: Convergence criterion: |dx|=7.6793e+04, |x|=3.1148e+05, |dx|/|x|=2.4654e-01
# info: [time] Iteration #1 took 0.435592 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.316622 s.
# info: [time] Applying Dirichlet BCs took 0.0099631 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 8.708635e-21
#
# info: [time] Linear solver took 0.0217541 s.
# info: Convergence criterion: |dx|=1.6308e-10, |x|=3.1148e+05, |dx|/|x|=5.2357e-16
# info: [time] Iteration #2 took 0.348498 s.
# info: [time] Solving process #0 took 0.784427 s in time step #20
# info: [time] Time step #20 took 0.838752 s.
# info: [time] Output of timestep 20 took 0.368225 s.
# info: Time step #21 started. Time: 2715.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.303783 s.
# info: [time] Applying Dirichlet BCs took 0.0100482 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 128/10000
# info: 	 residual: 7.224750e-21
#
# info: [time] Linear solver took 0.0627626 s.
# info: Convergence criterion: |dx|=3.3958e+05, |x|=6.4118e+05, |dx|/|x|=5.2961e-01
# info: [time] Iteration #1 took 0.376767 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.32618 s.
# info: [time] Applying Dirichlet BCs took 0.0109274 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 7.539919e-21
#
# info: [time] Linear solver took 0.0212596 s.
# info: Convergence criterion: |dx|=3.4885e-10, |x|=6.4118e+05, |dx|/|x|=5.4408e-16
# info: [time] Iteration #2 took 0.358526 s.
# info: [time] Solving process #0 took 0.735628 s in time step #21
# info: [time] Time step #21 took 0.785817 s.
# info: [time] Output of timestep 21 took 0.376088 s.
# info: Time step #22 started. Time: 2725.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.362189 s.
# info: [time] Applying Dirichlet BCs took 0.0101314 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 9.593735e-21
#
# info: [time] Linear solver took 0.0599819 s.
# info: Convergence criterion: |dx|=3.5726e+04, |x|=6.7180e+05, |dx|/|x|=5.3179e-02
# info: [time] Iteration #1 took 0.432473 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.362791 s.
# info: [time] Applying Dirichlet BCs took 0.0091398 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 6.851038e-21
#
# info: [time] Linear solver took 0.0212105 s.
# info: Convergence criterion: |dx|=5.2156e-10, |x|=6.7180e+05, |dx|/|x|=7.7637e-16
# info: [time] Iteration #2 took 0.393309 s.
# info: [time] Solving process #0 took 0.826136 s in time step #22
# info: [time] Time step #22 took 0.882085 s.
# info: [time] Output of timestep 22 took 0.36408 s.
# info: Time step #23 started. Time: 2735.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.349342 s.
# info: [time] Applying Dirichlet BCs took 0.0101154 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 9.914074e-21
#
# info: [time] Linear solver took 0.0629533 s.
# info: Convergence criterion: |dx|=1.1636e+04, |x|=6.8091e+05, |dx|/|x|=1.7089e-02
# info: [time] Iteration #1 took 0.422585 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305187 s.
# info: [time] Applying Dirichlet BCs took 0.0103875 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 9.341196e-21
#
# info: [time] Linear solver took 0.0217105 s.
# info: Convergence criterion: |dx|=3.8340e-10, |x|=6.8091e+05, |dx|/|x|=5.6307e-16
# info: [time] Iteration #2 took 0.337454 s.
# info: [time] Solving process #0 took 0.760415 s in time step #23
# info: [time] Time step #23 took 0.809492 s.
# info: [time] Output of timestep 23 took 0.363937 s.
# info: Time step #24 started. Time: 2745.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.319284 s.
# info: [time] Applying Dirichlet BCs took 0.0092117 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 121/10000
# info: 	 residual: 5.948157e-21
#
# info: [time] Linear solver took 0.0602329 s.
# info: Convergence criterion: |dx|=6.1066e+03, |x|=6.8542e+05, |dx|/|x|=8.9093e-03
# info: [time] Iteration #1 took 0.388897 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.31054 s.
# info: [time] Applying Dirichlet BCs took 0.009109 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 8.385514e-21
#
# info: [time] Linear solver took 0.0210243 s.
# info: Convergence criterion: |dx|=3.9425e-10, |x|=6.8542e+05, |dx|/|x|=5.7519e-16
# info: [time] Iteration #2 took 0.340834 s.
# info: [time] Solving process #0 took 0.730041 s in time step #24
# info: [time] Time step #24 took 0.781536 s.
# info: [time] Output of timestep 24 took 0.365193 s.
# info: Time step #25 started. Time: 2755.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.292987 s.
# info: [time] Applying Dirichlet BCs took 0.0094496 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 9.968229e-21
#
# info: [time] Linear solver took 0.0597193 s.
# info: Convergence criterion: |dx|=4.0550e+03, |x|=6.8830e+05, |dx|/|x|=5.8913e-03
# info: [time] Iteration #1 took 0.362338 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.319132 s.
# info: [time] Applying Dirichlet BCs took 0.0090349 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.420109e-21
#
# info: [time] Linear solver took 0.021927 s.
# info: Convergence criterion: |dx|=6.0697e-10, |x|=6.8830e+05, |dx|/|x|=8.8183e-16
# info: [time] Iteration #2 took 0.350256 s.
# info: [time] Solving process #0 took 0.712901 s in time step #25
# info: [time] Time step #25 took 0.767401 s.
# info: [time] Output of timestep 25 took 0.357433 s.
# info: Time step #26 started. Time: 2765.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.287987 s.
# info: [time] Applying Dirichlet BCs took 0.0090723 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 9.078531e-21
#
# info: [time] Linear solver took 0.0596096 s.
# info: Convergence criterion: |dx|=3.0491e+03, |x|=6.9041e+05, |dx|/|x|=4.4164e-03
# info: [time] Iteration #1 took 0.356852 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314557 s.
# info: [time] Applying Dirichlet BCs took 0.0091598 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 8.263972e-21
#
# info: [time] Linear solver took 0.0216804 s.
# info: Convergence criterion: |dx|=6.8649e-10, |x|=6.9041e+05, |dx|/|x|=9.9432e-16
# info: [time] Iteration #2 took 0.345558 s.
# info: [time] Solving process #0 took 0.702728 s in time step #26
# info: [time] Time step #26 took 0.754364 s.
# info: [time] Output of timestep 26 took 0.362597 s.
# info: Time step #27 started. Time: 2775.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.28187 s.
# info: [time] Applying Dirichlet BCs took 0.0088769 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 8.171473e-21
#
# info: [time] Linear solver took 0.0593032 s.
# info: Convergence criterion: |dx|=2.4605e+03, |x|=6.9208e+05, |dx|/|x|=3.5552e-03
# info: [time] Iteration #1 took 0.350227 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.308837 s.
# info: [time] Applying Dirichlet BCs took 0.0088393 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 7.966100e-21
#
# info: [time] Linear solver took 0.0217926 s.
# info: Convergence criterion: |dx|=5.3245e-10, |x|=6.9208e+05, |dx|/|x|=7.6935e-16
# info: [time] Iteration #2 took 0.339647 s.
# info: [time] Solving process #0 took 0.69019 s in time step #27
# info: [time] Time step #27 took 0.742822 s.
# info: [time] Output of timestep 27 took 0.365248 s.
# info: Time step #28 started. Time: 2785.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.300605 s.
# info: [time] Applying Dirichlet BCs took 0.0088835 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 7.370845e-21
#
# info: [time] Linear solver took 0.0616629 s.
# info: Convergence criterion: |dx|=2.0730e+03, |x|=6.9346e+05, |dx|/|x|=2.9893e-03
# info: [time] Iteration #1 took 0.371325 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.311609 s.
# info: [time] Applying Dirichlet BCs took 0.009132 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 9.056017e-21
#
# info: [time] Linear solver took 0.0213201 s.
# info: Convergence criterion: |dx|=5.1698e-10, |x|=6.9346e+05, |dx|/|x|=7.4551e-16
# info: [time] Iteration #2 took 0.342219 s.
# info: [time] Solving process #0 took 0.713861 s in time step #28
# info: [time] Time step #28 took 0.768394 s.
# info: [time] Output of timestep 28 took 0.363695 s.
# info: Time step #29 started. Time: 2795.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.44284 s.
# info: [time] Applying Dirichlet BCs took 0.0106117 s.
# ...
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.102451e-21
#
# info: [time] Linear solver took 0.0189683 s.
# info: Convergence criterion: |dx|=1.8347e-09, |x|=2.5647e+06, |dx|/|x|=7.1537e-16
# info: [time] Iteration #2 took 0.334027 s.
# info: [time] Solving process #0 took 0.686974 s in time step #156
# info: [time] Time step #156 took 0.740178 s.
# info: [time] Output of timestep 156 took 0.375564 s.
# info: Time step #157 started. Time: 4075.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.309768 s.
# info: [time] Applying Dirichlet BCs took 0.0087241 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 120/10000
# info: 	 residual: 7.000552e-21
#
# info: [time] Linear solver took 0.0618788 s.
# info: Convergence criterion: |dx|=2.0575e+05, |x|=2.3620e+06, |dx|/|x|=8.7106e-02
# info: [time] Iteration #1 took 0.38055 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303953 s.
# info: [time] Applying Dirichlet BCs took 0.0087884 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 8.904478e-21
#
# info: [time] Linear solver took 0.0186519 s.
# info: Convergence criterion: |dx|=1.3899e-09, |x|=2.3620e+06, |dx|/|x|=5.8844e-16
# info: [time] Iteration #2 took 0.33156 s.
# info: [time] Solving process #0 took 0.712463 s in time step #157
# info: [time] Time step #157 took 0.766887 s.
# info: [time] Output of timestep 157 took 0.371673 s.
# info: Time step #158 started. Time: 4085.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.32208 s.
# info: [time] Applying Dirichlet BCs took 0.0086968 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 119/10000
# info: 	 residual: 9.617956e-21
#
# info: [time] Linear solver took 0.0590606 s.
# info: Convergence criterion: |dx|=1.7133e+05, |x|=2.1933e+06, |dx|/|x|=7.8119e-02
# info: [time] Iteration #1 took 0.390025 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.325008 s.
# info: [time] Applying Dirichlet BCs took 0.0093594 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 8.073087e-21
#
# info: [time] Linear solver took 0.0189873 s.
# info: Convergence criterion: |dx|=1.2157e-09, |x|=2.1933e+06, |dx|/|x|=5.5430e-16
# info: [time] Iteration #2 took 0.353515 s.
# info: [time] Solving process #0 took 0.743864 s in time step #158
# info: [time] Time step #158 took 0.795116 s.
# info: [time] Output of timestep 158 took 0.365531 s.
# info: Time step #159 started. Time: 4095.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.278927 s.
# info: [time] Applying Dirichlet BCs took 0.0087259 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 119/10000
# info: 	 residual: 8.397863e-21
#
# info: [time] Linear solver took 0.0595133 s.
# info: Convergence criterion: |dx|=1.4531e+05, |x|=2.0501e+06, |dx|/|x|=7.0881e-02
# info: [time] Iteration #1 took 0.347355 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314909 s.
# info: [time] Applying Dirichlet BCs took 0.0087802 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 7.606763e-21
#
# info: [time] Linear solver took 0.0184144 s.
# info: Convergence criterion: |dx|=1.1160e-09, |x|=2.0501e+06, |dx|/|x|=5.4437e-16
# info: [time] Iteration #2 took 0.342276 s.
# info: [time] Solving process #0 took 0.689938 s in time step #159
# info: [time] Time step #159 took 0.741005 s.
# info: [time] Output of timestep 159 took 0.368388 s.
# info: Time step #160 started. Time: 4105.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289086 s.
# info: [time] Applying Dirichlet BCs took 0.0114277 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 118/10000
# info: 	 residual: 9.891554e-21
#
# info: [time] Linear solver took 0.0614655 s.
# info: Convergence criterion: |dx|=1.2508e+05, |x|=1.9268e+06, |dx|/|x|=6.4916e-02
# info: [time] Iteration #1 took 0.362168 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.311685 s.
# info: [time] Applying Dirichlet BCs took 0.0089838 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 8.004502e-21
#
# info: [time] Linear solver took 0.0182115 s.
# info: Convergence criterion: |dx|=1.0299e-09, |x|=1.9268e+06, |dx|/|x|=5.3449e-16
# info: [time] Iteration #2 took 0.339042 s.
# info: [time] Solving process #0 took 0.701539 s in time step #160
# info: [time] Time step #160 took 0.756101 s.
# info: [time] Output of timestep 160 took 0.36721 s.
# info: Time step #161 started. Time: 4115.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.281298 s.
# info: [time] Applying Dirichlet BCs took 0.0089878 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 118/10000
# info: 	 residual: 9.566102e-21
#
# info: [time] Linear solver took 0.0590033 s.
# info: Convergence criterion: |dx|=1.0899e+05, |x|=1.8194e+06, |dx|/|x|=5.9905e-02
# info: [time] Iteration #1 took 0.34947 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307254 s.
# info: [time] Applying Dirichlet BCs took 0.0089367 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 32/10000
# info: 	 residual: 9.932767e-21
#
# info: [time] Linear solver took 0.0164622 s.
# info: Convergence criterion: |dx|=9.8041e-10, |x|=1.8194e+06, |dx|/|x|=5.3885e-16
# info: [time] Iteration #2 took 0.332813 s.
# info: [time] Solving process #0 took 0.682619 s in time step #161
# info: [time] Time step #161 took 0.734187 s.
# info: [time] Output of timestep 161 took 0.366102 s.
# info: Time step #162 started. Time: 4125.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.319853 s.
# info: [time] Applying Dirichlet BCs took 0.0090586 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 112/10000
# info: 	 residual: 8.492714e-21
#
# info: [time] Linear solver took 0.0574899 s.
# info: Convergence criterion: |dx|=9.5958e+04, |x|=1.7249e+06, |dx|/|x|=5.5630e-02
# info: [time] Iteration #1 took 0.386579 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.309182 s.
# info: [time] Applying Dirichlet BCs took 0.009728 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 8.452519e-21
#
# info: [time] Linear solver took 0.0180852 s.
# info: Convergence criterion: |dx|=1.0135e-09, |x|=1.7249e+06, |dx|/|x|=5.8759e-16
# info: [time] Iteration #2 took 0.337156 s.
# info: [time] Solving process #0 took 0.72408 s in time step #162
# info: [time] Time step #162 took 0.77763 s.
# info: [time] Output of timestep 162 took 0.36591 s.
# info: Time step #163 started. Time: 4135.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.287851 s.
# info: [time] Applying Dirichlet BCs took 0.0090343 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 118/10000
# info: 	 residual: 7.856996e-21
#
# info: [time] Linear solver took 0.0588926 s.
# info: Convergence criterion: |dx|=8.5225e+04, |x|=1.6410e+06, |dx|/|x|=5.1935e-02
# info: [time] Iteration #1 took 0.355952 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.311772 s.
# info: [time] Applying Dirichlet BCs took 0.0090925 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 9.049001e-21
#
# info: [time] Linear solver took 0.0182442 s.
# info: Convergence criterion: |dx|=9.9899e-10, |x|=1.6410e+06, |dx|/|x|=6.0877e-16
# info: [time] Iteration #2 took 0.339284 s.
# info: [time] Solving process #0 took 0.695584 s in time step #163
# info: [time] Time step #163 took 0.749439 s.
# info: [time] Output of timestep 163 took 0.370587 s.
# info: Time step #164 started. Time: 4145.7722675781251. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.282746 s.
# info: [time] Applying Dirichlet BCs took 0.0101817 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 111/10000
# info: 	 residual: 9.271127e-21
#
# info: [time] Linear solver took 0.0571173 s.
# info: Convergence criterion: |dx|=7.6268e+04, |x|=1.5659e+06, |dx|/|x|=4.8705e-02
# info: [time] Iteration #1 took 0.350228 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.316428 s.
# info: [time] Applying Dirichlet BCs took 0.0091649 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 6.992298e-21
#
# info: [time] Linear solver took 0.018295 s.
# info: Convergence criterion: |dx|=8.9567e-10, |x|=1.5659e+06, |dx|/|x|=5.7197e-16
# info: [time] Iteration #2 took 0.344061 s.
# info: [time] Solving process #0 took 0.694619 s in time step #164
# info: [time] Time step #164 took 0.745866 s.
# info: [time] Output of timestep 164 took 0.359972 s.
# info: Time step #165 started. Time: 4149.973. Step size: 4.2007324218748181.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.28715 s.
# info: [time] Applying Dirichlet BCs took 0.0091546 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 107/10000
# info: 	 residual: 7.792252e-21
#
# info: [time] Linear solver took 0.0530423 s.
# info: Convergence criterion: |dx|=2.0115e+05, |x|=1.4422e+06, |dx|/|x|=1.3947e-01
# info: [time] Iteration #1 took 0.34952 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.317415 s.
# info: [time] Applying Dirichlet BCs took 0.0103272 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 28/10000
# info: 	 residual: 9.309926e-21
#
# info: [time] Linear solver took 0.0151754 s.
# info: Convergence criterion: |dx|=7.9837e-10, |x|=1.4422e+06, |dx|/|x|=5.5357e-16
# info: [time] Iteration #2 took 0.343084 s.
# info: [time] Solving process #0 took 0.693007 s in time step #165
# info: [time] Time step #165 took 0.746835 s.
# info: [time] Output of timestep 165 took 0.366058 s.
# info: The whole computation of the time stepping took 165 steps, in which
# 	 the accepted steps are 165, and the rejected steps are 0.
#
# info: [time] Execution took 188.917 s.
# info: OGS terminated on 2026-04-09 17:29:25+0200.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path = Path("_out_ps/BH10_20180716_51.6.pvd")
ms = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=25
z=-50

np.geomspace(0.038,5,5)

coords=np.array(np.linspace([25,y,z],[50,y,z],5)) #extracting along x linearly
coords[:,0]=rgeo+25 #adjusting geometry shifting
ms_probes = ms.extract_probe(ms,points=coords)

labels = [f"x={pt[0]:>5.2f}, y={y}, z={z}" for pt in coords]

pwsr2p= step_rate_s(pd_ps, ms_probes.timevalues, tp, q_array, ddict, k_val, r_val) #diff by time resolution
diff = pwsr2p - ms_probes['pressure']
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 166/166 [00:15<00:00, 10.92it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
t=dataex_f['Zeit [s]']

fig7, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
ot.plot.line(ms_probes,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(t, pwsr2/1e6,color='tab:red', label=line_labels) 
axs[1].plot(ms_probes.timevalues, diff/1e6, label=line_labels)

fig7.suptitle("Point source analytical - Numerical OGS Nodal, 3D") 
axs[0].set_title("Results by distance (radius)")
axs[1].set_title("Difference analytical-OGS")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

#plt.savefig("psn_3D_BH10_20180716_51.6.pdf", format="pdf") 
plt.show()

# %% [markdown]
# **NOTE: Numerical difference is due to mesh and rw relations.
# The specific storage capacity (OGS) scaling is equal to $$s=c* \phi, \quad \left[\mathrm{Pa^{-1}}\right]$$, the scaling for the flow is $$r_{\mathrm{eq}} = (3 * LV / (4 \pi))^{1/3}$$
# $$q_{\mathrm{fact}}=(1/r_{\mathrm{eq}})^{2/3}$$
# $$q_{\mathrm{num}}=q_{\mathrm{fact}} \, q_{\mathrm{an}}$$
# Where $LV$ is the local volume of the first ring of elements in around the node source; $q_{\mathrm{num}}\, , q_{\mathrm{fact}} \, , q_{\mathrm{an}}$, are the numerical (for OGS), factor, and analytical flow input.
