# %%
import os
import shutil
from pathlib import Path

import pyvista as pv
import ogstools as ot
import ogstools.variables as ov

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from meshing import create_cube_mesh_p, create_cube_mesh_psc
from functions import pwd_ps,step_rate_s, scale_and_smooth, pickings

# %% [markdown]
# # Path

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Point-source and model performance

# %% [markdown]
# ## Point-source analytical

# %%
k=5.35e-9
q=0.00016 #positive for production
r=np.linspace(1,25,20) #array or r 
t=np.linspace(0,100,26) #  t have to be equivalent to ms.timevalues 
t[0]=1e-10
rgeo=np.geomspace(1, 25, 6).round(2)

ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.2,
       "c_t":4.37e-5 ,
       "r_w":0.038,
      }

rinv=np.sqrt(k*max(t)/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Investigation radius (m):  7.82
#  "unperturbed" threshold (m):  31.30

# %%
#Point source
r_col=rgeo
pi, mu, B,rw= ddict['p_i'], ddict['mu'], ddict['B'],ddict['r_w']

C_vec = (mu * B) / (4 * np.pi * k * rw)
term1_matrix = pwd_ps(t, ddict, k, r_col) 

p_wsr = pi - (C_vec * q * term1_matrix)

# %%
line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

fig0, ax=plt.subplots()
ax.plot(t, p_wsr,label=line_labels) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title("Point source analytical")

plt.legend()
plt.pause(1)

# %% [markdown]
# ## Point-source numerical

# %% [markdown]
# ### Meshing 3D point-source

# %%
cube_file = MESH_DIR / "cube_3d_ps.msh"

create_cube_mesh_p(
        cube_file,        
        width=50.0,
        height=50.0,
        thickness=50.0,
        mesh_size=2.0, #optimal one-size-to-mesh ratio= 20-40, ie, side(50)/mesh_size(2)=25
        center_z=-100.0,
        debug_gui= False,
        local_ref=True,
    )

cube_meshes = ot.meshes_from_gmsh(cube_file, log=False)
for name, mesh in cube_meshes.items():
    vtu = MESH_DIR / f"cube_{name}.vtu"
    pv.save_meshio(vtu, mesh)
    print(f"Saved {vtu}")
# Out:
# Saved _out\mesh\cube_domain.vtu
# Saved _out\mesh\cube_physical_group_points.vtu
# Saved _out\mesh\cube_physical_group_center.vtu
# Saved _out\mesh\cube_physical_group_edges.vtu
# Saved _out\mesh\cube_physical_group_bottom.vtu
# Saved _out\mesh\cube_physical_group_top.vtu
# Saved _out\mesh\cube_physical_group_back.vtu
# Saved _out\mesh\cube_physical_group_front.vtu
# Saved _out\mesh\cube_physical_group_left.vtu
# Saved _out\mesh\cube_physical_group_right.vtu
# Saved _out\mesh\cube_physical_group_volume.vtu

# %% [markdown]
# ### PRJ file pre-procesing

# %%
PROJECT_BASENAME = "Point_source_3Dtest" 
prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR / f"{PROJECT_BASENAME}_updated.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
parent_xpath = "./processes/process[1]"
target_path = "./processes/process[1]/equation_balance_type"

try:
    root = prj.tree.getroot()
    node = root.find(target_path)
    
    if node is not None:
        if node.text == "volume":
            print("Verified: equation_balance_type 'volume' already exists.")
        else:
            prj.replace_text("volume", xpath=target_path)
            print("Updated: Existing equation_balance_type changed to 'volume'.")
    else:
        print("Adding equation_balance_type=volume")
        prj.add_element(
            parent_xpath=parent_xpath, 
            tag="equation_balance_type", 
            text="volume"
        )

except Exception as e:
    print(f"Error: {e}")
# Out:
# Adding equation_balance_type=volume

# %%
#permeability ref numerical
k_ref= 5.35e-9

# %%
q=-1*q #changing to proudction OGS

try:
    prj.replace_parameter_value(name="p0", value=ddict["p_i"])
    prj.replace_parameter_value(name="pi_inf", value=ddict["p_i"])
    prj.replace_parameter_value(name="q_in", value=q)

    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value=ddict["c_t"])
    
    print("media/properties, Parameters updated")
except Exception as e:
    print(f"Error occurred: {e}")
    
prj.write_input()
print('\n', f"prj update in {prj_out} as {PROJECT_BASENAME}_updated.prj")
# Out:
# media/properties, Parameters updated
#
#  prj update in _out\Point_source_3Dtest_updated.prj as Point_source_3Dtest_updated.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs ./_out/Point_source_3Dtest_updated.prj -m ./_out/mesh -o ./_out/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-04 16:45:14+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out\Point_source_3Dtest_updated.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: pi_inf
# info: ConstantParameter: constant_porosity_parameter
# info: ConstantParameter: q_in
# info: Initialize processes.
# info: Time step #0 started. Time: 0. Step size: 0.
# info: [time] Output of timestep 0 took 0.297873 s.
# info: Time step #0 took 0.333603 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-04 16:45:16+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 2. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.331826 s.
# info: [time] Applying Dirichlet BCs took 0.0093915 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 78/10000
# info: 	 residual: 5.791112e-21
#
# info: [time] Linear solver took 0.0382332 s.
# info: Convergence criterion: |dx|=8.8319e+01, |x|=8.8319e+01, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.379658 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.288753 s.
# info: [time] Applying Dirichlet BCs took 0.0088807 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 5.771784e-21
#
# info: [time] Linear solver took 0.0108729 s.
# info: Convergence criterion: |dx|=3.1010e-14, |x|=8.8319e+01, |dx|/|x|=3.5111e-16
# info: [time] Iteration #2 took 0.308656 s.
# info: [time] Solving process #0 took 0.688667 s in time step #1
# info: [time] Time step #1 took 0.731881 s.
# info: Time step #2 started. Time: 4. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.286263 s.
# info: [time] Applying Dirichlet BCs took 0.0087839 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 9.362205e-21
#
# info: [time] Linear solver took 0.0365927 s.
# info: Convergence criterion: |dx|=1.5697e+01, |x|=1.0053e+02, |dx|/|x|=1.5614e-01
# info: [time] Iteration #1 took 0.331809 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303167 s.
# info: [time] Applying Dirichlet BCs took 0.0090689 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.792026e-21
#
# info: [time] Linear solver took 0.0110562 s.
# info: Convergence criterion: |dx|=5.6004e-14, |x|=1.0053e+02, |dx|/|x|=5.5709e-16
# info: [time] Iteration #2 took 0.323467 s.
# info: [time] Solving process #0 took 0.655629 s in time step #2
# info: [time] Time step #2 took 0.702296 s.
# info: [time] Output of timestep 2 took 0.321468 s.
# info: Time step #3 started. Time: 6. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.278524 s.
# info: [time] Applying Dirichlet BCs took 0.0086055 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 7.366522e-21
#
# info: [time] Linear solver took 0.0333419 s.
# info: Convergence criterion: |dx|=6.9080e+00, |x|=1.0544e+02, |dx|/|x|=6.5518e-02
# info: [time] Iteration #1 took 0.320655 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.298279 s.
# info: [time] Applying Dirichlet BCs took 0.0086399 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 5.688415e-21
#
# info: [time] Linear solver took 0.0114892 s.
# info: Convergence criterion: |dx|=4.2228e-14, |x|=1.0544e+02, |dx|/|x|=4.0050e-16
# info: [time] Iteration #2 took 0.31856 s.
# info: [time] Solving process #0 took 0.63971 s in time step #3
# info: [time] Time step #3 took 0.687342 s.
# info: Time step #4 started. Time: 8. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.272614 s.
# info: [time] Applying Dirichlet BCs took 0.0104627 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 9.083332e-21
#
# info: [time] Linear solver took 0.0331615 s.
# info: Convergence criterion: |dx|=4.1043e+00, |x|=1.0823e+02, |dx|/|x|=3.7921e-02
# info: [time] Iteration #1 took 0.3164 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.313603 s.
# info: [time] Applying Dirichlet BCs took 0.0101544 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 8.813777e-21
#
# info: [time] Linear solver took 0.0129459 s.
# info: Convergence criterion: |dx|=4.3205e-14, |x|=1.0823e+02, |dx|/|x|=3.9918e-16
# info: [time] Iteration #2 took 0.336859 s.
# info: [time] Solving process #0 took 0.653594 s in time step #4
# info: [time] Time step #4 took 0.706378 s.
# info: [time] Output of timestep 4 took 0.34009 s.
# info: Time step #5 started. Time: 10. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.28305 s.
# info: [time] Applying Dirichlet BCs took 0.0082829 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 9.845156e-21
#
# info: [time] Linear solver took 0.0332978 s.
# info: Convergence criterion: |dx|=2.8135e+00, |x|=1.1010e+02, |dx|/|x|=2.5553e-02
# info: [time] Iteration #1 took 0.324801 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.30578 s.
# info: [time] Applying Dirichlet BCs took 0.0091968 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.837109e-21
#
# info: [time] Linear solver took 0.011628 s.
# info: Convergence criterion: |dx|=4.4446e-14, |x|=1.1010e+02, |dx|/|x|=4.0367e-16
# info: [time] Iteration #2 took 0.326781 s.
# info: [time] Solving process #0 took 0.651955 s in time step #5
# info: [time] Time step #5 took 0.698736 s.
# info: Time step #6 started. Time: 12. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.279822 s.
# info: [time] Applying Dirichlet BCs took 0.0102571 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 8.947028e-21
#
# info: [time] Linear solver took 0.0346946 s.
# info: Convergence criterion: |dx|=2.0926e+00, |x|=1.1147e+02, |dx|/|x|=1.8772e-02
# info: [time] Iteration #1 took 0.324935 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.30351 s.
# info: [time] Applying Dirichlet BCs took 0.0107302 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 6.650268e-21
#
# info: [time] Linear solver took 0.0132239 s.
# info: Convergence criterion: |dx|=5.9879e-14, |x|=1.1147e+02, |dx|/|x|=5.3716e-16
# info: [time] Iteration #2 took 0.327614 s.
# info: [time] Solving process #0 took 0.652898 s in time step #6
# info: [time] Time step #6 took 0.724488 s.
# info: [time] Output of timestep 6 took 0.343595 s.
# info: Time step #7 started. Time: 14. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.286118 s.
# info: [time] Applying Dirichlet BCs took 0.0091094 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 73/10000
# info: 	 residual: 4.042853e-21
#
# info: [time] Linear solver took 0.0327409 s.
# info: Convergence criterion: |dx|=1.6401e+00, |x|=1.1253e+02, |dx|/|x|=1.4574e-02
# info: [time] Iteration #1 took 0.328134 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.31833 s.
# info: [time] Applying Dirichlet BCs took 0.0083948 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.966158e-21
#
# info: [time] Linear solver took 0.0110471 s.
# info: Convergence criterion: |dx|=4.4256e-14, |x|=1.1253e+02, |dx|/|x|=3.9327e-16
# info: [time] Iteration #2 took 0.337949 s.
# info: [time] Solving process #0 took 0.666401 s in time step #7
# info: [time] Time step #7 took 0.715735 s.
# info: Time step #8 started. Time: 16. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.310502 s.
# info: [time] Applying Dirichlet BCs took 0.0094772 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 73/10000
# info: 	 residual: 4.101590e-21
#
# info: [time] Linear solver took 0.0327235 s.
# info: Convergence criterion: |dx|=1.3331e+00, |x|=1.1339e+02, |dx|/|x|=1.1758e-02
# info: [time] Iteration #1 took 0.352856 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305423 s.
# info: [time] Applying Dirichlet BCs took 0.0100923 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 4.959427e-21
#
# info: [time] Linear solver took 0.0124514 s.
# info: Convergence criterion: |dx|=4.0586e-14, |x|=1.1339e+02, |dx|/|x|=3.5794e-16
# info: [time] Iteration #2 took 0.328131 s.
# info: [time] Solving process #0 took 0.681328 s in time step #8
# info: [time] Time step #8 took 0.731699 s.
# info: [time] Output of timestep 8 took 0.342647 s.
# info: Time step #9 started. Time: 18. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.288239 s.
# info: [time] Applying Dirichlet BCs took 0.0084758 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 9.855160e-21
#
# info: [time] Linear solver took 0.0345401 s.
# info: Convergence criterion: |dx|=1.1132e+00, |x|=1.1409e+02, |dx|/|x|=9.7570e-03
# info: [time] Iteration #1 took 0.331437 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.323313 s.
# info: [time] Applying Dirichlet BCs took 0.0095236 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 7.473692e-21
#
# info: [time] Linear solver took 0.0118277 s.
# info: Convergence criterion: |dx|=4.6572e-14, |x|=1.1409e+02, |dx|/|x|=4.0819e-16
# info: [time] Iteration #2 took 0.344813 s.
# info: [time] Solving process #0 took 0.676599 s in time step #9
# info: [time] Time step #9 took 0.726412 s.
# info: Time step #10 started. Time: 20. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.283493 s.
# info: [time] Applying Dirichlet BCs took 0.0083762 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 9.222905e-21
#
# info: [time] Linear solver took 0.0304382 s.
# info: Convergence criterion: |dx|=9.4898e-01, |x|=1.1469e+02, |dx|/|x|=8.2742e-03
# info: [time] Iteration #1 took 0.322464 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.293193 s.
# info: [time] Applying Dirichlet BCs took 0.0084894 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.566094e-21
#
# info: [time] Linear solver took 0.0111373 s.
# info: Convergence criterion: |dx|=3.8925e-14, |x|=1.1469e+02, |dx|/|x|=3.3939e-16
# info: [time] Iteration #2 took 0.312991 s.
# info: [time] Solving process #0 took 0.63579 s in time step #10
# info: [time] Time step #10 took 0.711919 s.
# info: [time] Output of timestep 10 took 0.3606 s.
# info: Time step #11 started. Time: 22. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.292572 s.
# info: [time] Applying Dirichlet BCs took 0.0084041 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 8.635467e-21
#
# info: [time] Linear solver took 0.038532 s.
# info: Convergence criterion: |dx|=8.2238e-01, |x|=1.1521e+02, |dx|/|x|=7.1383e-03
# info: [time] Iteration #1 took 0.339668 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.323612 s.
# info: [time] Applying Dirichlet BCs took 0.0088468 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.713250e-21
#
# info: [time] Linear solver took 0.0111854 s.
# info: Convergence criterion: |dx|=5.0897e-14, |x|=1.1521e+02, |dx|/|x|=4.4179e-16
# info: [time] Iteration #2 took 0.343814 s.
# info: [time] Solving process #0 took 0.683801 s in time step #11
# info: [time] Time step #11 took 0.728505 s.
# info: Time step #12 started. Time: 24. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.282493 s.
# info: [time] Applying Dirichlet BCs took 0.0102894 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 7.934397e-21
#
# info: [time] Linear solver took 0.0317189 s.
# info: Convergence criterion: |dx|=7.2226e-01, |x|=1.1566e+02, |dx|/|x|=6.2448e-03
# info: [time] Iteration #1 took 0.324669 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305543 s.
# info: [time] Applying Dirichlet BCs took 0.0109579 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 7.545750e-21
#
# info: [time] Linear solver took 0.0127005 s.
# info: Convergence criterion: |dx|=3.8647e-14, |x|=1.1566e+02, |dx|/|x|=3.3415e-16
# info: [time] Iteration #2 took 0.329412 s.
# info: [time] Solving process #0 took 0.654402 s in time step #12
# info: [time] Time step #12 took 0.70414 s.
# info: [time] Output of timestep 12 took 0.327248 s.
# info: Time step #13 started. Time: 26. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.26699 s.
# info: [time] Applying Dirichlet BCs took 0.0103222 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 7.361608e-21
#
# info: [time] Linear solver took 0.0342576 s.
# info: Convergence criterion: |dx|=6.4140e-01, |x|=1.1606e+02, |dx|/|x|=5.5267e-03
# info: [time] Iteration #1 took 0.311754 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301566 s.
# info: [time] Applying Dirichlet BCs took 0.0093986 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 5.831757e-21
#
# info: [time] Linear solver took 0.0117146 s.
# info: Convergence criterion: |dx|=5.9523e-14, |x|=1.1606e+02, |dx|/|x|=5.1289e-16
# info: [time] Iteration #2 took 0.322831 s.
# info: [time] Solving process #0 took 0.634975 s in time step #13
# info: [time] Time step #13 took 0.683676 s.
# info: Time step #14 started. Time: 28. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.274901 s.
# info: [time] Applying Dirichlet BCs took 0.0085335 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 6.915933e-21
#
# info: [time] Linear solver took 0.0313608 s.
# info: Convergence criterion: |dx|=5.7495e-01, |x|=1.1641e+02, |dx|/|x|=4.9390e-03
# info: [time] Iteration #1 took 0.314937 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.283446 s.
# info: [time] Applying Dirichlet BCs took 0.0092773 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.045350e-21
#
# info: [time] Linear solver took 0.0111209 s.
# info: Convergence criterion: |dx|=4.1495e-14, |x|=1.1641e+02, |dx|/|x|=3.5646e-16
# info: [time] Iteration #2 took 0.303995 s.
# info: [time] Solving process #0 took 0.61925 s in time step #14
# info: [time] Time step #14 took 0.668638 s.
# info: [time] Output of timestep 14 took 0.323445 s.
# info: Time step #15 started. Time: 30. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251414 s.
# info: [time] Applying Dirichlet BCs took 0.009982 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 6.442134e-21
#
# info: [time] Linear solver took 0.0350347 s.
# info: Convergence criterion: |dx|=5.1952e-01, |x|=1.1673e+02, |dx|/|x|=4.4506e-03
# info: [time] Iteration #1 took 0.296599 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.27986 s.
# info: [time] Applying Dirichlet BCs took 0.008565 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 5.139997e-21
#
# info: [time] Linear solver took 0.0113096 s.
# info: Convergence criterion: |dx|=3.8711e-14, |x|=1.1673e+02, |dx|/|x|=3.3163e-16
# info: [time] Iteration #2 took 0.299898 s.
# info: [time] Solving process #0 took 0.596827 s in time step #15
# info: [time] Time step #15 took 0.643582 s.
# info: Time step #16 started. Time: 32. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.273609 s.
# info: [time] Applying Dirichlet BCs took 0.0082482 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 5.736735e-21
#
# info: [time] Linear solver took 0.0302077 s.
# info: Convergence criterion: |dx|=4.7270e-01, |x|=1.1702e+02, |dx|/|x|=4.0395e-03
# info: [time] Iteration #1 took 0.312232 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.291088 s.
# info: [time] Applying Dirichlet BCs took 0.0132023 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 6.604081e-21
#
# info: [time] Linear solver took 0.0188525 s.
# info: Convergence criterion: |dx|=6.1446e-14, |x|=1.1702e+02, |dx|/|x|=5.2509e-16
# info: [time] Iteration #2 took 0.323541 s.
# info: [time] Solving process #0 took 0.636288 s in time step #16
# info: [time] Time step #16 took 0.690171 s.
# info: [time] Output of timestep 16 took 0.333017 s.
# info: Time step #17 started. Time: 34. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.311938 s.
# info: [time] Applying Dirichlet BCs took 0.0084717 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.822951e-21
#
# info: [time] Linear solver took 0.0303988 s.
# info: Convergence criterion: |dx|=4.3271e-01, |x|=1.1728e+02, |dx|/|x|=3.6894e-03
# info: [time] Iteration #1 took 0.350978 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.277009 s.
# info: [time] Applying Dirichlet BCs took 0.0081251 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.469816e-21
#
# info: [time] Linear solver took 0.0102633 s.
# info: Convergence criterion: |dx|=4.4155e-14, |x|=1.1728e+02, |dx|/|x|=3.7648e-16
# info: [time] Iteration #2 took 0.295542 s.
# info: [time] Solving process #0 took 0.646888 s in time step #17
# info: [time] Time step #17 took 0.691382 s.
# info: Time step #18 started. Time: 36. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.339636 s.
# info: [time] Applying Dirichlet BCs took 0.0106445 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 71/10000
# info: 	 residual: 9.333816e-21
#
# info: [time] Linear solver took 0.0350685 s.
# info: Convergence criterion: |dx|=3.9822e-01, |x|=1.1753e+02, |dx|/|x|=3.3884e-03
# info: [time] Iteration #1 took 0.385513 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.295281 s.
# info: [time] Applying Dirichlet BCs took 0.0092828 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 8.591336e-21
#
# info: [time] Linear solver took 0.0107754 s.
# info: Convergence criterion: |dx|=4.4262e-14, |x|=1.1753e+02, |dx|/|x|=3.7661e-16
# info: [time] Iteration #2 took 0.315494 s.
# info: [time] Solving process #0 took 0.701347 s in time step #18
# info: [time] Time step #18 took 0.745807 s.
# info: [time] Output of timestep 18 took 0.362949 s.
# info: Time step #19 started. Time: 38. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.330715 s.
# info: [time] Applying Dirichlet BCs took 0.0129869 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 72/10000
# info: 	 residual: 4.873662e-21
#
# info: [time] Linear solver took 0.0339422 s.
# info: Convergence criterion: |dx|=3.6822e-01, |x|=1.1775e+02, |dx|/|x|=3.1272e-03
# info: [time] Iteration #1 took 0.37782 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.326367 s.
# info: [time] Applying Dirichlet BCs took 0.0121463 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 5.313843e-21
#
# info: [time] Linear solver took 0.0133571 s.
# info: Convergence criterion: |dx|=5.8626e-14, |x|=1.1775e+02, |dx|/|x|=4.9789e-16
# info: [time] Iteration #2 took 0.35202 s.
# info: [time] Solving process #0 took 0.73022 s in time step #19
# info: [time] Time step #19 took 0.778039 s.
# info: Time step #20 started. Time: 40. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.307384 s.
# info: [time] Applying Dirichlet BCs took 0.0094344 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 71/10000
# info: 	 residual: 9.118150e-21
#
# info: [time] Linear solver took 0.0328666 s.
# info: Convergence criterion: |dx|=3.4193e-01, |x|=1.1796e+02, |dx|/|x|=2.8988e-03
# info: [time] Iteration #1 took 0.349868 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.33002 s.
# info: [time] Applying Dirichlet BCs took 0.0103471 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.031297e-21
#
# info: [time] Linear solver took 0.0119673 s.
# info: Convergence criterion: |dx|=4.9048e-14, |x|=1.1796e+02, |dx|/|x|=4.1581e-16
# info: [time] Iteration #2 took 0.352501 s.
# info: [time] Solving process #0 took 0.702693 s in time step #20
# info: [time] Time step #20 took 0.752317 s.
# info: [time] Output of timestep 20 took 0.398973 s.
# info: Time step #21 started. Time: 42. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.324946 s.
# info: [time] Applying Dirichlet BCs took 0.0080628 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.553063e-21
#
# info: [time] Linear solver took 0.0284675 s.
# info: Convergence criterion: |dx|=3.1872e-01, |x|=1.1815e+02, |dx|/|x|=2.6977e-03
# info: [time] Iteration #1 took 0.361643 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.273314 s.
# info: [time] Applying Dirichlet BCs took 0.0077684 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 8.417666e-21
#
# info: [time] Linear solver took 0.0106477 s.
# info: Convergence criterion: |dx|=7.5360e-14, |x|=1.1815e+02, |dx|/|x|=6.3784e-16
# info: [time] Iteration #2 took 0.291886 s.
# info: [time] Solving process #0 took 0.653773 s in time step #21
# info: [time] Time step #21 took 0.700167 s.
# info: Time step #22 started. Time: 44. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.28363 s.
# info: [time] Applying Dirichlet BCs took 0.0076051 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 6.302746e-21
#
# info: [time] Linear solver took 0.0290542 s.
# info: Convergence criterion: |dx|=2.9812e-01, |x|=1.1833e+02, |dx|/|x|=2.5195e-03
# info: [time] Iteration #1 took 0.320439 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.289055 s.
# info: [time] Applying Dirichlet BCs took 0.0081514 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 8.626920e-21
#
# info: [time] Linear solver took 0.011194 s.
# info: Convergence criterion: |dx|=5.0870e-14, |x|=1.1833e+02, |dx|/|x|=4.2991e-16
# info: [time] Iteration #2 took 0.308558 s.
# info: [time] Solving process #0 took 0.62927 s in time step #22
# info: [time] Time step #22 took 0.678332 s.
# info: [time] Output of timestep 22 took 0.324073 s.
# info: Time step #23 started. Time: 46. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291728 s.
# info: [time] Applying Dirichlet BCs took 0.0084759 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 6.537236e-21
#
# info: [time] Linear solver took 0.0331792 s.
# info: Convergence criterion: |dx|=2.7972e-01, |x|=1.1849e+02, |dx|/|x|=2.3606e-03
# info: [time] Iteration #1 took 0.333541 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.297446 s.
# info: [time] Applying Dirichlet BCs took 0.0102159 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.624569e-21
#
# info: [time] Linear solver took 0.0124359 s.
# info: Convergence criterion: |dx|=4.4478e-14, |x|=1.1849e+02, |dx|/|x|=3.7536e-16
# info: [time] Iteration #2 took 0.320252 s.
# info: [time] Solving process #0 took 0.654079 s in time step #23
# info: [time] Time step #23 took 0.702704 s.
# info: Time step #24 started. Time: 48. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.322946 s.
# info: [time] Applying Dirichlet BCs took 0.008336 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 7.194173e-21
#
# info: [time] Linear solver took 0.0304422 s.
# info: Convergence criterion: |dx|=2.6322e-01, |x|=1.1865e+02, |dx|/|x|=2.2184e-03
# info: [time] Iteration #1 took 0.361887 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.33834 s.
# info: [time] Applying Dirichlet BCs took 0.0080308 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.391375e-21
#
# info: [time] Linear solver took 0.0110452 s.
# info: Convergence criterion: |dx|=4.7479e-14, |x|=1.1865e+02, |dx|/|x|=4.0015e-16
# info: [time] Iteration #2 took 0.357579 s.
# info: [time] Solving process #0 took 0.719732 s in time step #24
# info: [time] Time step #24 took 0.768928 s.
# info: [time] Output of timestep 24 took 0.334113 s.
# info: Time step #25 started. Time: 50. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.243355 s.
# info: [time] Applying Dirichlet BCs took 0.0076626 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 71/10000
# info: 	 residual: 6.761593e-21
#
# info: [time] Linear solver took 0.031794 s.
# info: Convergence criterion: |dx|=2.4833e-01, |x|=1.1880e+02, |dx|/|x|=2.0904e-03
# info: [time] Iteration #1 took 0.282982 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.275809 s.
# info: [time] Applying Dirichlet BCs took 0.00784 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 9.461265e-21
#
# info: [time] Linear solver took 0.0109182 s.
# info: Convergence criterion: |dx|=5.4260e-14, |x|=1.1880e+02, |dx|/|x|=4.5673e-16
# info: [time] Iteration #2 took 0.294737 s.
# info: [time] Solving process #0 took 0.577978 s in time step #25
# info: [time] Time step #25 took 0.624421 s.
# info: Time step #26 started. Time: 52. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.277551 s.
# info: [time] Applying Dirichlet BCs took 0.0097629 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 4.759484e-21
#
# info: [time] Linear solver took 0.0366422 s.
# info: Convergence criterion: |dx|=2.3486e-01, |x|=1.1894e+02, |dx|/|x|=1.9746e-03
# info: [time] Iteration #1 took 0.324111 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.312534 s.
# info: [time] Applying Dirichlet BCs took 0.0103119 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 8.410735e-21
#
# info: [time] Linear solver took 0.0110493 s.
# info: Convergence criterion: |dx|=4.8018e-14, |x|=1.1894e+02, |dx|/|x|=4.0372e-16
# info: [time] Iteration #2 took 0.334094 s.
# info: [time] Solving process #0 took 0.65857 s in time step #26
# info: [time] Time step #26 took 0.707894 s.
# info: [time] Output of timestep 26 took 0.323201 s.
# info: Time step #27 started. Time: 54. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.288592 s.
# info: [time] Applying Dirichlet BCs took 0.0101163 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 4.740727e-21
#
# info: [time] Linear solver took 0.0335427 s.
# info: Convergence criterion: |dx|=2.2261e-01, |x|=1.1907e+02, |dx|/|x|=1.8696e-03
# info: [time] Iteration #1 took 0.332423 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.291792 s.
# info: [time] Applying Dirichlet BCs took 0.0091 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.414818e-21
#
# info: [time] Linear solver took 0.0104025 s.
# info: Convergence criterion: |dx|=4.7088e-14, |x|=1.1907e+02, |dx|/|x|=3.9546e-16
# info: [time] Iteration #2 took 0.311451 s.
# info: [time] Solving process #0 took 0.644263 s in time step #27
# info: [time] Time step #27 took 0.688056 s.
# info: Time step #28 started. Time: 56. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.285734 s.
# info: [time] Applying Dirichlet BCs took 0.0077345 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 67/10000
# info: 	 residual: 9.680091e-21
#
# info: [time] Linear solver took 0.0277756 s.
# info: Convergence criterion: |dx|=2.1144e-01, |x|=1.1920e+02, |dx|/|x|=1.7739e-03
# info: [time] Iteration #1 took 0.321406 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.276098 s.
# info: [time] Applying Dirichlet BCs took 0.0078468 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 8.187260e-21
#
# info: [time] Linear solver took 0.0111367 s.
# info: Convergence criterion: |dx|=4.8237e-14, |x|=1.1920e+02, |dx|/|x|=4.0468e-16
# info: [time] Iteration #2 took 0.295244 s.
# info: [time] Solving process #0 took 0.616959 s in time step #28
# info: [time] Time step #28 took 0.667463 s.
# info: [time] Output of timestep 28 took 0.318918 s.
# info: Time step #29 started. Time: 58. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.243217 s.
# info: [time] Applying Dirichlet BCs took 0.0124754 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 67/10000
# info: 	 residual: 8.917139e-21
#
# info: [time] Linear solver took 0.0360832 s.
# info: Convergence criterion: |dx|=2.0121e-01, |x|=1.1932e+02, |dx|/|x|=1.6864e-03
# info: [time] Iteration #1 took 0.291982 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307314 s.
# info: [time] Applying Dirichlet BCs took 0.0104734 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.785532e-21
#
# info: [time] Linear solver took 0.0115667 s.
# info: Convergence criterion: |dx|=3.9842e-14, |x|=1.1932e+02, |dx|/|x|=3.3392e-16
# info: [time] Iteration #2 took 0.329524 s.
# info: [time] Solving process #0 took 0.621859 s in time step #29
# info: [time] Time step #29 took 0.668961 s.
# info: Time step #30 started. Time: 60. Step size: 2.
# ...
# info: 	 iteration: 66/10000
# info: 	 residual: 9.007941e-21
#
# info: [time] Linear solver took 0.0352454 s.
# info: Convergence criterion: |dx|=1.2408e-01, |x|=1.2040e+02, |dx|/|x|=1.0306e-03
# info: [time] Iteration #1 took 0.358225 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.383454 s.
# info: [time] Applying Dirichlet BCs took 0.0104989 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 9.608816e-21
#
# info: [time] Linear solver took 0.011734 s.
# info: Convergence criterion: |dx|=4.5025e-14, |x|=1.2040e+02, |dx|/|x|=3.7397e-16
# info: [time] Iteration #2 took 0.405844 s.
# info: [time] Solving process #0 took 0.764603 s in time step #41
# info: [time] Time step #41 took 0.81534 s.
# info: Time step #42 started. Time: 84. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.346356 s.
# info: [time] Applying Dirichlet BCs took 0.0108931 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 8.515820e-21
#
# info: [time] Linear solver took 0.0350807 s.
# info: Convergence criterion: |dx|=1.2003e-01, |x|=1.2047e+02, |dx|/|x|=9.9636e-04
# info: [time] Iteration #1 took 0.392498 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.388634 s.
# info: [time] Applying Dirichlet BCs took 0.0094472 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.101322e-21
#
# info: [time] Linear solver took 0.01266 s.
# info: Convergence criterion: |dx|=4.1932e-14, |x|=1.2047e+02, |dx|/|x|=3.4808e-16
# info: [time] Iteration #2 took 0.410926 s.
# info: [time] Solving process #0 took 0.803871 s in time step #42
# info: [time] Time step #42 took 0.853577 s.
# info: [time] Output of timestep 42 took 0.383332 s.
# info: Time step #43 started. Time: 86. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291453 s.
# info: [time] Applying Dirichlet BCs took 0.0081863 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 8.123414e-21
#
# info: [time] Linear solver took 0.0296007 s.
# info: Convergence criterion: |dx|=1.1620e-01, |x|=1.2053e+02, |dx|/|x|=9.6405e-04
# info: [time] Iteration #1 took 0.329413 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.290631 s.
# info: [time] Applying Dirichlet BCs took 0.0081354 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 7.881934e-21
#
# info: [time] Linear solver took 0.0127279 s.
# info: Convergence criterion: |dx|=3.9158e-14, |x|=1.2053e+02, |dx|/|x|=3.2487e-16
# info: [time] Iteration #2 took 0.31184 s.
# info: [time] Solving process #0 took 0.641594 s in time step #43
# info: [time] Time step #43 took 0.69298 s.
# info: Time step #44 started. Time: 88. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.307625 s.
# info: [time] Applying Dirichlet BCs took 0.0085345 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 7.857859e-21
#
# info: [time] Linear solver took 0.0300519 s.
# info: Convergence criterion: |dx|=1.1258e-01, |x|=1.2060e+02, |dx|/|x|=9.3354e-04
# info: [time] Iteration #1 took 0.346366 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.292748 s.
# info: [time] Applying Dirichlet BCs took 0.0089698 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 8.583221e-21
#
# info: [time] Linear solver took 0.0110383 s.
# info: Convergence criterion: |dx|=4.8814e-14, |x|=1.2060e+02, |dx|/|x|=4.0477e-16
# info: [time] Iteration #2 took 0.312912 s.
# info: [time] Solving process #0 took 0.659644 s in time step #44
# info: [time] Time step #44 took 0.707564 s.
# info: [time] Output of timestep 44 took 0.356322 s.
# info: Time step #45 started. Time: 90. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.300171 s.
# info: [time] Applying Dirichlet BCs took 0.007787 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 7.473305e-21
#
# info: [time] Linear solver took 0.0304645 s.
# info: Convergence criterion: |dx|=1.0916e-01, |x|=1.2066e+02, |dx|/|x|=9.0470e-04
# info: [time] Iteration #1 took 0.338589 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.296036 s.
# info: [time] Applying Dirichlet BCs took 0.0101352 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 5.278296e-21
#
# info: [time] Linear solver took 0.0117431 s.
# info: Convergence criterion: |dx|=4.7604e-14, |x|=1.2066e+02, |dx|/|x|=3.9453e-16
# info: [time] Iteration #2 took 0.3181 s.
# info: [time] Solving process #0 took 0.657673 s in time step #45
# info: [time] Time step #45 took 0.703811 s.
# info: Time step #46 started. Time: 92. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.270763 s.
# info: [time] Applying Dirichlet BCs took 0.0075082 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 7.150582e-21
#
# info: [time] Linear solver took 0.0288324 s.
# info: Convergence criterion: |dx|=1.0592e-01, |x|=1.2072e+02, |dx|/|x|=8.7740e-04
# info: [time] Iteration #1 took 0.307256 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.306703 s.
# info: [time] Applying Dirichlet BCs took 0.0092479 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 5.664134e-21
#
# info: [time] Linear solver took 0.0123207 s.
# info: Convergence criterion: |dx|=3.6617e-14, |x|=1.2072e+02, |dx|/|x|=3.0332e-16
# info: [time] Iteration #2 took 0.328427 s.
# info: [time] Solving process #0 took 0.636041 s in time step #46
# info: [time] Time step #46 took 0.687589 s.
# info: [time] Output of timestep 46 took 0.318383 s.
# info: Time step #47 started. Time: 94. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.270596 s.
# info: [time] Applying Dirichlet BCs took 0.0096555 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 6.886102e-21
#
# info: [time] Linear solver took 0.0306808 s.
# info: Convergence criterion: |dx|=1.0285e-01, |x|=1.2078e+02, |dx|/|x|=8.5152e-04
# info: [time] Iteration #1 took 0.311103 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.295747 s.
# info: [time] Applying Dirichlet BCs took 0.0094646 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 23/10000
# info: 	 residual: 6.860181e-21
#
# info: [time] Linear solver took 0.0112652 s.
# info: Convergence criterion: |dx|=5.6324e-14, |x|=1.2078e+02, |dx|/|x|=4.6634e-16
# info: [time] Iteration #2 took 0.316632 s.
# info: [time] Solving process #0 took 0.628197 s in time step #47
# info: [time] Time step #47 took 0.675992 s.
# info: Time step #48 started. Time: 96. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.272236 s.
# info: [time] Applying Dirichlet BCs took 0.0076623 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 6.594722e-21
#
# info: [time] Linear solver took 0.0292946 s.
# info: Convergence criterion: |dx|=9.9928e-02, |x|=1.2084e+02, |dx|/|x|=8.2696e-04
# info: [time] Iteration #1 took 0.309346 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.296197 s.
# info: [time] Applying Dirichlet BCs took 0.0076432 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 22/10000
# info: 	 residual: 9.890975e-21
#
# info: [time] Linear solver took 0.0103091 s.
# info: Convergence criterion: |dx|=4.2552e-14, |x|=1.2084e+02, |dx|/|x|=3.5214e-16
# info: [time] Iteration #2 took 0.314324 s.
# info: [time] Solving process #0 took 0.624183 s in time step #48
# info: [time] Time step #48 took 0.673743 s.
# info: [time] Output of timestep 48 took 0.318097 s.
# info: Time step #49 started. Time: 98. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.281795 s.
# info: [time] Applying Dirichlet BCs took 0.007808 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 6.432027e-21
#
# info: [time] Linear solver took 0.0302427 s.
# info: Convergence criterion: |dx|=9.7153e-02, |x|=1.2089e+02, |dx|/|x|=8.0363e-04
# info: [time] Iteration #1 took 0.32001 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.291414 s.
# info: [time] Applying Dirichlet BCs took 0.0080352 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 21/10000
# info: 	 residual: 9.059348e-21
#
# info: [time] Linear solver took 0.0108272 s.
# info: Convergence criterion: |dx|=4.2181e-14, |x|=1.2089e+02, |dx|/|x|=3.4891e-16
# info: [time] Iteration #2 took 0.31043 s.
# info: [time] Solving process #0 took 0.63081 s in time step #49
# info: [time] Time step #49 took 0.681928 s.
# info: Time step #50 started. Time: 100. Step size: 2.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.293812 s.
# info: [time] Applying Dirichlet BCs took 0.0078092 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 66/10000
# info: 	 residual: 6.183775e-21
#
# info: [time] Linear solver took 0.0289518 s.
# info: Convergence criterion: |dx|=9.4513e-02, |x|=1.2095e+02, |dx|/|x|=7.8144e-04
# info: [time] Iteration #1 took 0.330725 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.286235 s.
# info: [time] Applying Dirichlet BCs took 0.0079633 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 21/10000
# info: 	 residual: 6.994230e-21
#
# info: [time] Linear solver took 0.0102492 s.
# info: Convergence criterion: |dx|=3.7350e-14, |x|=1.2095e+02, |dx|/|x|=3.0881e-16
# info: [time] Iteration #2 took 0.304604 s.
# info: [time] Solving process #0 took 0.635692 s in time step #50
# info: [time] Time step #50 took 0.694302 s.
# info: [time] Output of timestep 50 took 0.346066 s.
# info: The whole computation of the time stepping took 50 steps, in which
# 	 the accepted steps are 50, and the rejected steps are 0.
#
# info: [time] Execution took 44.4535 s.
# info: OGS terminated on 2026-03-04 16:46:01+0100.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path = Path("_out/liquid_ps3d_test.pvd")
ms = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="Pa")

# %%
y=25
z=-100

#coords=np.array(np.geomspace([26,y,z],[50,y,z],6).round(2)) #extracting along x geometrically
coords=np.array(np.linspace([26,y,z],[50,y,z],6)) #extracting along x linearly
coords[:,0]=rgeo+25 #adjusting geometry shifting
ms_probes = ms.extract_probe(ms,points=coords)

labels = [f"x={pt[0]:>5.1f}, y={y}, z={z}" for pt in coords]

diff = p_wsr - ms_probes['pressure']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 26/26 [00:01<00:00, 17.03it/s]

# %% [markdown]
# ### Performance comparison

# %%
fig, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,8], sharex=True)
ot.plot.line(ms_probes,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(t, p_wsr,color='tab:red', label=line_labels) 
axs[1].plot(t, diff, label=line_labels)

fig.suptitle("Point source analytical - Numerical OGS Nodal, 3D")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / Pa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

# plt.savefig("psn_3D_BM.pdf", format="pdf")  
plt.show()

# %% [markdown]
# # STIMTEC Example

# %% [markdown]
# ## Path adjoint

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out_ps"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Point-source step-rate

# %% [markdown]
# ### Preprocesing and preparing data

# %%
cwd=Path.cwd()
newpath=cwd/"STIMTEC_example"
dataex=pd.read_csv(newpath/"BH10_20180716_51.6.csv",sep=",",header=0)

# %%
#visualising full data set
fig1, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title("test: BH10_20180716_51.6")

ax.plot(dataex['Zeit [s]'],dataex['Pint_uphole [MPa]'],label="Pint_uphole [MPa]")
ax.plot(dataex['Zeit [s]'],dataex['Q_uphole [lpm]'],label="Q_uphole [lpm]")

plt.legend()
plt.show()

# %%
#isolating Step-rate and preparing curve

mask = (dataex['Zeit [s]'] > 2600) & (dataex['Zeit [s]'] < 4150)
dataex_f = dataex.loc[mask, :].copy()
dataex_f = dataex_f.reset_index(drop=True)

dataex_f['Q_uphole [lpm]_s']=scale_and_smooth(dataex_f['Q_uphole [lpm]'])

steps_=pickings(dataex_f['Q_uphole [lpm]_s'],60,20)
print('steps','\t', len(steps_))

fig1, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title("test: BH10_20180716_51.6, steps")

ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]'],label="P int d")
for i in range (len(steps_)):
     ax.axvline(x=dataex_f.loc[steps_[i,0],'Zeit [s]'],ls="--",color="tab:red")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_uphole [lpm]'],label="Q uphole")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_uphole [lpm]_s'],label="Q uphole_smoothed")

plt.legend()
plt.show()
# Out:
# steps 	 15

# %%
#protocol
pr=pd.DataFrame(data=steps_,
                      index = np.arange(len(steps_)),
                      columns=['index','qs'])
protocol={'index':0,'qs':dataex_f['Q_uphole [lpm]_s'].values[0],'T_s':dataex_f['Zeit [s]'].values[0]}
pr["T_s"]=dataex_f.loc[steps_[:,0].astype(int),'Zeit [s]'].values
protocol=pd.concat([pd.DataFrame(protocol,index=[0]),pr],axis=0)
protocol.reset_index(drop=True, inplace=True)
protocol['qs']=-protocol['qs']/60000 #injection is negative flow

# %%
#data 
ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":4e-6 ,
       "r_w":0.038 
      }

# %% [markdown]
# ### Point-source analytical running

# %%
delta_t=dataex_f['Zeit [s]'].values
tp=protocol['T_s'].values
q_array=protocol['qs'].values

r_val=ddict['r_w'] #at wellbore face
k_val = np.geomspace(2e-14, 5e-14, 5) #real wellbore

pwsr2= step_rate_s(pwd_ps, delta_t, tp, q_array, ddict, k_val, r_val)

# %%
fig2, ax=plt.subplots()

for i, k in enumerate(k_val):
    ax.plot(delta_t, pwsr2[:, i], label=f'k = {k:.2e} m²')
    
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title("test: BH10_20180716_51.6, k-values")

plt.legend()
plt.pause(1)

# %%
k_val=4.5e-14 #reference k

rgeo=np.geomspace(0.038,5,5)
r_val=rgeo
pwsr2= step_rate_s(pwd_ps, delta_t, tp, q_array, ddict, k_val, r_val)

rinv=np.sqrt(k_val*(max(dataex_f['Zeit [s]'])-min(dataex_f['Zeit [s]']))/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Investigation radius (m):  0.76
#  "unperturbed" threshold (m):  3.05

# %%
line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

fig3, ax=plt.subplots()

for i, r in enumerate(rgeo):
    plt.plot(delta_t, pwsr2[:, i], label=f'r = {r:.2f} m')
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title("test: BH10_20180716_51.6, r-values")

plt.legend()
plt.pause(1)

# %% [markdown]
# ## Point-source Numerical

# %% [markdown]
# ### Meshing 3D point-source

# %%
cube_file = MESH_DIR / "cube_3d_ps.msh"

create_cube_mesh_psc(
        cube_file,        
        width=400.0,
        height=400.0,
        thickness=400.0,
        mesh_size=20, #optimal one-size-to-mesh ratio= 20-40, ie, side(50)/mesh_size(2)=25
        target_rw=1, #minum possible in current setting 0.7
        center_z=-500.0,
        debug_gui= False,
        local_ref=True,
    )

cube_meshes = ot.meshes_from_gmsh(cube_file, log=False)
for name, mesh in cube_meshes.items():
    vtu = MESH_DIR / f"cube_{name}.vtu"
    pv.save_meshio(vtu, mesh)
    print(f"Saved {vtu}")
# Out:
# Saved _out_ps\mesh\cube_domain.vtu
# Saved _out_ps\mesh\cube_physical_group_points.vtu
# Saved _out_ps\mesh\cube_physical_group_center.vtu
# Saved _out_ps\mesh\cube_physical_group_edges.vtu
# Saved _out_ps\mesh\cube_physical_group_bottom.vtu
# Saved _out_ps\mesh\cube_physical_group_top.vtu
# Saved _out_ps\mesh\cube_physical_group_back.vtu
# Saved _out_ps\mesh\cube_physical_group_front.vtu
# Saved _out_ps\mesh\cube_physical_group_left.vtu
# Saved _out_ps\mesh\cube_physical_group_right.vtu
# Saved _out_ps\mesh\cube_physical_group_volume.vtu

# %% [markdown]
# ### PRJ file pre-procesing

# %%
#adjusting to
ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":4e-6 ,
       "r_w":0.038 
      }

# %%
rnode=0.7

# %%
#Permeability reference and pressure pi, pinf

k_ref=4.5e-14*ddict['r_w']/rnode
ddict['c_t']=ddict['c_t']*ddict['r_w']/rnode
p_inf=0
p0=0

# %%
PROJECT_BASENAME = "Point_source_3Dtest" 
TESTSR= "BH10_20180716_51.6"
prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR / f"{TESTSR}_PS3D.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
parent_xpath = "./processes/process[1]"
target_path = "./processes/process[1]/equation_balance_type"

try:
    root = prj.tree.getroot()
    node = root.find(target_path)
    
    if node is not None:
        if node.text == "volume":
            print("Verified: equation_balance_type 'volume' already exists.")
        else:
            prj.replace_text("volume", xpath=target_path)
            print("Updated: Existing equation_balance_type changed to 'volume'.")
    else:
        print("Adding equation_balance_type=volume")
        prj.add_element(
            parent_xpath=parent_xpath, 
            tag="equation_balance_type", 
            text="volume"
        )

except Exception as e:
    print(f"Error: {e}")
# Out:
# Adding equation_balance_type=volume

# %%
last_t=dataex_f.loc[dataex_f.tail(1).index.values.astype(int),'Zeit [s]':'Q_uphole [lpm]']
last_t['Q_uphole [lpm]']=last_t['Q_uphole [lpm]']/60000
last_t=last_t.values.flatten().tolist() 
print(last_t)

param_name = "q_in" #inlet flow

def create_sr_ogs(T,q,data,var="t"):
    q=-q
    q_list=q.tolist()
    q_list.append(data[1])
    
    T_list= T.tolist()
    T_list.append(data[0])
        
    parts = [f"{var} < {T_list[i+1]:g} ? {q_list[i]:.6g} :" for i in range(0, len(T_list)-1)]
    
    return "(" + "\n           ".join(parts) + f"\n           {q_list[-1]:.6g})",T_list


try:
    prj.replace_parameter_value(name="p0", value=p0)
    prj.replace_parameter_value(name="pi_inf", value=p_inf)
    
    root = prj.tree.getroot() # Access the underlying ElementTree
    param_node = root.find(f".//parameters/parameter[name='{param_name}']")
    value_tag = param_node.find("value")
    if value_tag is not None:
         param_node.remove(value_tag)
    
    n_type = prj.replace_text(
        "Function", xpath=f".//parameters/parameter[name='{param_name}']/type"
    )
    
    n_expr,Times = create_sr_ogs(tp,q_array,last_t)
    
    prj.add_element(
        parent_xpath=f".//parameters/parameter[name='{param_name}']", 
        tag="expression", 
        text=n_expr
    )
    
    print("flow_expression", n_expr)
    
    #timestepping calculations 
    delta_res=5
    prj.replace_text(Times[0], 
                     xpath="./time_loop/processes/process/time_stepping/t_initial")
    prj.replace_text(Times[-1],
                     xpath="./time_loop/processes/process/time_stepping/t_end")
    prj.replace_text("1",
                     xpath="./time_loop/processes/process/time_stepping/timesteps/pair/repeat")
    prj.replace_text(delta_res, #resolution of stepping
        xpath="./time_loop/processes/process/time_stepping/timesteps/pair/delta_t")
    
    print("delta_t calculation: ", delta_res)

    #out and suffix
    outsteps=delta_res #10 at convenience
    prefix= TESTSR
    
    prj.replace_text("1",
                     xpath="./time_loop/output/timesteps/pair/repeat")
    prj.replace_text(outsteps, #resolution of stepping
                    xpath="./time_loop/output/timesteps/pair/each_steps")
    prj.replace_text(prefix, #resolution of stepping
                     xpath="./time_loop/output/prefix")
    
    print("ouput_res: ", outsteps,'\n','prefix:',prefix )
    
    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value=ddict["c_t"])
    
    print("media/properties, Parameters updated")
    
except Exception as e:
    
    print(f"Error occurred: {e}")

prj.write_input()
print('\n', f"prj update in {prj_in} as {prj_out}")
# Out:
# [4149.973, 5.675e-08]
# flow_expression (t < 2659.97 ? 2.2339e-08 :
#            t < 2689.27 ? 1.08984e-05 :
#            t < 2703.72 ? -5.02127e-09 :
#            t < 2800.72 ? 9.38908e-06 :
#            t < 2942.27 ? 1.90956e-05 :
#            t < 3081.27 ? 2.41941e-05 :
#            t < 3195.37 ? 3.27881e-05 :
#            t < 3308.12 ? 5.0799e-05 :
#            t < 3466.22 ? 6.72243e-05 :
#            t < 3575.17 ? 8.41117e-05 :
#            t < 3665.42 ? 0.000100544 :
#            t < 3741.02 ? 0.000118131 :
#            t < 3819.37 ? 0.000134109 :
#            t < 3906.42 ? 0.000151677 :
#            t < 3991.77 ? 0.000166767 :
#            t < 4149.97 ? 2.89914e-07 :
#            5.675e-08)
# delta_t calculation:  5
# ouput_res:  5
#  prefix: BH10_20180716_51.6
# media/properties, Parameters updated
#
#  prj update in Point_source_3Dtest.prj as _out_ps\BH10_20180716_51.6_PS3D.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs _out_ps\BH10_20180716_51.6_PS3D.prj -m ./_out_ps/mesh -o ./_out_ps/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-04 22:54:41+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out_ps\BH10_20180716_51.6_PS3D.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: pi_inf
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Initialize processes.
# info: Time step #0 started. Time: 2600.023. Step size: 0.
# info: [time] Output of timestep 0 took 0.306025 s.
# info: Time step #0 took 0.344803 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-04 22:54:43+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 2605.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.257566 s.
# info: [time] Applying Dirichlet BCs took 0.0075534 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 46/10000
# info: 	 residual: 8.884533e-21
#
# info: [time] Linear solver took 0.0215672 s.
# info: Convergence criterion: |dx|=9.2554e-01, |x|=9.2554e-01, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.28691 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.272722 s.
# info: [time] Applying Dirichlet BCs took 0.0069359 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 7.026152e-21
#
# info: [time] Linear solver took 0.0057774 s.
# info: Convergence criterion: |dx|=1.5238e-16, |x|=9.2554e-01, |dx|/|x|=1.6464e-16
# info: [time] Iteration #2 took 0.285603 s.
# info: [time] Solving process #0 took 0.572904 s in time step #1
# info: [time] Time step #1 took 0.622753 s.
# info: Time step #2 started. Time: 2610.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.26066 s.
# info: [time] Applying Dirichlet BCs took 0.006708 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 46/10000
# info: 	 residual: 4.441187e-21
#
# info: [time] Linear solver took 0.0221266 s.
# info: Convergence criterion: |dx|=9.2459e-01, |x|=1.8501e+00, |dx|/|x|=4.9974e-01
# info: [time] Iteration #1 took 0.289651 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301839 s.
# info: [time] Applying Dirichlet BCs took 0.0077651 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.381052e-21
#
# info: [time] Linear solver took 0.00642 s.
# info: Convergence criterion: |dx|=5.4175e-16, |x|=1.8501e+00, |dx|/|x|=2.9282e-16
# info: [time] Iteration #2 took 0.316194 s.
# info: [time] Solving process #0 took 0.606217 s in time step #2
# info: [time] Time step #2 took 0.658065 s.
# info: Time step #3 started. Time: 2615.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.272482 s.
# info: [time] Applying Dirichlet BCs took 0.0069473 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 9.158832e-21
#
# info: [time] Linear solver took 0.0200236 s.
# info: Convergence criterion: |dx|=9.2365e-01, |x|=2.7738e+00, |dx|/|x|=3.3299e-01
# info: [time] Iteration #1 took 0.299616 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.265016 s.
# info: [time] Applying Dirichlet BCs took 0.0064982 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 7.814192e-21
#
# info: [time] Linear solver took 0.0057004 s.
# info: Convergence criterion: |dx|=1.3850e-15, |x|=2.7738e+00, |dx|/|x|=4.9932e-16
# info: [time] Iteration #2 took 0.27737 s.
# info: [time] Solving process #0 took 0.577354 s in time step #3
# info: [time] Time step #3 took 0.623006 s.
# info: Time step #4 started. Time: 2620.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.26126 s.
# info: [time] Applying Dirichlet BCs took 0.0069842 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 6.867723e-21
#
# info: [time] Linear solver took 0.0210173 s.
# info: Convergence criterion: |dx|=9.2270e-01, |x|=3.6965e+00, |dx|/|x|=2.4962e-01
# info: [time] Iteration #1 took 0.289435 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.275873 s.
# info: [time] Applying Dirichlet BCs took 0.0072108 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.686264e-21
#
# info: [time] Linear solver took 0.0061235 s.
# info: Convergence criterion: |dx|=9.9978e-16, |x|=3.6965e+00, |dx|/|x|=2.7047e-16
# info: [time] Iteration #2 took 0.289371 s.
# info: [time] Solving process #0 took 0.579325 s in time step #4
# info: [time] Time step #4 took 0.628244 s.
# info: Time step #5 started. Time: 2625.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.266086 s.
# info: [time] Applying Dirichlet BCs took 0.0075317 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 5.493057e-21
#
# info: [time] Linear solver took 0.0197885 s.
# info: Convergence criterion: |dx|=9.2176e-01, |x|=4.6182e+00, |dx|/|x|=1.9959e-01
# info: [time] Iteration #1 took 0.293558 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.26361 s.
# info: [time] Applying Dirichlet BCs took 0.0079604 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 9.662526e-21
#
# info: [time] Linear solver took 0.0053919 s.
# info: Convergence criterion: |dx|=7.3312e-16, |x|=4.6182e+00, |dx|/|x|=1.5874e-16
# info: [time] Iteration #2 took 0.277177 s.
# info: [time] Solving process #0 took 0.571101 s in time step #5
# info: [time] Time step #5 took 0.622592 s.
# info: [time] Output of timestep 5 took 0.334874 s.
# info: Time step #6 started. Time: 2630.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.230143 s.
# info: [time] Applying Dirichlet BCs took 0.0068594 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 4.576612e-21
#
# info: [time] Linear solver took 0.0208825 s.
# info: Convergence criterion: |dx|=9.2081e-01, |x|=5.5391e+00, |dx|/|x|=1.6624e-01
# info: [time] Iteration #1 took 0.258086 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.270149 s.
# info: [time] Applying Dirichlet BCs took 0.0066656 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 9.426001e-21
#
# info: [time] Linear solver took 0.0049977 s.
# info: Convergence criterion: |dx|=7.1419e-16, |x|=5.5391e+00, |dx|/|x|=1.2894e-16
# info: [time] Iteration #2 took 0.281986 s.
# info: [time] Solving process #0 took 0.540429 s in time step #6
# info: [time] Time step #6 took 0.586111 s.
# info: Time step #7 started. Time: 2635.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.274539 s.
# info: [time] Applying Dirichlet BCs took 0.0081946 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 3.922008e-21
#
# info: [time] Linear solver took 0.0210064 s.
# info: Convergence criterion: |dx|=9.1987e-01, |x|=6.4589e+00, |dx|/|x|=1.4242e-01
# info: [time] Iteration #1 took 0.303899 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.280081 s.
# info: [time] Applying Dirichlet BCs took 0.0067597 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 7.600396e-21
#
# info: [time] Linear solver took 0.0056436 s.
# info: Convergence criterion: |dx|=1.1455e-15, |x|=6.4589e+00, |dx|/|x|=1.7735e-16
# info: [time] Iteration #2 took 0.292731 s.
# info: [time] Solving process #0 took 0.597062 s in time step #7
# info: [time] Time step #7 took 0.64829 s.
# info: Time step #8 started. Time: 2640.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.268355 s.
# info: [time] Applying Dirichlet BCs took 0.0068042 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 3.431054e-21
#
# info: [time] Linear solver took 0.0208922 s.
# info: Convergence criterion: |dx|=9.1893e-01, |x|=7.3779e+00, |dx|/|x|=1.2455e-01
# info: [time] Iteration #1 took 0.296228 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.272768 s.
# info: [time] Applying Dirichlet BCs took 0.0065587 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 8.502942e-21
#
# info: [time] Linear solver took 0.0056759 s.
# info: Convergence criterion: |dx|=2.8193e-15, |x|=7.3779e+00, |dx|/|x|=3.8213e-16
# info: [time] Iteration #2 took 0.285154 s.
# info: [time] Solving process #0 took 0.58173 s in time step #8
# info: [time] Time step #8 took 0.627464 s.
# info: Time step #9 started. Time: 2645.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.259553 s.
# info: [time] Applying Dirichlet BCs took 0.0071195 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 9.037130e-21
#
# info: [time] Linear solver took 0.0203751 s.
# info: Convergence criterion: |dx|=9.1799e-01, |x|=8.2958e+00, |dx|/|x|=1.1066e-01
# info: [time] Iteration #1 took 0.28722 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.270502 s.
# info: [time] Applying Dirichlet BCs took 0.0069376 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.031398e-21
#
# info: [time] Linear solver took 0.0055441 s.
# info: Convergence criterion: |dx|=1.3543e-15, |x|=8.2958e+00, |dx|/|x|=1.6325e-16
# info: [time] Iteration #2 took 0.283158 s.
# info: [time] Solving process #0 took 0.570895 s in time step #9
# info: [time] Time step #9 took 0.617456 s.
# info: Time step #10 started. Time: 2650.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.257555 s.
# info: [time] Applying Dirichlet BCs took 0.0064275 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 8.131558e-21
#
# info: [time] Linear solver took 0.0188297 s.
# info: Convergence criterion: |dx|=9.1705e-01, |x|=9.2129e+00, |dx|/|x|=9.9540e-02
# info: [time] Iteration #1 took 0.282976 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.252354 s.
# info: [time] Applying Dirichlet BCs took 0.0062254 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 7.207018e-21
#
# info: [time] Linear solver took 0.0048551 s.
# info: Convergence criterion: |dx|=2.2048e-15, |x|=9.2129e+00, |dx|/|x|=2.3932e-16
# info: [time] Iteration #2 took 0.263596 s.
# info: [time] Solving process #0 took 0.54692 s in time step #10
# info: [time] Time step #10 took 0.590678 s.
# info: [time] Output of timestep 10 took 0.274651 s.
# info: Time step #11 started. Time: 2655.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.188764 s.
# info: [time] Applying Dirichlet BCs took 0.0054164 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 7.390635e-21
#
# info: [time] Linear solver took 0.0152456 s.
# info: Convergence criterion: |dx|=9.1612e-01, |x|=1.0129e+01, |dx|/|x|=9.0445e-02
# info: [time] Iteration #1 took 0.209582 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.23056 s.
# info: [time] Applying Dirichlet BCs took 0.0056013 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 5.088978e-21
#
# info: [time] Linear solver took 0.0043754 s.
# info: Convergence criterion: |dx|=1.2510e-15, |x|=1.0129e+01, |dx|/|x|=1.2351e-16
# info: [time] Iteration #2 took 0.240678 s.
# info: [time] Solving process #0 took 0.450738 s in time step #11
# info: [time] Time step #11 took 0.489054 s.
# info: Time step #12 started. Time: 2660.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.219183 s.
# info: [time] Applying Dirichlet BCs took 0.0057679 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 46/10000
# info: 	 residual: 8.689354e-21
#
# info: [time] Linear solver took 0.0154899 s.
# info: Convergence criterion: |dx|=4.5153e+02, |x|=4.6166e+02, |dx|/|x|=9.7806e-01
# info: [time] Iteration #1 took 0.240586 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.230698 s.
# info: [time] Applying Dirichlet BCs took 0.005829 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 6.324624e-21
#
# info: [time] Linear solver took 0.004261 s.
# info: Convergence criterion: |dx|=1.8449e-13, |x|=4.6166e+02, |dx|/|x|=3.9963e-16
# info: [time] Iteration #2 took 0.240922 s.
# info: [time] Solving process #0 took 0.481802 s in time step #12
# info: [time] Time step #12 took 0.516903 s.
# info: Time step #13 started. Time: 2665.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.217125 s.
# info: [time] Applying Dirichlet BCs took 0.0057777 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 46/10000
# info: 	 residual: 4.391850e-21
#
# info: [time] Linear solver took 0.0159956 s.
# info: Convergence criterion: |dx|=4.5107e+02, |x|=9.1273e+02, |dx|/|x|=4.9420e-01
# info: [time] Iteration #1 took 0.239051 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.226109 s.
# info: [time] Applying Dirichlet BCs took 0.0057693 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 9.323088e-21
#
# info: [time] Linear solver took 0.0044643 s.
# info: Convergence criterion: |dx|=1.5629e-13, |x|=9.1273e+02, |dx|/|x|=1.7123e-16
# info: [time] Iteration #2 took 0.236488 s.
# info: [time] Solving process #0 took 0.47599 s in time step #13
# info: [time] Time step #13 took 0.514389 s.
# info: Time step #14 started. Time: 2670.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.231936 s.
# info: [time] Applying Dirichlet BCs took 0.0073842 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 9.090742e-21
#
# info: [time] Linear solver took 0.0161314 s.
# info: Convergence criterion: |dx|=4.5060e+02, |x|=1.3633e+03, |dx|/|x|=3.3052e-01
# info: [time] Iteration #1 took 0.2556 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.222577 s.
# info: [time] Applying Dirichlet BCs took 0.0055022 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.358479e-21
#
# info: [time] Linear solver took 0.004384 s.
# info: Convergence criterion: |dx|=3.0036e-13, |x|=1.3633e+03, |dx|/|x|=2.2032e-16
# info: [time] Iteration #2 took 0.232596 s.
# info: [time] Solving process #0 took 0.488537 s in time step #14
# info: [time] Time step #14 took 0.523155 s.
# info: Time step #15 started. Time: 2675.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.217103 s.
# info: [time] Applying Dirichlet BCs took 0.0055287 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 6.829351e-21
#
# info: [time] Linear solver took 0.0146156 s.
# info: Convergence criterion: |dx|=4.5014e+02, |x|=1.8135e+03, |dx|/|x|=2.4822e-01
# info: [time] Iteration #1 took 0.237385 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.21914 s.
# info: [time] Applying Dirichlet BCs took 0.0052905 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.701350e-21
#
# info: [time] Linear solver took 0.0041889 s.
# info: Convergence criterion: |dx|=5.0972e-13, |x|=1.8135e+03, |dx|/|x|=2.8107e-16
# info: [time] Iteration #2 took 0.228754 s.
# info: [time] Solving process #0 took 0.466401 s in time step #15
# info: [time] Time step #15 took 0.501162 s.
# info: [time] Output of timestep 15 took 0.258762 s.
# info: Time step #16 started. Time: 2680.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.187633 s.
# info: [time] Applying Dirichlet BCs took 0.0060369 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 5.468471e-21
#
# info: [time] Linear solver took 0.0163226 s.
# info: Convergence criterion: |dx|=4.4968e+02, |x|=2.2632e+03, |dx|/|x|=1.9870e-01
# info: [time] Iteration #1 took 0.210144 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.227995 s.
# info: [time] Applying Dirichlet BCs took 0.0056647 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.097668e-21
#
# info: [time] Linear solver took 0.0041887 s.
# info: Convergence criterion: |dx|=2.9820e-13, |x|=2.2632e+03, |dx|/|x|=1.3176e-16
# info: [time] Iteration #2 took 0.237992 s.
# info: [time] Solving process #0 took 0.448436 s in time step #16
# info: [time] Time step #16 took 0.486737 s.
# info: Time step #17 started. Time: 2685.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.225733 s.
# info: [time] Applying Dirichlet BCs took 0.0054857 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 4.559526e-21
#
# info: [time] Linear solver took 0.0146549 s.
# info: Convergence criterion: |dx|=4.4922e+02, |x|=2.7124e+03, |dx|/|x|=1.6562e-01
# info: [time] Iteration #1 took 0.246011 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.231873 s.
# info: [time] Applying Dirichlet BCs took 0.0055739 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.877082e-21
#
# info: [time] Linear solver took 0.0043108 s.
# info: Convergence criterion: |dx|=5.6787e-13, |x|=2.7124e+03, |dx|/|x|=2.0936e-16
# info: [time] Iteration #2 took 0.241915 s.
# info: [time] Solving process #0 took 0.488239 s in time step #17
# info: [time] Time step #17 took 0.528397 s.
# info: Time step #18 started. Time: 2690.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.225259 s.
# info: [time] Applying Dirichlet BCs took 0.0058688 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 9.248241e-21
#
# info: [time] Linear solver took 0.0137991 s.
# info: Convergence criterion: |dx|=3.3606e+00, |x|=2.7094e+03, |dx|/|x|=1.2404e-03
# info: [time] Iteration #1 took 0.245066 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.222241 s.
# info: [time] Applying Dirichlet BCs took 0.0053317 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 9.048338e-21
#
# info: [time] Linear solver took 0.0035701 s.
# info: Convergence criterion: |dx|=3.7454e-13, |x|=2.7094e+03, |dx|/|x|=1.3824e-16
# info: [time] Iteration #2 took 0.231264 s.
# info: [time] Solving process #0 took 0.47661 s in time step #18
# info: [time] Time step #18 took 0.511442 s.
# info: Time step #19 started. Time: 2695.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.212758 s.
# info: [time] Applying Dirichlet BCs took 0.0058211 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 9.248809e-21
#
# info: [time] Linear solver took 0.0138349 s.
# info: Convergence criterion: |dx|=3.3556e+00, |x|=2.7064e+03, |dx|/|x|=1.2399e-03
# info: [time] Iteration #1 took 0.23256 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.230723 s.
# info: [time] Applying Dirichlet BCs took 0.0060982 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.833401e-21
#
# info: [time] Linear solver took 0.004569 s.
# info: Convergence criterion: |dx|=5.6077e-13, |x|=2.7064e+03, |dx|/|x|=2.0720e-16
# info: [time] Iteration #2 took 0.241536 s.
# info: [time] Solving process #0 took 0.474532 s in time step #19
# info: [time] Time step #19 took 0.513167 s.
# info: Time step #20 started. Time: 2700.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.217507 s.
# info: [time] Applying Dirichlet BCs took 0.0065824 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 9.249381e-21
#
# info: [time] Linear solver took 0.0134702 s.
# info: Convergence criterion: |dx|=3.3505e+00, |x|=2.7034e+03, |dx|/|x|=1.2394e-03
# info: [time] Iteration #1 took 0.237723 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.2171 s.
# info: [time] Applying Dirichlet BCs took 0.0052404 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 5.845904e-21
#
# info: [time] Linear solver took 0.0039066 s.
# info: Convergence criterion: |dx|=4.1577e-13, |x|=2.7034e+03, |dx|/|x|=1.5379e-16
# info: [time] Iteration #2 took 0.226366 s.
# info: [time] Solving process #0 took 0.464374 s in time step #20
# info: [time] Time step #20 took 0.499356 s.
# info: [time] Output of timestep 20 took 0.260042 s.
# info: Time step #21 started. Time: 2705.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.184741 s.
# info: [time] Applying Dirichlet BCs took 0.0055077 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 45/10000
# info: 	 residual: 3.441402e-21
#
# info: [time] Linear solver took 0.0155521 s.
# info: Convergence criterion: |dx|=3.8624e+02, |x|=3.0897e+03, |dx|/|x|=1.2501e-01
# info: [time] Iteration #1 took 0.205972 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.228275 s.
# info: [time] Applying Dirichlet BCs took 0.0057872 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.292546e-21
#
# info: [time] Linear solver took 0.0044555 s.
# info: Convergence criterion: |dx|=5.9943e-13, |x|=3.0897e+03, |dx|/|x|=1.9401e-16
# info: [time] Iteration #2 took 0.238652 s.
# info: [time] Solving process #0 took 0.444956 s in time step #21
# info: [time] Time step #21 took 0.483585 s.
# info: Time step #22 started. Time: 2710.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.217465 s.
# info: [time] Applying Dirichlet BCs took 0.0055036 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 9.061358e-21
#
# info: [time] Linear solver took 0.014274 s.
# info: Convergence criterion: |dx|=3.8585e+02, |x|=3.4755e+03, |dx|/|x|=1.1102e-01
# info: [time] Iteration #1 took 0.237385 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.226049 s.
# info: [time] Applying Dirichlet BCs took 0.0059365 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 9.409229e-21
#
# info: [time] Linear solver took 0.0035963 s.
# info: Convergence criterion: |dx|=4.2791e-13, |x|=3.4755e+03, |dx|/|x|=1.2312e-16
# info: [time] Iteration #2 took 0.235705 s.
# info: [time] Solving process #0 took 0.4734 s in time step #22
# info: [time] Time step #22 took 0.508276 s.
# info: Time step #23 started. Time: 2715.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.211249 s.
# info: [time] Applying Dirichlet BCs took 0.0058196 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 8.151174e-21
#
# info: [time] Linear solver took 0.0153292 s.
# info: Convergence criterion: |dx|=3.8545e+02, |x|=3.8610e+03, |dx|/|x|=9.9833e-02
# info: [time] Iteration #1 took 0.232543 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.229178 s.
# info: [time] Applying Dirichlet BCs took 0.0063464 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 5.965428e-21
#
# info: [time] Linear solver took 0.0045531 s.
# info: Convergence criterion: |dx|=7.1582e-13, |x|=3.8610e+03, |dx|/|x|=1.8540e-16
# info: [time] Iteration #2 took 0.240222 s.
# info: [time] Solving process #0 took 0.473188 s in time step #23
# info: [time] Time step #23 took 0.511995 s.
# info: Time step #24 started. Time: 2720.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.218352 s.
# info: [time] Applying Dirichlet BCs took 0.0062127 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 7.406840e-21
#
# info: [time] Linear solver took 0.0148836 s.
# info: Convergence criterion: |dx|=3.8506e+02, |x|=4.2460e+03, |dx|/|x|=9.0687e-02
# info: [time] Iteration #1 took 0.239596 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.219019 s.
# info: [time] Applying Dirichlet BCs took 0.0053639 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 6.851951e-21
#
# info: [time] Linear solver took 0.0042081 s.
# info: Convergence criterion: |dx|=1.4706e-12, |x|=4.2460e+03, |dx|/|x|=3.4635e-16
# info: [time] Iteration #2 took 0.228726 s.
# info: [time] Solving process #0 took 0.468619 s in time step #24
# info: [time] Time step #24 took 0.503237 s.
# info: Time step #25 started. Time: 2725.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.212041 s.
# info: [time] Applying Dirichlet BCs took 0.0059831 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 6.786810e-21
#
# info: [time] Linear solver took 0.0152905 s.
# info: Convergence criterion: |dx|=3.8467e+02, |x|=4.6307e+03, |dx|/|x|=8.3069e-02
# info: [time] Iteration #1 took 0.233468 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.228429 s.
# info: [time] Applying Dirichlet BCs took 0.0061744 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 9.188017e-21
#
# info: [time] Linear solver took 0.0039014 s.
# info: Convergence criterion: |dx|=6.9669e-13, |x|=4.6307e+03, |dx|/|x|=1.5045e-16
# info: [time] Iteration #2 took 0.238655 s.
# info: [time] Solving process #0 took 0.47256 s in time step #25
# info: [time] Time step #25 took 0.510288 s.
# info: [time] Output of timestep 25 took 0.260571 s.
# info: Time step #26 started. Time: 2730.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.184573 s.
# info: [time] Applying Dirichlet BCs took 0.0055474 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 6.262345e-21
#
# info: [time] Linear solver took 0.0152806 s.
# info: Convergence criterion: |dx|=3.8427e+02, |x|=5.0150e+03, |dx|/|x|=7.6625e-02
# info: [time] Iteration #1 took 0.205566 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.227194 s.
# info: [time] Applying Dirichlet BCs took 0.0057395 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 9.690243e-21
#
# info: [time] Linear solver took 0.0042666 s.
# info: Convergence criterion: |dx|=1.2728e-12, |x|=5.0150e+03, |dx|/|x|=2.5379e-16
# info: [time] Iteration #2 took 0.237341 s.
# info: [time] Solving process #0 took 0.443344 s in time step #26
# info: [time] Time step #26 took 0.482639 s.
# info: Time step #27 started. Time: 2735.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.22068 s.
# info: [time] Applying Dirichlet BCs took 0.0054485 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 5.812931e-21
#
# info: [time] Linear solver took 0.0146243 s.
# info: Convergence criterion: |dx|=3.8388e+02, |x|=5.3988e+03, |dx|/|x|=7.1105e-02
# info: [time] Iteration #1 took 0.240906 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.225397 s.
# info: [time] Applying Dirichlet BCs took 0.0056584 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 5.198513e-21
#
# info: [time] Linear solver took 0.0040662 s.
# info: Convergence criterion: |dx|=6.6644e-13, |x|=5.3988e+03, |dx|/|x|=1.2344e-16
# info: [time] Iteration #2 took 0.23525 s.
# info: [time] Solving process #0 took 0.47647 s in time step #27
# info: [time] Time step #27 took 0.51221 s.
# info: Time step #28 started. Time: 2740.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.210707 s.
# info: [time] Applying Dirichlet BCs took 0.0056712 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 5.423535e-21
#
# info: [time] Linear solver took 0.015381 s.
# info: Convergence criterion: |dx|=3.8349e+02, |x|=5.7823e+03, |dx|/|x|=6.6321e-02
# info: [time] Iteration #1 took 0.231915 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.234261 s.
# info: [time] Applying Dirichlet BCs took 0.00606 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 4.955955e-21
#
# info: [time] Linear solver took 0.0044811 s.
# info: Convergence criterion: |dx|=1.2119e-12, |x|=5.7823e+03, |dx|/|x|=2.0958e-16
# info: [time] Iteration #2 took 0.244973 s.
# info: [time] Solving process #0 took 0.477295 s in time step #28
# info: [time] Time step #28 took 0.515859 s.
# info: Time step #29 started. Time: 2745.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.220153 s.
# info: [time] Applying Dirichlet BCs took 0.0056299 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 44/10000
# info: 	 residual: 5.082886e-21
#
# info: [time] Linear solver took 0.0144074 s.
# info: Convergence criterion: |dx|=3.8310e+02, |x|=6.1654e+03, |dx|/|x|=6.2137e-02
# info: [time] Iteration #1 took 0.240339 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.21845 s.
# info: [time] Applying Dirichlet BCs took 0.0053857 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 7.084388e-21
#
# info: [time] Linear solver took 0.0043003 s.
# info: Convergence criterion: |dx|=2.0280e-12, |x|=6.1654e+03, |dx|/|x|=3.2892e-16
# info: [time] Iteration #2 took 0.228271 s.
# info: [time] Solving process #0 took 0.468927 s in time step #29
# info: [time] Time step #29 took 0.50347 s.
# ...
# info: 	 iteration: 39/10000
# info: 	 residual: 7.642169e-21
#
# info: [time] Linear solver took 0.0134683 s.
# info: Convergence criterion: |dx|=7.6601e+02, |x|=6.9441e+05, |dx|/|x|=1.1031e-03
# info: [time] Iteration #1 took 0.19824 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.221537 s.
# info: [time] Applying Dirichlet BCs took 0.0060487 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.621549e-21
#
# info: [time] Linear solver took 0.0039582 s.
# info: Convergence criterion: |dx|=1.6228e-10, |x|=6.9441e+05, |dx|/|x|=2.3369e-16
# info: [time] Iteration #2 took 0.231673 s.
# info: [time] Solving process #0 took 0.430204 s in time step #301
# info: [time] Time step #301 took 0.464858 s.
# info: Time step #302 started. Time: 4110.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.209461 s.
# info: [time] Applying Dirichlet BCs took 0.005998 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.639940e-21
#
# info: [time] Linear solver took 0.0129456 s.
# info: Convergence criterion: |dx|=7.6488e+02, |x|=6.9375e+05, |dx|/|x|=1.1025e-03
# info: [time] Iteration #1 took 0.228541 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.220128 s.
# info: [time] Applying Dirichlet BCs took 0.0076315 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 6.213111e-21
#
# info: [time] Linear solver took 0.0043807 s.
# info: Convergence criterion: |dx|=8.4259e-11, |x|=6.9375e+05, |dx|/|x|=1.2145e-16
# info: [time] Iteration #2 took 0.232297 s.
# info: [time] Solving process #0 took 0.461154 s in time step #302
# info: [time] Time step #302 took 0.497723 s.
# info: Time step #303 started. Time: 4115.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.214559 s.
# info: [time] Applying Dirichlet BCs took 0.0060438 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.637713e-21
#
# info: [time] Linear solver took 0.0142818 s.
# info: Convergence criterion: |dx|=7.6374e+02, |x|=6.9309e+05, |dx|/|x|=1.1019e-03
# info: [time] Iteration #1 took 0.235043 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.228843 s.
# info: [time] Applying Dirichlet BCs took 0.0066419 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 8.506171e-21
#
# info: [time] Linear solver took 0.0039626 s.
# info: Convergence criterion: |dx|=8.4650e-11, |x|=6.9309e+05, |dx|/|x|=1.2213e-16
# info: [time] Iteration #2 took 0.239592 s.
# info: [time] Solving process #0 took 0.475046 s in time step #303
# info: [time] Time step #303 took 0.514035 s.
# info: Time step #304 started. Time: 4120.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.222889 s.
# info: [time] Applying Dirichlet BCs took 0.0060351 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.635489e-21
#
# info: [time] Linear solver took 0.0130969 s.
# info: Convergence criterion: |dx|=7.6261e+02, |x|=6.9243e+05, |dx|/|x|=1.1014e-03
# info: [time] Iteration #1 took 0.242167 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.228864 s.
# info: [time] Applying Dirichlet BCs took 0.0060469 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 7.959902e-21
#
# info: [time] Linear solver took 0.004413 s.
# info: Convergence criterion: |dx|=3.5722e-10, |x|=6.9243e+05, |dx|/|x|=5.1589e-16
# info: [time] Iteration #2 took 0.239454 s.
# info: [time] Solving process #0 took 0.481919 s in time step #304
# info: [time] Time step #304 took 0.516976 s.
# info: Time step #305 started. Time: 4125.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.223573 s.
# info: [time] Applying Dirichlet BCs took 0.0063668 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.633267e-21
#
# info: [time] Linear solver took 0.01403 s.
# info: Convergence criterion: |dx|=7.6148e+02, |x|=6.9177e+05, |dx|/|x|=1.1008e-03
# info: [time] Iteration #1 took 0.244116 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.24301 s.
# info: [time] Applying Dirichlet BCs took 0.0067845 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 9/10000
# info: 	 residual: 6.115046e-21
#
# info: [time] Linear solver took 0.0040645 s.
# info: Convergence criterion: |dx|=7.6582e-11, |x|=6.9177e+05, |dx|/|x|=1.1070e-16
# info: [time] Iteration #2 took 0.253999 s.
# info: [time] Solving process #0 took 0.498538 s in time step #305
# info: [time] Time step #305 took 0.536962 s.
# info: [time] Output of timestep 305 took 0.282832 s.
# info: Time step #306 started. Time: 4130.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.23741 s.
# info: [time] Applying Dirichlet BCs took 0.0057753 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.631048e-21
#
# info: [time] Linear solver took 0.0135108 s.
# info: Convergence criterion: |dx|=7.6036e+02, |x|=6.9112e+05, |dx|/|x|=1.1002e-03
# info: [time] Iteration #1 took 0.256845 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.230179 s.
# info: [time] Applying Dirichlet BCs took 0.0057363 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 7.981200e-21
#
# info: [time] Linear solver took 0.0041714 s.
# info: Convergence criterion: |dx|=1.5429e-10, |x|=6.9112e+05, |dx|/|x|=2.2325e-16
# info: [time] Iteration #2 took 0.24023 s.
# info: [time] Solving process #0 took 0.497405 s in time step #306
# info: [time] Time step #306 took 0.535685 s.
# info: Time step #307 started. Time: 4135.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.226646 s.
# info: [time] Applying Dirichlet BCs took 0.0055076 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.628831e-21
#
# info: [time] Linear solver took 0.0133889 s.
# info: Convergence criterion: |dx|=7.5923e+02, |x|=6.9046e+05, |dx|/|x|=1.0996e-03
# info: [time] Iteration #1 took 0.245688 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.283895 s.
# info: [time] Applying Dirichlet BCs took 0.0068173 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 7.041879e-21
#
# info: [time] Linear solver took 0.0045806 s.
# info: Convergence criterion: |dx|=1.4335e-10, |x|=6.9046e+05, |dx|/|x|=2.0762e-16
# info: [time] Iteration #2 took 0.295432 s.
# info: [time] Solving process #0 took 0.54135 s in time step #307
# info: [time] Time step #307 took 0.578569 s.
# info: Time step #308 started. Time: 4140.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.257878 s.
# info: [time] Applying Dirichlet BCs took 0.0057167 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.626617e-21
#
# info: [time] Linear solver took 0.0134926 s.
# info: Convergence criterion: |dx|=7.5811e+02, |x|=6.8981e+05, |dx|/|x|=1.0990e-03
# info: [time] Iteration #1 took 0.277234 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.258977 s.
# info: [time] Applying Dirichlet BCs took 0.0064414 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 8.885636e-21
#
# info: [time] Linear solver took 0.0044281 s.
# info: Convergence criterion: |dx|=3.6089e-10, |x|=6.8981e+05, |dx|/|x|=5.2317e-16
# info: [time] Iteration #2 took 0.269985 s.
# info: [time] Solving process #0 took 0.547541 s in time step #308
# info: [time] Time step #308 took 0.587695 s.
# info: Time step #309 started. Time: 4145.0230000000001. Step size: 5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.30823 s.
# info: [time] Applying Dirichlet BCs took 0.0077216 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 7.624405e-21
#
# info: [time] Linear solver took 0.014755 s.
# info: Convergence criterion: |dx|=7.5699e+02, |x|=6.8915e+05, |dx|/|x|=1.0984e-03
# info: [time] Iteration #1 took 0.330851 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301249 s.
# info: [time] Applying Dirichlet BCs took 0.0057674 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 10/10000
# info: 	 residual: 7.776468e-21
#
# info: [time] Linear solver took 0.0045011 s.
# info: Convergence criterion: |dx|=1.4140e-10, |x|=6.8915e+05, |dx|/|x|=2.0518e-16
# info: [time] Iteration #2 took 0.311652 s.
# info: [time] Solving process #0 took 0.642806 s in time step #309
# info: [time] Time step #309 took 0.681891 s.
# info: Time step #310 started. Time: 4149.973. Step size: 4.9499999999998181.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251883 s.
# info: [time] Applying Dirichlet BCs took 0.0057998 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 39/10000
# info: 	 residual: 6.793062e-21
#
# info: [time] Linear solver took 0.0135355 s.
# info: Convergence criterion: |dx|=7.5687e+02, |x|=6.8849e+05, |dx|/|x|=1.0993e-03
# info: [time] Iteration #1 took 0.271368 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.243172 s.
# info: [time] Applying Dirichlet BCs took 0.0055522 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 11/10000
# info: 	 residual: 7.440256e-21
#
# info: [time] Linear solver took 0.0042228 s.
# info: Convergence criterion: |dx|=1.4575e-10, |x|=6.8849e+05, |dx|/|x|=2.1170e-16
# info: [time] Iteration #2 took 0.253076 s.
# info: [time] Solving process #0 took 0.524789 s in time step #310
# info: [time] Time step #310 took 0.559812 s.
# info: [time] Output of timestep 310 took 0.264056 s.
# info: The whole computation of the time stepping took 310 steps, in which
# 	 the accepted steps are 310, and the rejected steps are 0.
#
# info: [time] Execution took 181.297 s.
# info: OGS terminated on 2026-03-04 22:57:44+0100.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path = Path("_out_ps/BH10_20180716_51.6.pvd")
ms = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="Pa")

# %%
y=200
z=-500

np.geomspace(0.038,5,5)

coords=np.array(np.linspace([200.038,y,z],[205,y,z],5)) #extracting along x linearly
coords[:,0]=rgeo+200 #adjusting geometry shifting
ms_probes = ms.extract_probe(ms,points=coords)

labels = [f"x={pt[0]:>5.1f}, y={y}, z={z}" for pt in coords]

# diff = pwsr2 - ms_probes['pressure']

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
t=dataex_f['Zeit [s]']

fig4, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,8], sharex=True)
ot.plot.line(ms_probes,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(t, pwsr2/10,color='tab:red', label=line_labels) 
# axs[1].plot(t, diffMpa, label=line_labels)

# fig4.suptitle("Point source analytical - Numerical OGS Nodal, 3D")
fig4.suptitle("Point source analytical scaled down 1/10 - Numerical OGS Nodal, 3D") 
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / Pa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_24668\1573124153.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()

# %% [markdown]
# **NOTE: Numerical difference is 10 times with current setting/configuration** Scaling should be done node/rw
