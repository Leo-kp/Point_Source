# %%
import os
import shutil
from pathlib import Path

import pyvista as pv
import ogstools as ot
import ogstools.variables as ov

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from meshing import create_cube_mesh_p
from functions import pwd_ps,step_rate_s, scale_and_smooth, pickings

# %% [markdown]
# # Path

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Point-source and model performance

# %% [markdown]
# ## Point-source analytical

# %%
k=5.35e-12
q=0.00016 #positive for production

ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.1,
       "c_t":4.37e-7 ,
       "r_w":0.05,
      }

def time_stepping_congruent(t_initial, t_final, n=50, bias_ratio=0.5): #produces OGS timestepping  congruently simultaneously
    t_split = t_final * 0.2
    n_start = max(2, int(n * bias_ratio))
    n_end = n - n_start + 1
    
    r1 = int(n_start - 1)
    r2 = int(n_end - 1)
    dt1 = (t_split - t_initial) / r1
    dt2 = (t_final - t_split) / r2
    
    t_segment1 = t_initial + np.arange(n_start) * dt1
    t_segment2 = t_split + np.arange(1, n_end) * dt2
    t_a = np.concatenate([t_segment1, t_segment2])
    
    t_a[-1] = t_final 
    return t_a, (r1, dt1), (r2, dt2)

t_initial=0
t_final=500
t_initial_offset = 1e-10 
t, ts1, ts2 = time_stepping_congruent(t_initial, t_final, 50)

rgeo=np.geomspace(1, 12.5, 6).round(2)

rinv=np.sqrt(k*max(t)/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Investigation radius (m):  7.82
#  "unperturbed" threshold (m):  31.30

# %%
#Point source
r_col=rgeo
pi, mu, B,rw= ddict['p_i'], ddict['mu'], ddict['B'],ddict['r_w']

C_vec = (mu * B) / (4 * np.pi * k * rw)
term1_matrix = pwd_ps(t, ddict, k, r_col) 

p_wsr = pi - (C_vec * q * term1_matrix)

# %%
line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

fig0, ax=plt.subplots()
ax.plot(t, p_wsr,label=line_labels) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title("Point source analytical")

plt.legend()
#plt.savefig("psa_3D_Ca.pdf", format="pdf") 
plt.pause(1)

# %% [markdown]
# ## Point-source numerical

# %% [markdown]
# ### Meshing 3D point-source

# %%
cube_file = MESH_DIR / "cube_3d_ps.msh"

create_cube_mesh_p(
    cube_file,
    width= 50,
    height= 50,
    thickness=50,
    mesh_size= 2, #optimal one-size-to-mesh ratio= 20-40, ie, side(50)/mesh_size(2)=25, ref 1
    target_rw= 0.05, # Added target_rw for explicit control
    center_z= -50,
    debug_gui= False,
    local_ref= True,
    ) 

cube_meshes = ot.meshes_from_gmsh(cube_file, log=False)
for name, mesh in cube_meshes.items():
    vtu = MESH_DIR / f"cube_{name}.vtu"
    pv.save_meshio(vtu, mesh)
    print(f"Saved {vtu}")
# Out:
# Saved _out\mesh\cube_domain.vtu
# Saved _out\mesh\cube_physical_group_points.vtu
# Saved _out\mesh\cube_physical_group_center.vtu
# Saved _out\mesh\cube_physical_group_edges.vtu
# Saved _out\mesh\cube_physical_group_bottom.vtu
# Saved _out\mesh\cube_physical_group_top.vtu
# Saved _out\mesh\cube_physical_group_back.vtu
# Saved _out\mesh\cube_physical_group_front.vtu
# Saved _out\mesh\cube_physical_group_left.vtu
# Saved _out\mesh\cube_physical_group_right.vtu
# Saved _out\mesh\cube_physical_group_volume.vtu

# %%
#slcaing meshing first round of tetrahedra
x=50
y=50
z=-50

point_idx = mesh.find_closest_point([x, y, z])
cell_ids = mesh.extract_points([point_idx])["vtkOriginalCellIds"]

refined_cells = mesh.extract_cells(cell_ids)
local_volume = refined_cells.volume

r_eq = (3 * local_volume / (4 * np.pi))**(1/3)
q_fact=(1/r_eq)**(2/3)

# %% [markdown]
# ### PRJ file pre-procesing

# %%
PROJECT_BASENAME = "Point_source_3Dtest" 
prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR / f"{PROJECT_BASENAME}_updated.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
#permeability ref numerical
k_ref= 5.35e-12
ct_ref= ddict["c_t"]*ddict['por']

# %%
parent_xpath = "./processes/process[1]"
target_path = "./processes/process[1]/equation_balance_type"

mode='volume'

def f_mode(mode:str):
    if mode=="volume":       
            prj.replace_text("volume", xpath=target_path)
    elif mode=="mass":       
            prj.replace_text("mass", xpath=target_path)
    else:
        print("Input just: mass or volume")

    print(f"Updated: Existing equation_balance_type changed to {mode}.")
    

try:
    root = prj.tree.getroot()
    node = root.find(target_path)
    
    if node is not None:
        if node.text == "volume":
            print("Verified: equation_balance_type 'volume' already exists.")
       
        elif node.text=="mass":
            print("Verified: equation_balance_type 'mass' already exists.")
        
        else:
            f_mode(mode)
    else:
        print(f"Adding equation_balance_type={mode}")
        prj.add_element(
            parent_xpath=parent_xpath, 
            tag="equation_balance_type", 
            text=mode
        )

except Exception as e:
    print(f"Error: {e}")
# Out:
# Adding equation_balance_type=volume

# %%
q_in=-1*q*q_fact #changing to proudction OGS, scaling the flow to 1st-ring-mesh
if mode=="mass":
    q_in=q_in*1000 #water density

try:
    prj.replace_parameter_value(name="p0", value=ddict["p_i"])
    prj.replace_parameter_value(name="pi_inf", value=ddict["p_i"])
    prj.replace_parameter_value(name="q_in", value=q_in)

    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value= ct_ref)

    print("media/properties, Parameters updated")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# media/properties, Parameters updated

# %%
#timestepping calculations 
try:
    prj.replace_text(t[0], 
                     xpath="./time_loop/processes/process/time_stepping/t_initial")
    prj.replace_text(t[-1],
                     xpath="./time_loop/processes/process/time_stepping/t_end")
    
    prj.replace_text(ts1[0],
                     xpath="./time_loop/processes/process/time_stepping/timesteps/pair/repeat")
    prj.replace_text(ts1[1], 
        xpath="./time_loop/processes/process/time_stepping/timesteps/pair/delta_t")

    prj.add_block( #new block to cover resolution
    blocktag="pair",
    parent_xpath="./time_loop/processes/process/time_stepping/timesteps",
    taglist=["repeat", "delta_t"],
    textlist=[ts2[0], ts2[1]]  
     )
    print('time stepping calculation repeat/delta_t', ts1, '\t', ts2)

    #out 
    prj.replace_text(ts1[0],
                     xpath="./time_loop/output/timesteps/pair/repeat")
    prj.replace_text('1', 
                    xpath="./time_loop/output/timesteps/pair/each_steps")

    prj.add_block( #new block to cover resolution
    blocktag="pair",
    parent_xpath="./time_loop/output/timesteps",
    taglist=["repeat", "each_steps"],
    textlist=[ts2[0], '1']  
     )
    
    print("ouput_res: timestep/each_steps", ts1, '\t', ts2)
except Exception as e:
    print(f"Error occurred: {e}")

prj.write_input()
print('\n', f"prj update in {prj_out} as {PROJECT_BASENAME}_updated.prj")
# Out:
# Error occurred: -1
#
#  prj update in _out_ps\Point_source_3Dtest_updated.prj as Point_source_3Dtest_updated.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs ./_out/Point_source_3Dtest_updated.prj -m ./_out/mesh -o ./_out/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-19 14:08:32+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out\Point_source_3Dtest_updated.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: pi_inf
# info: ConstantParameter: constant_porosity_parameter
# info: ConstantParameter: q_in
# info: Initialize processes.
# info: Time step #0 started. Time: 0. Step size: 0.
# info: [time] Output of timestep 0 took 0.484121 s.
# info: Time step #0 took 0.542965 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-19 14:08:35+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 4.166666666666667. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.435057 s.
# info: [time] Applying Dirichlet BCs took 0.0157988 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 133/10000
# info: 	 residual: 8.629838e-21
#
# info: [time] Linear solver took 0.0949907 s.
# info: Convergence criterion: |dx|=2.9077e+05, |x|=2.9077e+05, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.546098 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.367265 s.
# info: [time] Applying Dirichlet BCs took 0.0101718 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 6.517216e-21
#
# info: [time] Linear solver took 0.0279049 s.
# info: Convergence criterion: |dx|=1.9312e-10, |x|=2.9077e+05, |dx|/|x|=6.6415e-16
# info: [time] Iteration #2 took 0.405521 s.
# info: [time] Solving process #0 took 0.951993 s in time step #1
# info: [time] Time step #1 took 1.02617 s.
# info: [time] Output of timestep 1 took 0.451784 s.
# info: Time step #2 started. Time: 8.3333333333333339. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.385877 s.
# info: [time] Applying Dirichlet BCs took 0.0132379 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 6.738298e-21
#
# info: [time] Linear solver took 0.0846898 s.
# info: Convergence criterion: |dx|=3.4127e+04, |x|=3.1755e+05, |dx|/|x|=1.0747e-01
# info: [time] Iteration #1 took 0.48402 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.405488 s.
# info: [time] Applying Dirichlet BCs took 0.012683 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 6.671602e-21
#
# info: [time] Linear solver took 0.0335237 s.
# info: Convergence criterion: |dx|=1.4003e-10, |x|=3.1755e+05, |dx|/|x|=4.4098e-16
# info: [time] Iteration #2 took 0.451883 s.
# info: [time] Solving process #0 took 0.936234 s in time step #2
# info: [time] Time step #2 took 1.01214 s.
# info: [time] Output of timestep 2 took 0.484065 s.
# info: Time step #3 started. Time: 12.5. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.456316 s.
# info: [time] Applying Dirichlet BCs took 0.0151542 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 8.629165e-21
#
# info: [time] Linear solver took 0.0960044 s.
# info: Convergence criterion: |dx|=1.2743e+04, |x|=3.2677e+05, |dx|/|x|=3.8997e-02
# info: [time] Iteration #1 took 0.567694 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.364495 s.
# info: [time] Applying Dirichlet BCs took 0.0106824 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 6.681457e-21
#
# info: [time] Linear solver took 0.0247929 s.
# info: Convergence criterion: |dx|=1.6843e-10, |x|=3.2677e+05, |dx|/|x|=5.1544e-16
# info: [time] Iteration #2 took 0.400135 s.
# info: [time] Solving process #0 took 0.968203 s in time step #3
# info: [time] Time step #3 took 1.02481 s.
# info: [time] Output of timestep 3 took 0.349013 s.
# info: Time step #4 started. Time: 16.666666666666668. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.32087 s.
# info: [time] Applying Dirichlet BCs took 0.0097292 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 125/10000
# info: 	 residual: 5.817919e-21
#
# info: [time] Linear solver took 0.0640347 s.
# info: Convergence criterion: |dx|=7.0266e+03, |x|=3.3168e+05, |dx|/|x|=2.1185e-02
# info: [time] Iteration #1 took 0.39481 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.313658 s.
# info: [time] Applying Dirichlet BCs took 0.0105069 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 43/10000
# info: 	 residual: 7.489772e-21
#
# info: [time] Linear solver took 0.0225216 s.
# info: Convergence criterion: |dx|=3.6412e-10, |x|=3.3168e+05, |dx|/|x|=1.0978e-15
# info: [time] Iteration #2 took 0.346849 s.
# info: [time] Solving process #0 took 0.741992 s in time step #4
# info: [time] Time step #4 took 0.82515 s.
# info: [time] Output of timestep 4 took 0.365055 s.
# info: Time step #5 started. Time: 20.833333333333336. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.37204 s.
# info: [time] Applying Dirichlet BCs took 0.0092996 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 125/10000
# info: 	 residual: 5.889674e-21
#
# info: [time] Linear solver took 0.0671509 s.
# info: Convergence criterion: |dx|=4.6112e+03, |x|=3.3483e+05, |dx|/|x|=1.3772e-02
# info: [time] Iteration #1 took 0.448663 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307863 s.
# info: [time] Applying Dirichlet BCs took 0.008954 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 43/10000
# info: 	 residual: 6.391881e-21
#
# info: [time] Linear solver took 0.022275 s.
# info: Convergence criterion: |dx|=2.6156e-10, |x|=3.3483e+05, |dx|/|x|=7.8118e-16
# info: [time] Iteration #2 took 0.339257 s.
# info: [time] Solving process #0 took 0.788254 s in time step #5
# info: [time] Time step #5 took 0.841904 s.
# info: [time] Output of timestep 5 took 0.347901 s.
# info: Time step #6 started. Time: 25. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.29165 s.
# info: [time] Applying Dirichlet BCs took 0.0087496 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 125/10000
# info: 	 residual: 5.733464e-21
#
# info: [time] Linear solver took 0.0623035 s.
# info: Convergence criterion: |dx|=3.3307e+03, |x|=3.3708e+05, |dx|/|x|=9.8809e-03
# info: [time] Iteration #1 took 0.362874 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303751 s.
# info: [time] Applying Dirichlet BCs took 0.0089592 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.755106e-21
#
# info: [time] Linear solver took 0.0221739 s.
# info: Convergence criterion: |dx|=2.0550e-10, |x|=3.3708e+05, |dx|/|x|=6.0966e-16
# info: [time] Iteration #2 took 0.335049 s.
# info: [time] Solving process #0 took 0.698312 s in time step #6
# info: [time] Time step #6 took 0.752122 s.
# info: [time] Output of timestep 6 took 0.348001 s.
# info: Time step #7 started. Time: 29.166666666666668. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.319394 s.
# info: [time] Applying Dirichlet BCs took 0.0099123 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 9.389983e-21
#
# info: [time] Linear solver took 0.0679937 s.
# info: Convergence criterion: |dx|=2.5558e+03, |x|=3.3879e+05, |dx|/|x|=7.5441e-03
# info: [time] Iteration #1 took 0.397506 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.341625 s.
# info: [time] Applying Dirichlet BCs took 0.0089391 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.080877e-21
#
# info: [time] Linear solver took 0.0232143 s.
# info: Convergence criterion: |dx|=1.6858e-10, |x|=3.3879e+05, |dx|/|x|=4.9759e-16
# info: [time] Iteration #2 took 0.373931 s.
# info: [time] Solving process #0 took 0.771752 s in time step #7
# info: [time] Time step #7 took 0.821368 s.
# info: [time] Output of timestep 7 took 0.360671 s.
# info: Time step #8 started. Time: 33.333333333333336. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.290332 s.
# info: [time] Applying Dirichlet BCs took 0.0089433 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 8.636047e-21
#
# info: [time] Linear solver took 0.0617738 s.
# info: Convergence criterion: |dx|=2.0446e+03, |x|=3.4014e+05, |dx|/|x|=6.0111e-03
# info: [time] Iteration #1 took 0.361214 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.304011 s.
# info: [time] Applying Dirichlet BCs took 0.0090794 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 7.324602e-21
#
# info: [time] Linear solver took 0.0217208 s.
# info: Convergence criterion: |dx|=1.9682e-10, |x|=3.4014e+05, |dx|/|x|=5.7865e-16
# info: [time] Iteration #2 took 0.334983 s.
# info: [time] Solving process #0 took 0.696509 s in time step #8
# info: [time] Time step #8 took 0.750982 s.
# info: [time] Output of timestep 8 took 0.358109 s.
# info: Time step #9 started. Time: 37.5. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.287436 s.
# info: [time] Applying Dirichlet BCs took 0.0098278 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 7.908019e-21
#
# info: [time] Linear solver took 0.0617116 s.
# info: Convergence criterion: |dx|=1.6861e+03, |x|=3.4125e+05, |dx|/|x|=4.9409e-03
# info: [time] Iteration #1 took 0.359141 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.299967 s.
# info: [time] Applying Dirichlet BCs took 0.0095664 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.191825e-21
#
# info: [time] Linear solver took 0.0203807 s.
# info: Convergence criterion: |dx|=3.1277e-10, |x|=3.4125e+05, |dx|/|x|=9.1655e-16
# info: [time] Iteration #2 took 0.330073 s.
# info: [time] Solving process #0 took 0.689523 s in time step #9
# info: [time] Time step #9 took 0.739253 s.
# info: [time] Output of timestep 9 took 0.351241 s.
# info: Time step #10 started. Time: 41.666666666666671. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.284639 s.
# info: [time] Applying Dirichlet BCs took 0.008815 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 118/10000
# info: 	 residual: 7.445134e-21
#
# info: [time] Linear solver took 0.0588498 s.
# info: Convergence criterion: |dx|=1.4229e+03, |x|=3.4218e+05, |dx|/|x|=4.1582e-03
# info: [time] Iteration #1 took 0.35249 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307582 s.
# info: [time] Applying Dirichlet BCs took 0.0089779 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.452883e-21
#
# info: [time] Linear solver took 0.0210748 s.
# info: Convergence criterion: |dx|=1.8311e-10, |x|=3.4218e+05, |dx|/|x|=5.3511e-16
# info: [time] Iteration #2 took 0.337795 s.
# info: [time] Solving process #0 took 0.69063 s in time step #10
# info: [time] Time step #10 took 0.742237 s.
# info: [time] Output of timestep 10 took 0.356737 s.
# info: Time step #11 started. Time: 45.833333333333336. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.293643 s.
# info: [time] Applying Dirichlet BCs took 0.0091186 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 6.794398e-21
#
# info: [time] Linear solver took 0.0619412 s.
# info: Convergence criterion: |dx|=1.2227e+03, |x|=3.4298e+05, |dx|/|x|=3.5651e-03
# info: [time] Iteration #1 took 0.364874 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301038 s.
# info: [time] Applying Dirichlet BCs took 0.0086979 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 7.869098e-21
#
# info: [time] Linear solver took 0.0208965 s.
# info: Convergence criterion: |dx|=1.7889e-10, |x|=3.4298e+05, |dx|/|x|=5.2158e-16
# info: [time] Iteration #2 took 0.330791 s.
# info: [time] Solving process #0 took 0.695982 s in time step #11
# info: [time] Time step #11 took 0.746667 s.
# info: [time] Output of timestep 11 took 0.349126 s.
# info: Time step #12 started. Time: 50. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.288457 s.
# info: [time] Applying Dirichlet BCs took 0.0091704 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 124/10000
# info: 	 residual: 6.335718e-21
#
# info: [time] Linear solver took 0.0618055 s.
# info: Convergence criterion: |dx|=1.0662e+03, |x|=3.4367e+05, |dx|/|x|=3.1026e-03
# info: [time] Iteration #1 took 0.359611 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.3038 s.
# info: [time] Applying Dirichlet BCs took 0.0093971 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.328440e-21
#
# info: [time] Linear solver took 0.0218038 s.
# info: Convergence criterion: |dx|=1.6939e-10, |x|=3.4367e+05, |dx|/|x|=4.9288e-16
# info: [time] Iteration #2 took 0.335186 s.
# info: [time] Solving process #0 took 0.695105 s in time step #12
# info: [time] Time step #12 took 0.749076 s.
# info: [time] Output of timestep 12 took 0.358339 s.
# info: Time step #13 started. Time: 54.166666666666671. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.28535 s.
# info: [time] Applying Dirichlet BCs took 0.0086088 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 9.729057e-21
#
# info: [time] Linear solver took 0.0610284 s.
# info: Convergence criterion: |dx|=9.4105e+02, |x|=3.4427e+05, |dx|/|x|=2.7335e-03
# info: [time] Iteration #1 took 0.355158 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.302914 s.
# info: [time] Applying Dirichlet BCs took 0.0091615 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 43/10000
# info: 	 residual: 6.166807e-21
#
# info: [time] Linear solver took 0.0228676 s.
# info: Convergence criterion: |dx|=1.9499e-10, |x|=3.4427e+05, |dx|/|x|=5.6637e-16
# info: [time] Iteration #2 took 0.335115 s.
# info: [time] Solving process #0 took 0.690564 s in time step #13
# info: [time] Time step #13 took 0.742786 s.
# info: [time] Output of timestep 13 took 0.346551 s.
# info: Time step #14 started. Time: 58.333333333333336. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.360677 s.
# info: [time] Applying Dirichlet BCs took 0.0087597 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 9.173301e-21
#
# info: [time] Linear solver took 0.0602461 s.
# info: Convergence criterion: |dx|=8.3899e+02, |x|=3.4481e+05, |dx|/|x|=2.4332e-03
# info: [time] Iteration #1 took 0.429852 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.305786 s.
# info: [time] Applying Dirichlet BCs took 0.0088779 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.413292e-21
#
# info: [time] Linear solver took 0.0211492 s.
# info: Convergence criterion: |dx|=1.8828e-10, |x|=3.4481e+05, |dx|/|x|=5.4604e-16
# info: [time] Iteration #2 took 0.335967 s.
# info: [time] Solving process #0 took 0.766157 s in time step #14
# info: [time] Time step #14 took 0.817458 s.
# info: [time] Output of timestep 14 took 0.3499 s.
# info: Time step #15 started. Time: 62.500000000000007. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.292392 s.
# info: [time] Applying Dirichlet BCs took 0.0085629 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 7.761579e-21
#
# info: [time] Linear solver took 0.0607997 s.
# info: Convergence criterion: |dx|=7.5446e+02, |x|=3.4529e+05, |dx|/|x|=2.1850e-03
# info: [time] Iteration #1 took 0.361937 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307088 s.
# info: [time] Applying Dirichlet BCs took 0.0089867 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 41/10000
# info: 	 residual: 9.250187e-21
#
# info: [time] Linear solver took 0.0204336 s.
# info: Convergence criterion: |dx|=2.2959e-10, |x|=3.4529e+05, |dx|/|x|=6.6492e-16
# info: [time] Iteration #2 took 0.336676 s.
# info: [time] Solving process #0 took 0.699406 s in time step #15
# info: [time] Time step #15 took 0.750576 s.
# info: [time] Output of timestep 15 took 0.344947 s.
# info: Time step #16 started. Time: 66.666666666666671. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291394 s.
# info: [time] Applying Dirichlet BCs took 0.0087861 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 8.155489e-21
#
# info: [time] Linear solver took 0.0647978 s.
# info: Convergence criterion: |dx|=6.8348e+02, |x|=3.4573e+05, |dx|/|x|=1.9769e-03
# info: [time] Iteration #1 took 0.36515 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.306569 s.
# info: [time] Applying Dirichlet BCs took 0.0090976 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.500432e-21
#
# info: [time] Linear solver took 0.021828 s.
# info: Convergence criterion: |dx|=2.0576e-10, |x|=3.4573e+05, |dx|/|x|=5.9514e-16
# info: [time] Iteration #2 took 0.337649 s.
# info: [time] Solving process #0 took 0.703094 s in time step #16
# info: [time] Time step #16 took 0.756748 s.
# info: [time] Output of timestep 16 took 0.350728 s.
# info: Time step #17 started. Time: 70.833333333333343. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.285315 s.
# info: [time] Applying Dirichlet BCs took 0.0089152 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 7.699144e-21
#
# info: [time] Linear solver took 0.06078 s.
# info: Convergence criterion: |dx|=6.2318e+02, |x|=3.4613e+05, |dx|/|x|=1.8005e-03
# info: [time] Iteration #1 took 0.355181 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301584 s.
# info: [time] Applying Dirichlet BCs took 0.0094733 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 7.752233e-21
#
# info: [time] Linear solver took 0.0213419 s.
# info: Convergence criterion: |dx|=2.0756e-10, |x|=3.4613e+05, |dx|/|x|=5.9966e-16
# info: [time] Iteration #2 took 0.332576 s.
# info: [time] Solving process #0 took 0.688072 s in time step #17
# info: [time] Time step #17 took 0.741372 s.
# info: [time] Output of timestep 17 took 0.34786 s.
# info: Time step #18 started. Time: 75. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.303275 s.
# info: [time] Applying Dirichlet BCs took 0.0092409 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 7.268240e-21
#
# info: [time] Linear solver took 0.0610438 s.
# info: Convergence criterion: |dx|=5.7144e+02, |x|=3.4649e+05, |dx|/|x|=1.6492e-03
# info: [time] Iteration #1 took 0.373728 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.304491 s.
# info: [time] Applying Dirichlet BCs took 0.0090145 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.724510e-21
#
# info: [time] Linear solver took 0.0223962 s.
# info: Convergence criterion: |dx|=2.0886e-10, |x|=3.4649e+05, |dx|/|x|=6.0281e-16
# info: [time] Iteration #2 took 0.336057 s.
# info: [time] Solving process #0 took 0.710184 s in time step #18
# info: [time] Time step #18 took 0.764043 s.
# info: [time] Output of timestep 18 took 0.348501 s.
# info: Time step #19 started. Time: 79.166666666666671. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.284179 s.
# info: [time] Applying Dirichlet BCs took 0.0093602 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 6.771845e-21
#
# info: [time] Linear solver took 0.0615148 s.
# info: Convergence criterion: |dx|=5.2662e+02, |x|=3.4682e+05, |dx|/|x|=1.5184e-03
# info: [time] Iteration #1 took 0.355239 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.30293 s.
# info: [time] Applying Dirichlet BCs took 0.0092792 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.796985e-21
#
# info: [time] Linear solver took 0.0209186 s.
# info: Convergence criterion: |dx|=2.3511e-10, |x|=3.4682e+05, |dx|/|x|=6.7791e-16
# info: [time] Iteration #2 took 0.333302 s.
# info: [time] Solving process #0 took 0.688899 s in time step #19
# info: [time] Time step #19 took 0.739676 s.
# info: [time] Output of timestep 19 took 0.350093 s.
# info: Time step #20 started. Time: 83.333333333333343. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.299871 s.
# info: [time] Applying Dirichlet BCs took 0.0096333 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 6.499947e-21
#
# info: [time] Linear solver took 0.0616838 s.
# info: Convergence criterion: |dx|=4.8750e+02, |x|=3.4713e+05, |dx|/|x|=1.4044e-03
# info: [time] Iteration #1 took 0.371362 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.308628 s.
# info: [time] Applying Dirichlet BCs took 0.0100542 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.276804e-21
#
# info: [time] Linear solver took 0.0217553 s.
# info: Convergence criterion: |dx|=1.9889e-10, |x|=3.4713e+05, |dx|/|x|=5.7295e-16
# info: [time] Iteration #2 took 0.340619 s.
# info: [time] Solving process #0 took 0.712335 s in time step #20
# info: [time] Time step #20 took 0.765915 s.
# info: [time] Output of timestep 20 took 0.350418 s.
# info: Time step #21 started. Time: 87.5. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289074 s.
# info: [time] Applying Dirichlet BCs took 0.0098978 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 6.141406e-21
#
# info: [time] Linear solver took 0.0614416 s.
# info: Convergence criterion: |dx|=4.5310e+02, |x|=3.4741e+05, |dx|/|x|=1.3042e-03
# info: [time] Iteration #1 took 0.360605 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.306584 s.
# info: [time] Applying Dirichlet BCs took 0.0097526 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 43/10000
# info: 	 residual: 5.842990e-21
#
# info: [time] Linear solver took 0.0220277 s.
# info: Convergence criterion: |dx|=3.3354e-10, |x|=3.4741e+05, |dx|/|x|=9.6006e-16
# info: [time] Iteration #2 took 0.338527 s.
# info: [time] Solving process #0 took 0.699482 s in time step #21
# info: [time] Time step #21 took 0.750861 s.
# info: [time] Output of timestep 21 took 0.355569 s.
# info: Time step #22 started. Time: 91.666666666666671. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.293744 s.
# info: [time] Applying Dirichlet BCs took 0.0090328 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 5.801757e-21
#
# info: [time] Linear solver took 0.0612217 s.
# info: Convergence criterion: |dx|=4.2266e+02, |x|=3.4768e+05, |dx|/|x|=1.2157e-03
# info: [time] Iteration #1 took 0.364162 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303842 s.
# info: [time] Applying Dirichlet BCs took 0.0097055 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 9.916102e-21
#
# info: [time] Linear solver took 0.0213072 s.
# info: Convergence criterion: |dx|=1.9604e-10, |x|=3.4768e+05, |dx|/|x|=5.6386e-16
# info: [time] Iteration #2 took 0.33503 s.
# info: [time] Solving process #0 took 0.699579 s in time step #22
# info: [time] Time step #22 took 0.750692 s.
# info: [time] Output of timestep 22 took 0.350882 s.
# info: Time step #23 started. Time: 95.833333333333343. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291954 s.
# info: [time] Applying Dirichlet BCs took 0.0096038 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 123/10000
# info: 	 residual: 5.544013e-21
#
# info: [time] Linear solver took 0.0617861 s.
# info: Convergence criterion: |dx|=3.9557e+02, |x|=3.4793e+05, |dx|/|x|=1.1369e-03
# info: [time] Iteration #1 took 0.363528 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.348461 s.
# info: [time] Applying Dirichlet BCs took 0.0122434 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 7.035877e-21
#
# info: [time] Linear solver took 0.022532 s.
# info: Convergence criterion: |dx|=1.5857e-10, |x|=3.4793e+05, |dx|/|x|=4.5575e-16
# info: [time] Iteration #2 took 0.3834 s.
# info: [time] Solving process #0 took 0.747293 s in time step #23
# info: [time] Time step #23 took 0.800682 s.
# info: [time] Output of timestep 23 took 0.359194 s.
# info: Time step #24 started. Time: 100. Step size: 4.166666666666667.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.296966 s.
# info: [time] Applying Dirichlet BCs took 0.0099284 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 122/10000
# info: 	 residual: 9.697272e-21
#
# info: [time] Linear solver took 0.0615388 s.
# info: Convergence criterion: |dx|=3.7132e+02, |x|=3.4816e+05, |dx|/|x|=1.0665e-03
# info: [time] Iteration #1 took 0.368611 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303861 s.
# info: [time] Applying Dirichlet BCs took 0.0100427 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 42/10000
# info: 	 residual: 8.930793e-21
#
# info: [time] Linear solver took 0.0219356 s.
# info: Convergence criterion: |dx|=2.4167e-10, |x|=3.4816e+05, |dx|/|x|=6.9413e-16
# info: [time] Iteration #2 took 0.335998 s.
# info: [time] Solving process #0 took 0.704971 s in time step #24
# info: [time] Time step #24 took 0.758511 s.
# info: [time] Output of timestep 24 took 0.363885 s.
# info: Time step #25 started. Time: 116. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289375 s.
# info: [time] Applying Dirichlet BCs took 0.0094564 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 137/10000
# info: 	 residual: 9.404091e-21
#
# info: [time] Linear solver took 0.068794 s.
# info: Convergence criterion: |dx|=1.1696e+03, |x|=3.4888e+05, |dx|/|x|=3.3525e-03
# info: [time] Iteration #1 took 0.367807 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.308661 s.
# info: [time] Applying Dirichlet BCs took 0.009436 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 7.718456e-21
#
# info: [time] Linear solver took 0.0246558 s.
# info: Convergence criterion: |dx|=1.9541e-10, |x|=3.4888e+05, |dx|/|x|=5.6012e-16
# info: [time] Iteration #2 took 0.342913 s.
# info: [time] Solving process #0 took 0.711234 s in time step #25
# info: [time] Time step #25 took 0.764767 s.
# info: [time] Output of timestep 25 took 0.354625 s.
# info: Time step #26 started. Time: 132. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.29173 s.
# info: [time] Applying Dirichlet BCs took 0.0096078 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 137/10000
# info: 	 residual: 8.756644e-21
#
# info: [time] Linear solver took 0.0688379 s.
# info: Convergence criterion: |dx|=9.8011e+02, |x|=3.4949e+05, |dx|/|x|=2.8044e-03
# info: [time] Iteration #1 took 0.370341 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.300056 s.
# info: [time] Applying Dirichlet BCs took 0.0101393 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 50/10000
# info: 	 residual: 7.319604e-21
#
# info: [time] Linear solver took 0.0263013 s.
# info: Convergence criterion: |dx|=3.1968e-10, |x|=3.4949e+05, |dx|/|x|=9.1472e-16
# info: [time] Iteration #2 took 0.336649 s.
# info: [time] Solving process #0 took 0.70737 s in time step #26
# info: [time] Time step #26 took 0.760976 s.
# info: [time] Output of timestep 26 took 0.351388 s.
# info: Time step #27 started. Time: 148. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.294478 s.
# info: [time] Applying Dirichlet BCs took 0.0097035 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 137/10000
# info: 	 residual: 8.022444e-21
#
# info: [time] Linear solver took 0.0694095 s.
# info: Convergence criterion: |dx|=8.3601e+02, |x|=3.5000e+05, |dx|/|x|=2.3886e-03
# info: [time] Iteration #1 took 0.37376 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.300561 s.
# info: [time] Applying Dirichlet BCs took 0.0099015 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 9.148105e-21
#
# info: [time] Linear solver took 0.0252822 s.
# info: Convergence criterion: |dx|=2.3638e-10, |x|=3.5000e+05, |dx|/|x|=6.7536e-16
# info: [time] Iteration #2 took 0.335906 s.
# info: [time] Solving process #0 took 0.710144 s in time step #27
# info: [time] Time step #27 took 0.763725 s.
# info: [time] Output of timestep 27 took 0.34658 s.
# info: Time step #28 started. Time: 164. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.286119 s.
# info: [time] Applying Dirichlet BCs took 0.0099325 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 137/10000
# info: 	 residual: 7.567594e-21
#
# info: [time] Linear solver took 0.0697085 s.
# info: Convergence criterion: |dx|=7.2379e+02, |x|=3.5044e+05, |dx|/|x|=2.0654e-03
# info: [time] Iteration #1 took 0.365936 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.300914 s.
# info: [time] Applying Dirichlet BCs took 0.0094216 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 7.899890e-21
#
# info: [time] Linear solver took 0.0248283 s.
# info: Convergence criterion: |dx|=2.2606e-10, |x|=3.5044e+05, |dx|/|x|=6.4507e-16
# info: [time] Iteration #2 took 0.335331 s.
# info: [time] Solving process #0 took 0.701683 s in time step #28
# info: [time] Time step #28 took 0.752862 s.
# info: [time] Output of timestep 28 took 0.353154 s.
# info: Time step #29 started. Time: 180. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.34202 s.
# info: [time] Applying Dirichlet BCs took 0.0097112 s.
# ...
# info: [time] Assembly took 0.360394 s.
# info: [time] Applying Dirichlet BCs took 0.0122286 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 8.233141e-21
#
# info: [time] Linear solver took 0.0286309 s.
# info: Convergence criterion: |dx|=2.5118e-10, |x|=3.5322e+05, |dx|/|x|=7.1113e-16
# info: [time] Iteration #2 took 0.401427 s.
# info: [time] Solving process #0 took 0.781829 s in time step #40
# info: [time] Time step #40 took 0.864282 s.
# info: [time] Output of timestep 40 took 0.361515 s.
# info: Time step #41 started. Time: 372. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.365459 s.
# info: [time] Applying Dirichlet BCs took 0.0086455 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 9.985476e-21
#
# info: [time] Linear solver took 0.0671125 s.
# info: Convergence criterion: |dx|=2.2825e+02, |x|=3.5335e+05, |dx|/|x|=6.4598e-04
# info: [time] Iteration #1 took 0.441408 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.304544 s.
# info: [time] Applying Dirichlet BCs took 0.0085538 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 49/10000
# info: 	 residual: 8.505577e-21
#
# info: [time] Linear solver took 0.0252508 s.
# info: Convergence criterion: |dx|=2.3830e-10, |x|=3.5335e+05, |dx|/|x|=6.7440e-16
# info: [time] Iteration #2 took 0.338506 s.
# info: [time] Solving process #0 took 0.780293 s in time step #41
# info: [time] Time step #41 took 0.834157 s.
# info: [time] Output of timestep 41 took 0.35134 s.
# info: Time step #42 started. Time: 388. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289179 s.
# info: [time] Applying Dirichlet BCs took 0.0085592 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 9.581675e-21
#
# info: [time] Linear solver took 0.0666341 s.
# info: Convergence criterion: |dx|=2.1538e+02, |x|=3.5347e+05, |dx|/|x|=6.0933e-04
# info: [time] Iteration #1 took 0.364537 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.32586 s.
# info: [time] Applying Dirichlet BCs took 0.0089415 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 8.928962e-21
#
# info: [time] Linear solver took 0.0241457 s.
# info: Convergence criterion: |dx|=1.7640e-10, |x|=3.5347e+05, |dx|/|x|=4.9906e-16
# info: [time] Iteration #2 took 0.359112 s.
# info: [time] Solving process #0 took 0.724135 s in time step #42
# info: [time] Time step #42 took 0.777124 s.
# info: [time] Output of timestep 42 took 0.347638 s.
# info: Time step #43 started. Time: 404. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.306286 s.
# info: [time] Applying Dirichlet BCs took 0.0087414 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 9.152415e-21
#
# info: [time] Linear solver took 0.0664983 s.
# info: Convergence criterion: |dx|=2.0374e+02, |x|=3.5358e+05, |dx|/|x|=5.7622e-04
# info: [time] Iteration #1 took 0.381682 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301304 s.
# info: [time] Applying Dirichlet BCs took 0.0089912 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 47/10000
# info: 	 residual: 9.288854e-21
#
# info: [time] Linear solver took 0.0236019 s.
# info: Convergence criterion: |dx|=2.2024e-10, |x|=3.5358e+05, |dx|/|x|=6.2288e-16
# info: [time] Iteration #2 took 0.334065 s.
# info: [time] Solving process #0 took 0.716325 s in time step #43
# info: [time] Time step #43 took 0.767032 s.
# info: [time] Output of timestep 43 took 0.345371 s.
# info: Time step #44 started. Time: 420. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.294159 s.
# info: [time] Applying Dirichlet BCs took 0.0088515 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 127/10000
# info: 	 residual: 8.657593e-21
#
# info: [time] Linear solver took 0.0624764 s.
# info: Convergence criterion: |dx|=1.9318e+02, |x|=3.5369e+05, |dx|/|x|=5.4619e-04
# info: [time] Iteration #1 took 0.365666 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.30274 s.
# info: [time] Applying Dirichlet BCs took 0.0089337 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 9.053066e-21
#
# info: [time] Linear solver took 0.0246 s.
# info: Convergence criterion: |dx|=2.3394e-10, |x|=3.5369e+05, |dx|/|x|=6.6142e-16
# info: [time] Iteration #2 took 0.336429 s.
# info: [time] Solving process #0 took 0.702468 s in time step #44
# info: [time] Time step #44 took 0.75585 s.
# info: [time] Output of timestep 44 took 0.349165 s.
# info: Time step #45 started. Time: 436. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.290286 s.
# info: [time] Applying Dirichlet BCs took 0.0098399 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 127/10000
# info: 	 residual: 8.309615e-21
#
# info: [time] Linear solver took 0.0626379 s.
# info: Convergence criterion: |dx|=1.8356e+02, |x|=3.5379e+05, |dx|/|x|=5.1884e-04
# info: [time] Iteration #1 took 0.362923 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.303715 s.
# info: [time] Applying Dirichlet BCs took 0.0086921 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 47/10000
# info: 	 residual: 8.435474e-21
#
# info: [time] Linear solver took 0.0241367 s.
# info: Convergence criterion: |dx|=2.1990e-10, |x|=3.5379e+05, |dx|/|x|=6.2155e-16
# info: [time] Iteration #2 took 0.336705 s.
# info: [time] Solving process #0 took 0.699972 s in time step #45
# info: [time] Time step #45 took 0.750931 s.
# info: [time] Output of timestep 45 took 0.348654 s.
# info: Time step #46 started. Time: 452. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.29288 s.
# info: [time] Applying Dirichlet BCs took 0.0085105 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 7.754282e-21
#
# info: [time] Linear solver took 0.0664226 s.
# info: Convergence criterion: |dx|=1.7477e+02, |x|=3.5389e+05, |dx|/|x|=4.9384e-04
# info: [time] Iteration #1 took 0.367996 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.307621 s.
# info: [time] Applying Dirichlet BCs took 0.0090008 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 9.567364e-21
#
# info: [time] Linear solver took 0.0245545 s.
# info: Convergence criterion: |dx|=1.9809e-10, |x|=3.5389e+05, |dx|/|x|=5.5976e-16
# info: [time] Iteration #2 took 0.341336 s.
# info: [time] Solving process #0 took 0.709674 s in time step #46
# info: [time] Time step #46 took 0.761281 s.
# info: [time] Output of timestep 46 took 0.347799 s.
# info: Time step #47 started. Time: 468. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.292095 s.
# info: [time] Applying Dirichlet BCs took 0.0088459 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 7.169329e-21
#
# info: [time] Linear solver took 0.0681491 s.
# info: Convergence criterion: |dx|=1.6669e+02, |x|=3.5398e+05, |dx|/|x|=4.7090e-04
# info: [time] Iteration #1 took 0.369255 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.295287 s.
# info: [time] Applying Dirichlet BCs took 0.0087413 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 9.267714e-21
#
# info: [time] Linear solver took 0.024217 s.
# info: Convergence criterion: |dx|=1.9238e-10, |x|=3.5398e+05, |dx|/|x|=5.4349e-16
# info: [time] Iteration #2 took 0.328436 s.
# info: [time] Solving process #0 took 0.698056 s in time step #47
# info: [time] Time step #47 took 0.749635 s.
# info: [time] Output of timestep 47 took 0.378583 s.
# info: Time step #48 started. Time: 484. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291466 s.
# info: [time] Applying Dirichlet BCs took 0.0098041 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 7.224398e-21
#
# info: [time] Linear solver took 0.0685681 s.
# info: Convergence criterion: |dx|=1.5926e+02, |x|=3.5407e+05, |dx|/|x|=4.4979e-04
# info: [time] Iteration #1 took 0.370008 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.3063 s.
# info: [time] Applying Dirichlet BCs took 0.0104128 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 48/10000
# info: 	 residual: 6.290053e-21
#
# info: [time] Linear solver took 0.0250625 s.
# info: Convergence criterion: |dx|=2.0116e-10, |x|=3.5407e+05, |dx|/|x|=5.6813e-16
# info: [time] Iteration #2 took 0.341933 s.
# info: [time] Solving process #0 took 0.712236 s in time step #48
# info: [time] Time step #48 took 0.765686 s.
# info: [time] Output of timestep 48 took 0.361661 s.
# info: Time step #49 started. Time: 500. Step size: 16.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.291304 s.
# info: [time] Applying Dirichlet BCs took 0.0099465 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 135/10000
# info: 	 residual: 6.891149e-21
#
# info: [time] Linear solver took 0.0672953 s.
# info: Convergence criterion: |dx|=1.5239e+02, |x|=3.5415e+05, |dx|/|x|=4.3029e-04
# info: [time] Iteration #1 took 0.368723 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301216 s.
# info: [time] Applying Dirichlet BCs took 0.0096582 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 47/10000
# info: 	 residual: 9.040981e-21
#
# info: [time] Linear solver took 0.0237553 s.
# info: Convergence criterion: |dx|=1.9606e-10, |x|=3.5415e+05, |dx|/|x|=5.5359e-16
# info: [time] Iteration #2 took 0.334787 s.
# info: [time] Solving process #0 took 0.70383 s in time step #49
# info: [time] Time step #49 took 0.757666 s.
# info: [time] Output of timestep 49 took 0.345256 s.
# info: The whole computation of the time stepping took 49 steps, in which
# 	 the accepted steps are 49, and the rejected steps are 0.
#
# info: [time] Execution took 56.4843 s.
# info: OGS terminated on 2026-03-19 14:09:32+0100.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path = Path("_out/liquid_ps3d_test.pvd")
ms = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="Pa")

# %%
y=25
z=-50

#coords=np.array(np.geomspace([26,y,z],[50,y,z],6).round(2)) #extracting along x geometrically
coords=np.array(np.linspace([26,y,z],[50,y,z],6)) #extracting along x linearly
coords[:,0]=rgeo+25 #adjusting geometry shifting
ms_probes = ms.extract_probe(ms,points=coords)

labels = [f"x={pt[0]:>5.2f}, y={y}, z={z}" for pt in coords]

diff = p_wsr - ms_probes['pressure']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.81it/s]

# %% [markdown]
# ### Performance comparison

# %%
fig, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
ot.plot.line(ms_probes,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(t, p_wsr,color='tab:red', label=line_labels) 
axs[1].plot(t, diff, label=line_labels)

fig.suptitle("Point source analytical - Numerical OGS Nodal, 3D")
axs[0].set_title("Results by distance (radius)")
axs[1].set_title("Difference analytical-OGS")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / Pa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

#plt.savefig("psn_3D_Ca.pdf", format="pdf")  
plt.show()

# %% [markdown]
# # STIMTEC Example

# %% [markdown]
# ## Path adjoint

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out_ps"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Point-source step-rate

# %% [markdown]
# ### Preprocesing and preparing data

# %%
cwd=Path.cwd()
newpath=cwd/"STIMTEC_example"
dataex=pd.read_csv(newpath/"BH10_20180716_51.6.csv",sep=",",header=0)

# %%
#visualising full data set
fig1, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title("test: BH10_20180716_51.6")

ax.plot(dataex['Zeit [s]'],dataex['Pint_uphole [MPa]'],label="Pint_uphole [MPa]")
ax.plot(dataex['Zeit [s]'],dataex['Q_uphole [lpm]'],label="Q_uphole [lpm]")

plt.legend()
plt.show()

# %%
#isolating Step-rate and preparing curve

mask = (dataex['Zeit [s]'] > 2600) & (dataex['Zeit [s]'] < 4150)
dataex_f = dataex.loc[mask, :].copy()
dataex_f = dataex_f.reset_index(drop=True)

dataex_f['Q_uphole [lpm]_s']=scale_and_smooth(dataex_f['Q_uphole [lpm]'])

steps_=pickings(dataex_f['Q_uphole [lpm]_s'],60,20)
print('steps','\t', len(steps_))

fig1, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title("test: BH10_20180716_51.6, steps")

ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]'],label="P int d")
for i in range (len(steps_)):
     ax.axvline(x=dataex_f.loc[steps_[i,0],'Zeit [s]'],ls="--",color="tab:red")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_uphole [lpm]'],label="Q uphole")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_uphole [lpm]_s'],label="Q uphole_smoothed")

plt.legend()
plt.show()
# Out:
# steps 	 15

# %%
#protocol
pr=pd.DataFrame(data=steps_,
                      index = np.arange(len(steps_)),
                      columns=['index','qs'])
protocol={'index':0,'qs':dataex_f['Q_uphole [lpm]_s'].values[0],'T_s':dataex_f['Zeit [s]'].values[0]}
pr["T_s"]=dataex_f.loc[steps_[:,0].astype(int),'Zeit [s]'].values
protocol=pd.concat([pd.DataFrame(protocol,index=[0]),pr],axis=0)
protocol.reset_index(drop=True, inplace=True)
protocol['qs']=-protocol['qs']/60000 #injection is negative flow

# %% [markdown]
# ### Point-source analytical running

# %%
#data 
ddict={"p_i":0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":4e-8 ,
       "r_w":0.038 
      }

# %%
delta_t=dataex_f['Zeit [s]'].values
tp=protocol['T_s'].values
q_array=protocol['qs'].values

r_val1=ddict['r_w'] #at wellbore face
k_val1= np.geomspace(2e-14, 5e-14, 5) #real wellbore

pwsr1= step_rate_s(pwd_ps, delta_t, tp, q_array, ddict, k_val1, r_val1)

# %%
fig2, ax=plt.subplots()

for i, k in enumerate(k_val1):
    ax.plot(delta_t, pwsr1[:, i], label=f'k = {k:.2e} m²')
    
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title("test: BH10_20180716_51.6, k-values")

plt.legend()
plt.pause(1)

# %%
k_val=4.5e-14 #reference k

rgeo=np.geomspace(0.038,5,5)
r_val=rgeo
pwsr2= step_rate_s(pwd_ps, delta_t, tp, q_array, ddict, k_val, r_val)

rinv=np.sqrt(k_val*(max(dataex_f['Zeit [s]'])-min(dataex_f['Zeit [s]']))/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Investigation radius (m):  7.62
#  "unperturbed" threshold (m):  30.50

# %%
line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

fig3, ax=plt.subplots()

for i, r in enumerate(rgeo):
    plt.plot(delta_t, pwsr2[:, i], label=f'r = {r:.2f} m')
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / Pa")
plt.title(f"test: BH10_20180716_51.6, r-values, k={k_val} m^2")

plt.legend() 
plt.pause(1)

# %% [markdown]
# ### Plot report

# %%
figprint, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,5], sharex=True)

for i, k in enumerate(k_val1):
    axs[0].plot(delta_t, pwsr1[:, i], label=f'k = {k:.2e} m²')
    
axs[0].plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

axs[0].set_xlabel("time / s")
axs[0].set_ylabel("Pressure / Pa")
axs[0].set_title("test: BH10_20180716_51.6, k-values")

line_labels = [f"r = {val:>5.2f} m" for val in rgeo]

for i, r in enumerate(rgeo):
    axs[1].plot(delta_t, pwsr2[:, i], label=f'r = {r:.2f} m')
axs[1].plot(dataex_f['Zeit [s]'],dataex_f['Pint_uphole [MPa]']*1e6,label="P int d", ls="--")

axs[1].set_xlabel("time / s")
axs[1].set_ylabel("Pressure / Pa")
axs[1].set_title(f"test: BH10_20180716_51.6, r-values, k={k_val} m^2")

fig4.suptitle("Point source analytical , r and k values") 

axs[0].legend()
axs[1].legend()
axs[0].grid()
axs[1].grid()
plt.tight_layout()

#plt.savefig("psa_3D_BH10_20180716_51.6.pdf", format="pdf") 
plt.show()

# %% [markdown]
# ## Point-source Numerical

# %% [markdown]
# ### Meshing 3D point-source

# %%
cube_file = MESH_DIR / "cube_3d_ps.msh"

create_cube_mesh_p(
    cube_file,
    width= 50,
    height= 50,
    thickness=50,
    mesh_size= 2, #optimal one-size-to-mesh ratio= 20-40, ie, side(50)/mesh_size(2)=25, ref 1
    target_rw= 0.05, # Added target_rw for explicit control
    center_z= -50,
    debug_gui= False,
    local_ref= True,
    ) 

cube_meshes = ot.meshes_from_gmsh(cube_file, log=False)
for name, mesh in cube_meshes.items():
    vtu = MESH_DIR / f"cube_{name}.vtu"
    pv.save_meshio(vtu, mesh)
    print(f"Saved {vtu}")
# Out:
# Saved _out_ps\mesh\cube_domain.vtu
# Saved _out_ps\mesh\cube_physical_group_points.vtu
# Saved _out_ps\mesh\cube_physical_group_center.vtu
# Saved _out_ps\mesh\cube_physical_group_edges.vtu
# Saved _out_ps\mesh\cube_physical_group_bottom.vtu
# Saved _out_ps\mesh\cube_physical_group_top.vtu
# Saved _out_ps\mesh\cube_physical_group_back.vtu
# Saved _out_ps\mesh\cube_physical_group_front.vtu
# Saved _out_ps\mesh\cube_physical_group_left.vtu
# Saved _out_ps\mesh\cube_physical_group_right.vtu
# Saved _out_ps\mesh\cube_physical_group_volume.vtu

# %%
#slcaing meshing first round of tetrahedra
x=50
y=50
z=-50

point_idx = mesh.find_closest_point([x, y, z])
cell_ids = mesh.extract_points([point_idx])["vtkOriginalCellIds"]

refined_cells = mesh.extract_cells(cell_ids)
local_volume = refined_cells.volume

r_eq = (3 * local_volume / (4 * np.pi))**(1/3)
q_fact=(1/r_eq)**(2/3)

# %% [markdown]
# ### PRJ file pre-procesing

# %%
PROJECT_BASENAME = "Point_source_3Dtest" 
TESTSR= "BH10_20180716_51.6"
prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR / f"{TESTSR}_PS3D.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
#Permeability reference and pressure pi, pinf
k_ref= 4.5e-14
ct_ref= ddict["c_t"]*ddict['por']

p_inf=0
p0=0

# %%
parent_xpath = "./processes/process[1]"
target_path = "./processes/process[1]/equation_balance_type"

mode='volume'

def f_mode(mode:str):
    if mode=="volume":       
            prj.replace_text("volume", xpath=target_path)
    elif mode=="mass":       
            prj.replace_text("mass", xpath=target_path)
    else:
        print("Input just: mass or volume")

    print(f"Updated: Existing equation_balance_type changed to {mode}.")
    

try:
    root = prj.tree.getroot()
    node = root.find(target_path)
    
    if node is not None:
        if node.text == "volume":
            print("Verified: equation_balance_type 'volume' already exists.")
       
        elif node.text=="mass":
            print("Verified: equation_balance_type 'mass' already exists.")
        
        else:
            f_mode(mode)
    else:
        print(f"Adding equation_balance_type={mode}")
        prj.add_element(
            parent_xpath=parent_xpath, 
            tag="equation_balance_type", 
            text=mode
        )

except Exception as e:
    print(f"Error: {e}")
# Out:
# Adding equation_balance_type=volume

# %%
last_t=dataex_f.loc[dataex_f.tail(1).index.values.astype(int),'Zeit [s]':'Q_uphole [lpm]']
last_t['Q_uphole [lpm]']=last_t['Q_uphole [lpm]']/60000
last_t=last_t.values.flatten().tolist() 
print(last_t)

param_name = "q_in" #inlet flow

def create_sr_ogs(T,q,data,mode=mode,factor=q_fact,var="t"):
    q_scaled = -q * factor
    q_last_scaled = data[1] * factor 
    
    q_list = q_scaled.tolist()
    q_list.append(q_last_scaled)
    
    T_list = T.tolist()
    T_list.append(data[0])


    if mode == "mass":
        q_list = [val * 1000 for val in q_list]
        
    parts = [f"{var} < {T_list[i+1]:g} ? {q_list[i]:.6g} :" for i in range(0, len(T_list)-1)]
    
    return "(" + "\n           ".join(parts) + f"\n           {q_list[-1]:.6g})",T_list

try:
    prj.replace_parameter_value(name="p0", value=p0)
    prj.replace_parameter_value(name="pi_inf", value=p_inf)
    
    root = prj.tree.getroot() # Access the underlying ElementTree
    param_node = root.find(f".//parameters/parameter[name='{param_name}']")
    value_tag = param_node.find("value")
    if value_tag is not None:
         param_node.remove(value_tag)
    
    n_type = prj.replace_text(
        "Function", xpath=f".//parameters/parameter[name='{param_name}']/type"
    )
    
    n_expr,Times = create_sr_ogs(tp,q_array,last_t,mode)
    
    prj.add_element(
        parent_xpath=f".//parameters/parameter[name='{param_name}']", 
        tag="expression", 
        text=n_expr
    )
    
    print("flow_expression", n_expr)
    
    #timestepping calculations 
    delta_res=1
    prj.replace_text(Times[0], 
                     xpath="./time_loop/processes/process/time_stepping/t_initial")
    prj.replace_text(Times[-1],
                     xpath="./time_loop/processes/process/time_stepping/t_end")
    prj.replace_text("1",
                     xpath="./time_loop/processes/process/time_stepping/timesteps/pair/repeat")
    prj.replace_text(delta_res, #resolution of stepping
        xpath="./time_loop/processes/process/time_stepping/timesteps/pair/delta_t")
    
    print("delta_t calculation: ", delta_res)

    #out and prefix
    outsteps=10 #10 at convenience
    prefix= TESTSR
    
    prj.replace_text("1",
                     xpath="./time_loop/output/timesteps/pair/repeat")
    prj.replace_text(outsteps, #resolution of stepping
                    xpath="./time_loop/output/timesteps/pair/each_steps")
    prj.replace_text(prefix, 
                     xpath="./time_loop/output/prefix")
    
    print("ouput_res: ", outsteps,'\n','prefix:',prefix )
    
    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value=ct_ref)
    
    print("media/properties, Parameters updated")
    
except Exception as e:
    
    print(f"Error occurred: {e}")

prj.write_input()
print('\n', f"prj update in {prj_in} as {prj_out}")
# Out:
# [4149.973, 5.675e-08]
# flow_expression (t < 2659.97 ? 2.33588e-08 :
#            t < 2689.27 ? 1.13959e-05 :
#            t < 2703.72 ? -5.2505e-09 :
#            t < 2800.72 ? 9.8177e-06 :
#            t < 2942.27 ? 1.99673e-05 :
#            t < 3081.27 ? 2.52986e-05 :
#            t < 3195.37 ? 3.42849e-05 :
#            t < 3308.12 ? 5.3118e-05 :
#            t < 3466.22 ? 7.02932e-05 :
#            t < 3575.17 ? 8.79515e-05 :
#            t < 3665.42 ? 0.000105134 :
#            t < 3741.02 ? 0.000123523 :
#            t < 3819.37 ? 0.000140232 :
#            t < 3906.42 ? 0.000158601 :
#            t < 3991.77 ? 0.00017438 :
#            t < 4149.97 ? 3.03149e-07 :
#            5.93407e-08)
# delta_t calculation:  1
# ouput_res:  1
#  prefix: BH10_20180716_51.6
# media/properties, Parameters updated
#
#  prj update in Point_source_3Dtest.prj as _out_ps\BH10_20180716_51.6_PS3D.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs _out_ps\BH10_20180716_51.6_PS3D.prj -m ./_out_ps/mesh -o ./_out_ps/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-19 11:45:32+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out_ps\BH10_20180716_51.6_PS3D.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: pi_inf
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: Initialize processes.
# info: Time step #0 started. Time: 2600.023. Step size: 0.
# info: [time] Output of timestep 0 took 0.290475 s.
# info: Time step #0 took 0.324525 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-19 11:45:34+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 2601.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.27954 s.
# info: [time] Applying Dirichlet BCs took 0.0087097 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 111/10000
# info: 	 residual: 9.809256e-21
#
# info: [time] Linear solver took 0.0430399 s.
# info: Convergence criterion: |dx|=3.3437e+03, |x|=3.3437e+03, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.331468 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.283746 s.
# info: [time] Applying Dirichlet BCs took 0.0109349 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 4.735461e-21
#
# info: [time] Linear solver took 0.0163668 s.
# info: Convergence criterion: |dx|=1.3293e-12, |x|=3.3437e+03, |dx|/|x|=3.9756e-16
# info: [time] Iteration #2 took 0.311181 s.
# info: [time] Solving process #0 took 0.643019 s in time step #1
# info: [time] Time step #1 took 0.687891 s.
# info: [time] Output of timestep 1 took 0.338362 s.
# info: Time step #2 started. Time: 2602.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.336396 s.
# info: [time] Applying Dirichlet BCs took 0.0102922 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 9.790775e-21
#
# info: [time] Linear solver took 0.0516263 s.
# info: Convergence criterion: |dx|=8.7167e+02, |x|=4.0371e+03, |dx|/|x|=2.1591e-01
# info: [time] Iteration #1 took 0.398493 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.28552 s.
# info: [time] Applying Dirichlet BCs took 0.0109251 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 7.472078e-21
#
# info: [time] Linear solver took 0.0153794 s.
# info: Convergence criterion: |dx|=2.2915e-12, |x|=4.0371e+03, |dx|/|x|=5.6762e-16
# info: [time] Iteration #2 took 0.311982 s.
# info: [time] Solving process #0 took 0.710823 s in time step #2
# info: [time] Time step #2 took 0.751482 s.
# info: [time] Output of timestep 2 took 0.300955 s.
# info: Time step #3 started. Time: 2603.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.310657 s.
# info: [time] Applying Dirichlet BCs took 0.0108116 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 8.688889e-21
#
# info: [time] Linear solver took 0.0460007 s.
# info: Convergence criterion: |dx|=4.3527e+02, |x|=4.3658e+03, |dx|/|x|=9.9700e-02
# info: [time] Iteration #1 took 0.367616 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.291829 s.
# info: [time] Applying Dirichlet BCs took 0.0080158 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 34/10000
# info: 	 residual: 9.197521e-21
#
# info: [time] Linear solver took 0.0139449 s.
# info: Convergence criterion: |dx|=2.2349e-12, |x|=4.3658e+03, |dx|/|x|=5.1191e-16
# info: [time] Iteration #2 took 0.313919 s.
# info: [time] Solving process #0 took 0.681905 s in time step #3
# info: [time] Time step #3 took 0.721804 s.
# info: [time] Output of timestep 3 took 0.31087 s.
# info: Time step #4 started. Time: 2604.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.310753 s.
# info: [time] Applying Dirichlet BCs took 0.0098706 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 6.118652e-21
#
# info: [time] Linear solver took 0.049593 s.
# info: Convergence criterion: |dx|=2.6897e+02, |x|=4.5648e+03, |dx|/|x|=5.8923e-02
# info: [time] Iteration #1 took 0.370365 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.301966 s.
# info: [time] Applying Dirichlet BCs took 0.0169972 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 34/10000
# info: 	 residual: 9.156016e-21
#
# info: [time] Linear solver took 0.0174294 s.
# info: Convergence criterion: |dx|=2.4768e-12, |x|=4.5648e+03, |dx|/|x|=5.4259e-16
# info: [time] Iteration #2 took 0.336573 s.
# info: [time] Solving process #0 took 0.707475 s in time step #4
# info: [time] Time step #4 took 0.754898 s.
# info: [time] Output of timestep 4 took 0.324187 s.
# info: Time step #5 started. Time: 2605.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.292971 s.
# info: [time] Applying Dirichlet BCs took 0.0107933 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 8.852357e-21
#
# info: [time] Linear solver took 0.0472107 s.
# info: Convergence criterion: |dx|=1.8704e+02, |x|=4.7014e+03, |dx|/|x|=3.9783e-02
# info: [time] Iteration #1 took 0.351132 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.322936 s.
# info: [time] Applying Dirichlet BCs took 0.0115368 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 37/10000
# info: 	 residual: 5.332662e-21
#
# info: [time] Linear solver took 0.0176273 s.
# info: Convergence criterion: |dx|=2.6618e-12, |x|=4.7014e+03, |dx|/|x|=5.6618e-16
# info: [time] Iteration #2 took 0.352245 s.
# info: [time] Solving process #0 took 0.703717 s in time step #5
# info: [time] Time step #5 took 0.747963 s.
# info: [time] Output of timestep 5 took 0.335554 s.
# info: Time step #6 started. Time: 2606.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.273581 s.
# info: [time] Applying Dirichlet BCs took 0.0099076 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 6.819832e-21
#
# info: [time] Linear solver took 0.0437679 s.
# info: Convergence criterion: |dx|=1.3996e+02, |x|=4.8029e+03, |dx|/|x|=2.9140e-02
# info: [time] Iteration #1 took 0.327399 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.293518 s.
# info: [time] Applying Dirichlet BCs took 0.0098951 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 6.203703e-21
#
# info: [time] Linear solver took 0.0155064 s.
# info: Convergence criterion: |dx|=2.2304e-12, |x|=4.8029e+03, |dx|/|x|=4.6439e-16
# info: [time] Iteration #2 took 0.319054 s.
# info: [time] Solving process #0 took 0.646826 s in time step #6
# info: [time] Time step #6 took 0.688204 s.
# info: [time] Output of timestep 6 took 0.32982 s.
# info: Time step #7 started. Time: 2607.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.328787 s.
# info: [time] Applying Dirichlet BCs took 0.008998 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 7.690212e-21
#
# info: [time] Linear solver took 0.0457606 s.
# info: Convergence criterion: |dx|=1.1002e+02, |x|=4.8821e+03, |dx|/|x|=2.2535e-02
# info: [time] Iteration #1 took 0.383695 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.31008 s.
# info: [time] Applying Dirichlet BCs took 0.0094562 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 8.335052e-21
#
# info: [time] Linear solver took 0.0175337 s.
# info: Convergence criterion: |dx|=2.7306e-12, |x|=4.8821e+03, |dx|/|x|=5.5931e-16
# info: [time] Iteration #2 took 0.337215 s.
# info: [time] Solving process #0 took 0.721409 s in time step #7
# info: [time] Time step #7 took 0.764949 s.
# info: [time] Output of timestep 7 took 0.328469 s.
# info: Time step #8 started. Time: 2608.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.286291 s.
# info: [time] Applying Dirichlet BCs took 0.0130359 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 103/10000
# info: 	 residual: 9.747446e-21
#
# info: [time] Linear solver took 0.0434263 s.
# info: Convergence criterion: |dx|=8.9583e+01, |x|=4.9464e+03, |dx|/|x|=1.8111e-02
# info: [time] Iteration #1 took 0.342909 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.292321 s.
# info: [time] Applying Dirichlet BCs took 0.0095352 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.626502e-21
#
# info: [time] Linear solver took 0.0157262 s.
# info: Convergence criterion: |dx|=2.5930e-12, |x|=4.9464e+03, |dx|/|x|=5.2422e-16
# info: [time] Iteration #2 took 0.317726 s.
# info: [time] Solving process #0 took 0.661064 s in time step #8
# info: [time] Time step #8 took 0.70206 s.
# info: [time] Output of timestep 8 took 0.316272 s.
# info: Time step #9 started. Time: 2609.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.257288 s.
# info: [time] Applying Dirichlet BCs took 0.008105 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 7.705160e-21
#
# info: [time] Linear solver took 0.0416017 s.
# info: Convergence criterion: |dx|=7.4882e+01, |x|=4.9998e+03, |dx|/|x|=1.4977e-02
# info: [time] Iteration #1 took 0.307133 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.281113 s.
# info: [time] Applying Dirichlet BCs took 0.0093606 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 38/10000
# info: 	 residual: 7.108149e-21
#
# info: [time] Linear solver took 0.0162973 s.
# info: Convergence criterion: |dx|=2.3151e-12, |x|=4.9998e+03, |dx|/|x|=4.6304e-16
# info: [time] Iteration #2 took 0.306909 s.
# info: [time] Solving process #0 took 0.614407 s in time step #9
# info: [time] Time step #9 took 0.655619 s.
# info: [time] Output of timestep 9 took 0.307423 s.
# info: Time step #10 started. Time: 2610.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.258174 s.
# info: [time] Applying Dirichlet BCs took 0.0077318 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 6.827571e-21
#
# info: [time] Linear solver took 0.0417523 s.
# info: Convergence criterion: |dx|=6.3880e+01, |x|=5.0452e+03, |dx|/|x|=1.2661e-02
# info: [time] Iteration #1 took 0.307801 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.271934 s.
# info: [time] Applying Dirichlet BCs took 0.0079214 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 7.500346e-21
#
# info: [time] Linear solver took 0.0151123 s.
# info: Convergence criterion: |dx|=2.8888e-12, |x|=5.0452e+03, |dx|/|x|=5.7258e-16
# info: [time] Iteration #2 took 0.295108 s.
# info: [time] Solving process #0 took 0.603258 s in time step #10
# info: [time] Time step #10 took 0.643319 s.
# info: [time] Output of timestep 10 took 0.302995 s.
# info: Time step #11 started. Time: 2611.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.25713 s.
# info: [time] Applying Dirichlet BCs took 0.0080791 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 106/10000
# info: 	 residual: 6.467342e-21
#
# info: [time] Linear solver took 0.0425126 s.
# info: Convergence criterion: |dx|=5.5383e+01, |x|=5.0844e+03, |dx|/|x|=1.0893e-02
# info: [time] Iteration #1 took 0.30787 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.27425 s.
# info: [time] Applying Dirichlet BCs took 0.0081283 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 5.832707e-21
#
# info: [time] Linear solver took 0.0146501 s.
# info: Convergence criterion: |dx|=2.5059e-12, |x|=5.0844e+03, |dx|/|x|=4.9286e-16
# info: [time] Iteration #2 took 0.297165 s.
# info: [time] Solving process #0 took 0.60545 s in time step #11
# info: [time] Time step #11 took 0.645825 s.
# info: [time] Output of timestep 11 took 0.303015 s.
# info: Time step #12 started. Time: 2612.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.258747 s.
# info: [time] Applying Dirichlet BCs took 0.0094333 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 9.787763e-21
#
# info: [time] Linear solver took 0.0459827 s.
# info: Convergence criterion: |dx|=4.8654e+01, |x|=5.1188e+03, |dx|/|x|=9.5050e-03
# info: [time] Iteration #1 took 0.314314 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.274346 s.
# info: [time] Applying Dirichlet BCs took 0.0086535 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.257512e-21
#
# info: [time] Linear solver took 0.0148534 s.
# info: Convergence criterion: |dx|=3.6907e-12, |x|=5.1188e+03, |dx|/|x|=7.2101e-16
# info: [time] Iteration #2 took 0.298004 s.
# info: [time] Solving process #0 took 0.612715 s in time step #12
# info: [time] Time step #12 took 0.652437 s.
# info: [time] Output of timestep 12 took 0.297404 s.
# info: Time step #13 started. Time: 2613.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.250046 s.
# info: [time] Applying Dirichlet BCs took 0.0085198 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 7.927378e-21
#
# info: [time] Linear solver took 0.0402598 s.
# info: Convergence criterion: |dx|=4.3213e+01, |x|=5.1493e+03, |dx|/|x|=8.3921e-03
# info: [time] Iteration #1 took 0.298988 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.273273 s.
# info: [time] Applying Dirichlet BCs took 0.0082433 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 40/10000
# info: 	 residual: 4.570639e-21
#
# info: [time] Linear solver took 0.0163434 s.
# info: Convergence criterion: |dx|=4.1199e-12, |x|=5.1493e+03, |dx|/|x|=8.0009e-16
# info: [time] Iteration #2 took 0.297988 s.
# info: [time] Solving process #0 took 0.597364 s in time step #13
# info: [time] Time step #13 took 0.637497 s.
# info: [time] Output of timestep 13 took 0.305409 s.
# info: Time step #14 started. Time: 2614.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.249823 s.
# info: [time] Applying Dirichlet BCs took 0.0079055 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 8.935804e-21
#
# info: [time] Linear solver took 0.0421392 s.
# info: Convergence criterion: |dx|=3.8737e+01, |x|=5.1765e+03, |dx|/|x|=7.4832e-03
# info: [time] Iteration #1 took 0.300013 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.273709 s.
# info: [time] Applying Dirichlet BCs took 0.0080042 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 38/10000
# info: 	 residual: 7.737842e-21
#
# info: [time] Linear solver took 0.0157619 s.
# info: Convergence criterion: |dx|=2.7381e-12, |x|=5.1765e+03, |dx|/|x|=5.2896e-16
# info: [time] Iteration #2 took 0.297613 s.
# info: [time] Solving process #0 took 0.597999 s in time step #14
# info: [time] Time step #14 took 0.637967 s.
# info: [time] Output of timestep 14 took 0.316244 s.
# info: Time step #15 started. Time: 2615.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251156 s.
# info: [time] Applying Dirichlet BCs took 0.0078297 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 8.360584e-21
#
# info: [time] Linear solver took 0.0427942 s.
# info: Convergence criterion: |dx|=3.4999e+01, |x|=5.2010e+03, |dx|/|x|=6.7293e-03
# info: [time] Iteration #1 took 0.301919 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.282608 s.
# info: [time] Applying Dirichlet BCs took 0.0078123 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.415056e-21
#
# info: [time] Linear solver took 0.0151942 s.
# info: Convergence criterion: |dx|=3.1892e-12, |x|=5.2010e+03, |dx|/|x|=6.1318e-16
# info: [time] Iteration #2 took 0.305759 s.
# info: [time] Solving process #0 took 0.608049 s in time step #15
# info: [time] Time step #15 took 0.64791 s.
# info: [time] Output of timestep 15 took 0.314339 s.
# info: Time step #16 started. Time: 2616.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.259647 s.
# info: [time] Applying Dirichlet BCs took 0.0101104 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 6.606584e-21
#
# info: [time] Linear solver took 0.0406675 s.
# info: Convergence criterion: |dx|=3.1839e+01, |x|=5.2233e+03, |dx|/|x|=6.0956e-03
# info: [time] Iteration #1 took 0.310563 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.267427 s.
# info: [time] Applying Dirichlet BCs took 0.0085857 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 9.057242e-21
#
# info: [time] Linear solver took 0.0150127 s.
# info: Convergence criterion: |dx|=3.5870e-12, |x|=5.2233e+03, |dx|/|x|=6.8672e-16
# info: [time] Iteration #2 took 0.291172 s.
# info: [time] Solving process #0 took 0.602166 s in time step #16
# info: [time] Time step #16 took 0.642646 s.
# info: [time] Output of timestep 16 took 0.314063 s.
# info: Time step #17 started. Time: 2617.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.269038 s.
# info: [time] Applying Dirichlet BCs took 0.0091096 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 8.187296e-21
#
# info: [time] Linear solver took 0.0416239 s.
# info: Convergence criterion: |dx|=2.9137e+01, |x|=5.2436e+03, |dx|/|x|=5.5567e-03
# info: [time] Iteration #1 took 0.319909 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.290222 s.
# info: [time] Applying Dirichlet BCs took 0.0084554 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 6.548237e-21
#
# info: [time] Linear solver took 0.0162131 s.
# info: Convergence criterion: |dx|=3.0785e-12, |x|=5.2436e+03, |dx|/|x|=5.8710e-16
# info: [time] Iteration #2 took 0.31503 s.
# info: [time] Solving process #0 took 0.635301 s in time step #17
# info: [time] Time step #17 took 0.676611 s.
# info: [time] Output of timestep 17 took 0.308138 s.
# info: Time step #18 started. Time: 2618.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.248581 s.
# info: [time] Applying Dirichlet BCs took 0.0078163 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 6.509765e-21
#
# info: [time] Linear solver took 0.0402695 s.
# info: Convergence criterion: |dx|=2.6805e+01, |x|=5.2623e+03, |dx|/|x|=5.0938e-03
# info: [time] Iteration #1 took 0.2968 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.27244 s.
# info: [time] Applying Dirichlet BCs took 0.0084593 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 8.266943e-21
#
# info: [time] Linear solver took 0.0144982 s.
# info: Convergence criterion: |dx|=3.0145e-12, |x|=5.2623e+03, |dx|/|x|=5.7285e-16
# info: [time] Iteration #2 took 0.295549 s.
# info: [time] Solving process #0 took 0.592712 s in time step #18
# info: [time] Time step #18 took 0.632332 s.
# info: [time] Output of timestep 18 took 0.304398 s.
# info: Time step #19 started. Time: 2619.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251655 s.
# info: [time] Applying Dirichlet BCs took 0.0080457 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 9.029699e-21
#
# info: [time] Linear solver took 0.0401121 s.
# info: Convergence criterion: |dx|=2.4775e+01, |x|=5.2795e+03, |dx|/|x|=4.6926e-03
# info: [time] Iteration #1 took 0.299955 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.268062 s.
# info: [time] Applying Dirichlet BCs took 0.0082648 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 6.409387e-21
#
# info: [time] Linear solver took 0.0148852 s.
# info: Convergence criterion: |dx|=2.5704e-12, |x|=5.2795e+03, |dx|/|x|=4.8686e-16
# info: [time] Iteration #2 took 0.291356 s.
# info: [time] Solving process #0 took 0.591697 s in time step #19
# info: [time] Time step #19 took 0.631814 s.
# info: [time] Output of timestep 19 took 0.316627 s.
# info: Time step #20 started. Time: 2620.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.252264 s.
# info: [time] Applying Dirichlet BCs took 0.0078611 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 7.504011e-21
#
# info: [time] Linear solver took 0.0423609 s.
# info: Convergence criterion: |dx|=2.2993e+01, |x|=5.2955e+03, |dx|/|x|=4.3421e-03
# info: [time] Iteration #1 took 0.302625 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.26778 s.
# info: [time] Applying Dirichlet BCs took 0.0082025 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 7.859513e-21
#
# info: [time] Linear solver took 0.0152989 s.
# info: Convergence criterion: |dx|=2.5059e-12, |x|=5.2955e+03, |dx|/|x|=4.7321e-16
# info: [time] Iteration #2 took 0.291418 s.
# info: [time] Solving process #0 took 0.594421 s in time step #20
# info: [time] Time step #20 took 0.634188 s.
# info: [time] Output of timestep 20 took 0.306417 s.
# info: Time step #21 started. Time: 2621.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.262475 s.
# info: [time] Applying Dirichlet BCs took 0.0089738 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 105/10000
# info: 	 residual: 8.399020e-21
#
# info: [time] Linear solver took 0.0456043 s.
# info: Convergence criterion: |dx|=2.1420e+01, |x|=5.3103e+03, |dx|/|x|=4.0337e-03
# info: [time] Iteration #1 took 0.317198 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.271601 s.
# info: [time] Applying Dirichlet BCs took 0.0081915 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 6.826164e-21
#
# info: [time] Linear solver took 0.0146225 s.
# info: Convergence criterion: |dx|=2.4069e-12, |x|=5.3103e+03, |dx|/|x|=4.5324e-16
# info: [time] Iteration #2 took 0.294563 s.
# info: [time] Solving process #0 took 0.612147 s in time step #21
# info: [time] Time step #21 took 0.652701 s.
# info: [time] Output of timestep 21 took 0.299709 s.
# info: Time step #22 started. Time: 2622.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251458 s.
# info: [time] Applying Dirichlet BCs took 0.0077992 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 8.360254e-21
#
# info: [time] Linear solver took 0.0399666 s.
# info: Convergence criterion: |dx|=2.0022e+01, |x|=5.3242e+03, |dx|/|x|=3.7606e-03
# info: [time] Iteration #1 took 0.29936 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.285821 s.
# info: [time] Applying Dirichlet BCs took 0.0085526 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 37/10000
# info: 	 residual: 7.979566e-21
#
# info: [time] Linear solver took 0.015787 s.
# info: Convergence criterion: |dx|=3.5501e-12, |x|=5.3242e+03, |dx|/|x|=6.6678e-16
# info: [time] Iteration #2 took 0.310303 s.
# info: [time] Solving process #0 took 0.610085 s in time step #22
# info: [time] Time step #22 took 0.650731 s.
# info: [time] Output of timestep 22 took 0.306748 s.
# info: Time step #23 started. Time: 2623.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.254341 s.
# info: [time] Applying Dirichlet BCs took 0.007712 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 9.180504e-21
#
# info: [time] Linear solver took 0.0397661 s.
# info: Convergence criterion: |dx|=1.8773e+01, |x|=5.3371e+03, |dx|/|x|=3.5174e-03
# info: [time] Iteration #1 took 0.301958 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.278699 s.
# info: [time] Applying Dirichlet BCs took 0.0086878 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 9.478930e-21
#
# info: [time] Linear solver took 0.0150178 s.
# info: Convergence criterion: |dx|=2.2985e-12, |x|=5.3371e+03, |dx|/|x|=4.3066e-16
# info: [time] Iteration #2 took 0.302542 s.
# info: [time] Solving process #0 took 0.604856 s in time step #23
# info: [time] Time step #23 took 0.644597 s.
# info: [time] Output of timestep 23 took 0.346392 s.
# info: Time step #24 started. Time: 2624.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.289189 s.
# info: [time] Applying Dirichlet BCs took 0.0109105 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 8.871374e-21
#
# info: [time] Linear solver took 0.0435451 s.
# info: Convergence criterion: |dx|=1.7651e+01, |x|=5.3493e+03, |dx|/|x|=3.2997e-03
# info: [time] Iteration #1 took 0.343793 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.294234 s.
# info: [time] Applying Dirichlet BCs took 0.0112299 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 34/10000
# info: 	 residual: 8.669660e-21
#
# info: [time] Linear solver took 0.0153704 s.
# info: Convergence criterion: |dx|=2.2583e-12, |x|=5.3493e+03, |dx|/|x|=4.2218e-16
# info: [time] Iteration #2 took 0.320972 s.
# info: [time] Solving process #0 took 0.665133 s in time step #24
# info: [time] Time step #24 took 0.709155 s.
# info: [time] Output of timestep 24 took 0.344501 s.
# info: Time step #25 started. Time: 2625.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.250235 s.
# info: [time] Applying Dirichlet BCs took 0.0097033 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 101/10000
# info: 	 residual: 7.634757e-21
#
# info: [time] Linear solver took 0.0414299 s.
# info: Convergence criterion: |dx|=1.6639e+01, |x|=5.3608e+03, |dx|/|x|=3.1038e-03
# info: [time] Iteration #1 took 0.301511 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.270731 s.
# info: [time] Applying Dirichlet BCs took 0.0079185 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 9.391651e-21
#
# info: [time] Linear solver took 0.0146632 s.
# info: Convergence criterion: |dx|=2.5164e-12, |x|=5.3608e+03, |dx|/|x|=4.6940e-16
# info: [time] Iteration #2 took 0.293446 s.
# info: [time] Solving process #0 took 0.595326 s in time step #25
# info: [time] Time step #25 took 0.635261 s.
# info: [time] Output of timestep 25 took 0.300728 s.
# info: Time step #26 started. Time: 2626.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.252955 s.
# info: [time] Applying Dirichlet BCs took 0.0076487 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 100/10000
# info: 	 residual: 9.600571e-21
#
# info: [time] Linear solver took 0.0396083 s.
# info: Convergence criterion: |dx|=1.5722e+01, |x|=5.3716e+03, |dx|/|x|=2.9269e-03
# info: [time] Iteration #1 took 0.300349 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.272445 s.
# info: [time] Applying Dirichlet BCs took 0.0096608 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 35/10000
# info: 	 residual: 5.687743e-21
#
# info: [time] Linear solver took 0.0153006 s.
# info: Convergence criterion: |dx|=3.4388e-12, |x|=5.3716e+03, |dx|/|x|=6.4019e-16
# info: [time] Iteration #2 took 0.297553 s.
# info: [time] Solving process #0 took 0.598247 s in time step #26
# info: [time] Time step #26 took 0.64005 s.
# info: [time] Output of timestep 26 took 0.317097 s.
# info: Time step #27 started. Time: 2627.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.255253 s.
# info: [time] Applying Dirichlet BCs took 0.0081097 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 100/10000
# info: 	 residual: 9.151084e-21
#
# info: [time] Linear solver took 0.0429089 s.
# info: Convergence criterion: |dx|=1.4888e+01, |x|=5.3818e+03, |dx|/|x|=2.7663e-03
# info: [time] Iteration #1 took 0.306476 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.269498 s.
# info: [time] Applying Dirichlet BCs took 0.0079863 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 36/10000
# info: 	 residual: 8.082676e-21
#
# info: [time] Linear solver took 0.0152372 s.
# info: Convergence criterion: |dx|=2.7756e-12, |x|=5.3818e+03, |dx|/|x|=5.1574e-16
# info: [time] Iteration #2 took 0.29285 s.
# info: [time] Solving process #0 took 0.599677 s in time step #27
# info: [time] Time step #27 took 0.639836 s.
# info: [time] Output of timestep 27 took 0.320904 s.
# info: Time step #28 started. Time: 2628.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.251057 s.
# info: [time] Applying Dirichlet BCs took 0.0078653 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 100/10000
# info: 	 residual: 8.448662e-21
#
# info: [time] Linear solver took 0.0398429 s.
# info: Convergence criterion: |dx|=1.4126e+01, |x|=5.3915e+03, |dx|/|x|=2.6201e-03
# info: [time] Iteration #1 took 0.298909 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.282402 s.
# info: [time] Applying Dirichlet BCs took 0.0079391 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 34/10000
# info: 	 residual: 7.978246e-21
#
# info: [time] Linear solver took 0.0142625 s.
# info: Convergence criterion: |dx|=2.1422e-12, |x|=5.3915e+03, |dx|/|x|=3.9733e-16
# info: [time] Iteration #2 took 0.304735 s.
# info: [time] Solving process #0 took 0.604015 s in time step #28
# info: [time] Time step #28 took 0.644236 s.
# info: [time] Output of timestep 28 took 0.302669 s.
# info: Time step #29 started. Time: 2629.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.27397 s.
# info: [time] Applying Dirichlet BCs took 0.0099393 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# ...
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 6.044463e-21
#
# info: [time] Linear solver took 0.013622 s.
# info: Convergence criterion: |dx|=7.5600e-10, |x|=1.5118e+06, |dx|/|x|=5.0006e-16
# info: [time] Iteration #2 took 0.338311 s.
# info: [time] Solving process #0 took 0.719495 s in time step #1541
# info: [time] Time step #1541 took 0.772831 s.
# info: [time] Output of timestep 1541 took 0.363239 s.
# info: Time step #1542 started. Time: 4142.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.326879 s.
# info: [time] Applying Dirichlet BCs took 0.0097451 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 7.200950e-21
#
# info: [time] Linear solver took 0.0467763 s.
# info: Convergence criterion: |dx|=7.7615e+03, |x|=1.5042e+06, |dx|/|x|=5.1600e-03
# info: [time] Iteration #1 took 0.383574 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314382 s.
# info: [time] Applying Dirichlet BCs took 0.0087311 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 20/10000
# info: 	 residual: 7.123841e-21
#
# info: [time] Linear solver took 0.0108458 s.
# info: Convergence criterion: |dx|=7.6358e-10, |x|=1.5042e+06, |dx|/|x|=5.0764e-16
# info: [time] Iteration #2 took 0.334132 s.
# info: [time] Solving process #0 took 0.718112 s in time step #1542
# info: [time] Time step #1542 took 0.769086 s.
# info: [time] Output of timestep 1542 took 0.376197 s.
# info: Time step #1543 started. Time: 4143.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.302885 s.
# info: [time] Applying Dirichlet BCs took 0.0087285 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 7.135267e-21
#
# info: [time] Linear solver took 0.0463768 s.
# info: Convergence criterion: |dx|=7.6794e+03, |x|=1.4966e+06, |dx|/|x|=5.1313e-03
# info: [time] Iteration #1 took 0.358148 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.341847 s.
# info: [time] Applying Dirichlet BCs took 0.0119233 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 20/10000
# info: 	 residual: 7.679327e-21
#
# info: [time] Linear solver took 0.0129643 s.
# info: Convergence criterion: |dx|=8.0551e-10, |x|=1.4966e+06, |dx|/|x|=5.3823e-16
# info: [time] Iteration #2 took 0.366897 s.
# info: [time] Solving process #0 took 0.725443 s in time step #1543
# info: [time] Time step #1543 took 0.784258 s.
# info: [time] Output of timestep 1543 took 0.38139 s.
# info: Time step #1544 started. Time: 4144.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.326744 s.
# info: [time] Applying Dirichlet BCs took 0.009781 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 7.069853e-21
#
# info: [time] Linear solver took 0.0462633 s.
# info: Convergence criterion: |dx|=7.5987e+03, |x|=1.4891e+06, |dx|/|x|=5.1029e-03
# info: [time] Iteration #1 took 0.382965 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.313491 s.
# info: [time] Applying Dirichlet BCs took 0.0089144 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 7.220164e-21
#
# info: [time] Linear solver took 0.0137226 s.
# info: Convergence criterion: |dx|=7.8383e-10, |x|=1.4891e+06, |dx|/|x|=5.2638e-16
# info: [time] Iteration #2 took 0.336278 s.
# info: [time] Solving process #0 took 0.719843 s in time step #1544
# info: [time] Time step #1544 took 0.773321 s.
# info: [time] Output of timestep 1544 took 0.364286 s.
# info: Time step #1545 started. Time: 4145.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.321078 s.
# info: [time] Applying Dirichlet BCs took 0.0090179 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 7.004624e-21
#
# info: [time] Linear solver took 0.0465267 s.
# info: Convergence criterion: |dx|=7.5193e+03, |x|=1.4817e+06, |dx|/|x|=5.0749e-03
# info: [time] Iteration #1 took 0.37679 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.318494 s.
# info: [time] Applying Dirichlet BCs took 0.0086843 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 6.417319e-21
#
# info: [time] Linear solver took 0.0132196 s.
# info: Convergence criterion: |dx|=7.5031e-10, |x|=1.4817e+06, |dx|/|x|=5.0640e-16
# info: [time] Iteration #2 took 0.34055 s.
# info: [time] Solving process #0 took 0.717762 s in time step #1545
# info: [time] Time step #1545 took 0.767877 s.
# info: [time] Output of timestep 1545 took 0.387418 s.
# info: Time step #1546 started. Time: 4146.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.330764 s.
# info: [time] Applying Dirichlet BCs took 0.0091692 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 6.939857e-21
#
# info: [time] Linear solver took 0.0463928 s.
# info: Convergence criterion: |dx|=7.4411e+03, |x|=1.4743e+06, |dx|/|x|=5.0471e-03
# info: [time] Iteration #1 took 0.386493 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.321814 s.
# info: [time] Applying Dirichlet BCs took 0.0083467 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 6.146978e-21
#
# info: [time] Linear solver took 0.0136879 s.
# info: Convergence criterion: |dx|=7.1765e-10, |x|=1.4743e+06, |dx|/|x|=4.8676e-16
# info: [time] Iteration #2 took 0.343997 s.
# info: [time] Solving process #0 took 0.730869 s in time step #1546
# info: [time] Time step #1546 took 0.780848 s.
# info: [time] Output of timestep 1546 took 0.372485 s.
# info: Time step #1547 started. Time: 4147.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.334552 s.
# info: [time] Applying Dirichlet BCs took 0.0088371 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 6.874684e-21
#
# info: [time] Linear solver took 0.0462067 s.
# info: Convergence criterion: |dx|=7.3643e+03, |x|=1.4671e+06, |dx|/|x|=5.0197e-03
# info: [time] Iteration #1 took 0.389773 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.32091 s.
# info: [time] Applying Dirichlet BCs took 0.0092033 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 6.734274e-21
#
# info: [time] Linear solver took 0.013081 s.
# info: Convergence criterion: |dx|=7.3081e-10, |x|=1.4671e+06, |dx|/|x|=4.9815e-16
# info: [time] Iteration #2 took 0.343359 s.
# info: [time] Solving process #0 took 0.733532 s in time step #1547
# info: [time] Time step #1547 took 0.784413 s.
# info: [time] Output of timestep 1547 took 0.357945 s.
# info: Time step #1548 started. Time: 4148.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.323817 s.
# info: [time] Applying Dirichlet BCs took 0.0088242 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 6.809857e-21
#
# info: [time] Linear solver took 0.0462602 s.
# info: Convergence criterion: |dx|=7.2887e+03, |x|=1.4599e+06, |dx|/|x|=4.9927e-03
# info: [time] Iteration #1 took 0.379072 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.314751 s.
# info: [time] Applying Dirichlet BCs took 0.0087636 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 7.816790e-21
#
# info: [time] Linear solver took 0.013535 s.
# info: Convergence criterion: |dx|=7.4198e-10, |x|=1.4599e+06, |dx|/|x|=5.0825e-16
# info: [time] Iteration #2 took 0.33722 s.
# info: [time] Solving process #0 took 0.716691 s in time step #1548
# info: [time] Time step #1548 took 0.767233 s.
# info: [time] Output of timestep 1548 took 0.368778 s.
# info: Time step #1549 started. Time: 4149.0230000000001. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.324682 s.
# info: [time] Applying Dirichlet BCs took 0.0091794 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 6.745041e-21
#
# info: [time] Linear solver took 0.0479406 s.
# info: Convergence criterion: |dx|=7.2142e+03, |x|=1.4528e+06, |dx|/|x|=4.9659e-03
# info: [time] Iteration #1 took 0.381972 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.31204 s.
# info: [time] Applying Dirichlet BCs took 0.0090959 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 25/10000
# info: 	 residual: 6.069034e-21
#
# info: [time] Linear solver took 0.0130863 s.
# info: Convergence criterion: |dx|=7.2940e-10, |x|=1.4528e+06, |dx|/|x|=5.0208e-16
# info: [time] Iteration #2 took 0.334383 s.
# info: [time] Solving process #0 took 0.716753 s in time step #1549
# info: [time] Time step #1549 took 0.766171 s.
# info: [time] Output of timestep 1549 took 0.376565 s.
# info: Time step #1550 started. Time: 4149.973. Step size: 0.9499999999998181.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.324567 s.
# info: [time] Applying Dirichlet BCs took 0.0084613 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 8.389755e-21
#
# info: [time] Linear solver took 0.0464495 s.
# info: Convergence criterion: |dx|=3.7427e+04, |x|=1.4340e+06, |dx|/|x|=2.6099e-02
# info: [time] Iteration #1 took 0.37967 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.315725 s.
# info: [time] Applying Dirichlet BCs took 0.0086323 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 24/10000
# info: 	 residual: 8.855003e-21
#
# info: [time] Linear solver took 0.0129389 s.
# info: Convergence criterion: |dx|=6.6407e-10, |x|=1.4340e+06, |dx|/|x|=4.6308e-16
# info: [time] Iteration #2 took 0.337458 s.
# info: [time] Solving process #0 took 0.717526 s in time step #1550
# info: [time] Time step #1550 took 0.768902 s.
# info: [time] Output of timestep 1550 took 0.376673 s.
# info: The whole computation of the time stepping took 1550 steps, in which
# 	 the accepted steps are 1550, and the rejected steps are 0.
#
# info: [time] Execution took 1744.91 s.
# info: OGS terminated on 2026-03-19 12:14:38+0100.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path = Path("_out_ps/BH10_20180716_51.6.pvd")
ms = ot.MeshSeries(pvd_path)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="Pa")

# %%
y=25
z=-50

np.geomspace(0.038,5,5)

coords=np.array(np.linspace([25,y,z],[50,y,z],5)) #extracting along x linearly
coords[:,0]=rgeo+25 #adjusting geometry shifting
ms_probes = ms.extract_probe(ms,points=coords)

labels = [f"x={pt[0]:>5.2f}, y={y}, z={z}" for pt in coords]

pwsr2p= step_rate_s(pwd_ps, ms_probes.timevalues, tp, q_array, ddict, k_val, r_val) #diff by time resolution
diff = pwsr2p - ms_probes['pressure']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1551/1551 [01:46<00:00, 14.52it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
t=dataex_f['Zeit [s]']

fig4, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
ot.plot.line(ms_probes,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels)
axs[0].plot(t, pwsr2,color='tab:red', label=line_labels) 
axs[1].plot(ms_probes.timevalues, diff, label=line_labels)

fig4.suptitle("Point source analytical - Numerical OGS Nodal, 3D") 
axs[0].set_title("Results by distance (radius)")
axs[1].set_title("Difference analytical-OGS")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / Pa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

#plt.savefig("psn_3D_BH10_20180716_51.6.pdf", format="pdf") 
plt.show()

# %% [markdown]
# **NOTE: Numerical difference is due to mesh and rw relations.
# The specific storage capacity (OGS) scaling is equal to $$s=c* \phi, \quad \left[\mathrm{Pa^{-1}}\right]$$, the scaling for the flow is $$r_{\mathrm{eq}} = (3 * LV / (4 \pi))^{1/3}$$
# $$q_{\mathrm{fact}}=(1/r_{\mathrm{eq}})^{2/3}$$
# $$q_{\mathrm{num}}=q_{\mathrm{fact}} \, q_{\mathrm{an}}$$
# Where $LV$ is the local volume of the first ring of elements in around the node source; $q_{\mathrm{num}}\, , q_{\mathrm{fact}} \, , q_{\mathrm{an}}$, are the numerical (for OGS), factor, and analytical flow input.
